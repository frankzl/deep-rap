# %% [markdown]
# # 02 - Generating Word by Word
#
# This time we don't predict letter by letter, but word by word!

# %%
import tools.processing as pre
import re

# use less text for now to avoid memory error
text = pre.get_text("data/cleaned-rap-lyrics/clean2_pac_.txt")[:20002]

vocab = pre.Vocabulary(text)

TIMESTEPS = 10

# double \\n to avoid null error in tensorboard projection
text = text.replace("\n", " \\n ")

# remove extra spacing
tokens = re.sub( " +", " ", text).split(" ")[:-1]

str_data, str_labels = pre.create_data_label_pairs(tokens, TIMESTEPS)

print( list( zip(str_data, str_labels) )[:5] )
# Out:
# [(['as', 'real', 'as', 'it', 'seems', 'the', 'american', 'dream', '\\n', "ain't"], 'nothing'), (['real', 'as', 'it', 'seems', 'the', 'american', 'dream', '\\n', "ain't", 'nothing'], 'but'), (['as', 'it', 'seems', 'the', 'american', 'dream', '\\n', "ain't", 'nothing', 'but'], 'another'), (['it', 'seems', 'the', 'american', 'dream', '\\n', "ain't", 'nothing', 'but', 'another'], 'calculated'), (['seems', 'the', 'american', 'dream', '\\n', "ain't", 'nothing', 'but', 'another', 'calculated'], 'schemes')]

# %%
import numpy as np 
import tools.training as tr

class OneHotWordEncoder(tr.Encoder):
    """
    Encodes sequences of words to sequences of 1-Hot Encoded vectors
    """
    
    def __init__(self, name, word2index):
        super(OneHotWordEncoder, self).__init__(name)
        self.word2index = word2index
        
    def encode(self, sequences):
        """
        Encodes our sequences of words to sequences of 1-Hots
        """
        encoded_sequences = []
        for seq in sequences:
            
            encoded = np.zeros( ( len(seq), len(self.word2index) ) )
            
            for idx, word in enumerate(seq):
                encoded[idx][ self.word2index[word] ] = 1
            
            encoded_sequences.append(encoded)
        
        return np.array(encoded_sequences)
    
    def encode_raw(self, text):
        """
        Encodes a text to sequences of 1-Hots (needed for sampling)
        """
        text = text.replace("\n", " \\n ")
        text = text.replace(" +", " ")
        words = text.split(" ")
        encoded = np.zeros( ( len(words), len(self.word2index) ) )
        
        for idx, word in enumerate(words):
            if word != "":
                encoded[idx][ self.word2index[word] ] = 1
        
        return np.array( [encoded] )
        
    
    def encode_labels(self, labels):
        """
        Encodes the labels (sequences of one word)
        """
        
        encoded = []
        
        for label in labels:
            one_hot_vec = np.zeros(len(self.word2index), dtype=int)
            one_hot_vec[ self.word2index[label] ] = 1
            encoded.append( one_hot_vec )
            
        return np.array(encoded)
    
class OneHotWordDecoder(tr.Decoder):
    """
    Decodes a 1-Hot Encoded vector (prediction) to a word
    """
    def __init__(self, name, index2word, temperature=0.5):
        super(OneHotWordDecoder, self).__init__(name)
        self.temperature = temperature
        self.index2word = index2word 
        
    def decode(self, predicted):
        predicted = tr.sample_from_distribution(predicted, temperature=self.temperature)
        return " " + self.index2word[ np.argmax(predicted) ].replace("\\n","\n")

# %%
import tools.training as tr

encoder = OneHotWordEncoder("1-Hot-Word-Encoding", vocab.word2index)
decoder = OneHotWordDecoder("1-Hot-Word-Decoding", vocab.index2word, temperature=0.8)

data = encoder.encode( str_data )
labels = encoder.encode_labels( str_labels )

# %%
import tools.architectures as nn

HIDDEN_LAYER_SIZE = 512
VOCAB_SIZE = vocab.get_size()

EPOCHS = 20
BATCH_SIZE = 256

rnn = nn.SingleLayerRNN(name = "basic")
rnn.build(HIDDEN_LAYER_SIZE, VOCAB_SIZE, TIMESTEPS, l2_reg=0.0)


sampler = lambda trainable, seed_text: tr.sample( seed_text, trainable, encoder, decoder, length=20)

tr.train_model(rnn, data, labels, sampler, epochs=EPOCHS, batch_size=BATCH_SIZE)
# Out:
# Epoch 1/20
# Loss:    	 6.189930438995361
# Accuracy:	 10.659217834472656
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me time time leave day next get weapon tried fiend grabbed run them stompin' got young toast curve passed sell look
#
#
# Epoch 2/20
# Loss:    	 5.690038681030273
# Accuracy:	 10.659217834472656
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
#
#  ear vicious anywhere
#  the they tried if is don't purity
#  me risin' liar door
#  a
#
#
# Epoch 3/20
# Loss:    	 5.626894474029541
# Accuracy:	 10.659217834472656
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me that you
#
#  education drop
#  and vacation knew get but you i'm you gold when
#
#
#
#
#
# Epoch 4/20
# Loss:    	 5.531834602355957
# Accuracy:	 10.659217834472656
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me up up of to the
#  i sleepin weapon reach
#  you
#  the that
#  teach
#  to rock
#
#
# Epoch 5/20
# Loss:    	 5.548983573913574
# Accuracy:	 10.659217834472656
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me other to a to be i
#  on dizzy's i'm larger people bad
#
#
#  it'll i this that
#
#
# Epoch 6/20
# Loss:    	 5.486374855041504
# Accuracy:	 10.659217834472656
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me you
#  the
#  ray up like the i it
#  and my like i the
#  out makin' a
#
#
# Epoch 7/20
# Loss:    	 5.419228553771973
# Accuracy:	 10.681564331054688
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me the
#
#  change roc me the how i
#  its the and my to
#  lady thing hell you
#
#
# Epoch 8/20
# Loss:    	 5.324215888977051
# Accuracy:	 10.703910827636719
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me help
#
#
#  they finally
#  gone the to
#  can't gave
#  you're
#  to
#
#  and
#
#
# Epoch 9/20
# Loss:    	 5.203132629394531
# Accuracy:	 10.905028343200684
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me people
#  you was don't kept dizzy but my was the couldn't get the it you
#
#  never mic
#
#
# Epoch 10/20
# Loss:    	 5.036197185516357
# Accuracy:	 12.983240127563477
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
#
#
#  wanna the i bomb like uncle i'm cause i stop of your now you the
#  get
#
#
# Epoch 11/20
# Loss:    	 4.854938983917236
# Accuracy:	 15.932960510253906
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me your dizzy me me beat cause tyson
#  out the what i'm tip
#  cause i this i'll
#  reason
#
#
# Epoch 12/20
# Loss:    	 4.60801887512207
# Accuracy:	 18.055866241455078
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me me mother
#  me
#  mother a go
#  and
#  and now cause the
#
#  damn i'm ray
#
#
# Epoch 13/20
# Loss:    	 4.457935810089111
# Accuracy:	 16.759777069091797
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me me me make you i'm me on cause i'll cause cause this stop cute my be up knowledge punk started
#
#
# Epoch 14/20
# Loss:    	 4.25487756729126
# Accuracy:	 19.418994903564453
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
#  a you a be seconds on in to
#  fantasizin
#  history dizzy deny like history my us now
#
#
# Epoch 15/20
# Loss:    	 4.030706405639648
# Accuracy:	 21.85474967956543
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me me cordless
#  you me lady dropped and me
#  me me let wanted cared
#  and
#  drop go
#
#
# Epoch 16/20
# Loss:    	 3.8866708278656006
# Accuracy:	 22.10055923461914
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me me me me
#  me me just speakin' at get beat punk diss house so
#  hell
#  i still
#
#
# Epoch 17/20
# Loss:    	 3.7227392196655273
# Accuracy:	 23.82122802734375
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me beat me you a what i'm go i'm my be think you poetry you why like cause strictly beat think
#
#
# Epoch 18/20
# Loss:    	 3.5273277759552
# Accuracy:	 27.240222930908203
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
#  cause cause cause me this scared the
#
#  beat it less the start
#  the future
#  in
#
#
# Epoch 19/20
# Loss:    	 3.473210096359253
# Accuracy:	 27.173185348510742
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
#  a a man realize is with gonna
#  choke you you over
#  too use this no nuclear you
#
#
# Epoch 20/20
# Loss:    	 3.199958086013794
# Accuracy:	 30.078210830688477
# ------Sampling----------
# seed:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
# -
# result:
# as real as it seems the american dream
# ain't nothing but another calculated schemes
# to get us locked up shot up back in chains
# to deny us of the future rob our names
# kept my history of mystery but now i see
# the american dream wasn't meant for me
# cause lady liberty is a hypocrite she lied to me
# promised me freedom education equality
# never gave me nothing but slavery
# and now look at how dangerous you made me
#  well mad sure motion strong is over your your your your your your that's that to do to and

# %% [markdown]
# ### Let's try to sample on completely random sentences that we made up!

# %%
sampler(rnn, "while i go down the street \n you was lookin' at me \n is this even good \n why")

# %% [markdown]
# ### Alright, but far from good. Now increase the #TIMESTEPS and decrease temperature

# %%
TIMESTEPS = 20

str_data, str_labels = pre.create_data_label_pairs(tokens, TIMESTEPS)

encoder = OneHotWordEncoder("1-Hot-Word-Encoding", vocab.word2index)
decoder = OneHotWordDecoder("1-Hot-Word-Decoding", vocab.index2word, temperature=0.6)

data = encoder.encode( str_data )
labels = encoder.encode_labels( str_labels )

# %%
import tools.architectures as nn

HIDDEN_LAYER_SIZE = 512
VOCAB_SIZE = vocab.get_size()

EPOCHS = 20
BATCH_SIZE = 256

rnn = nn.SingleLayerRNN(name = "basic")
rnn.build(HIDDEN_LAYER_SIZE, VOCAB_SIZE, TIMESTEPS, l2_reg=0.0)


sampler = lambda trainable, seed_text: tr.sample( seed_text, trainable, encoder, decoder, length=20)

tr.train_model(rnn, data, labels, sampler, epochs=EPOCHS, batch_size=BATCH_SIZE)

# %%
sampler(rnn, "while i go down the street \n you was lookin' at me \n is this even good or is it just bad \n is this even good or is it just bad")

# %% [markdown]
# # Learnings
#
# We are now not predicting letter by letter, but word by word. The model does not have to learn how to spell the words.
# After a few iterations we already get some sentences that make sense to a reader!
#
# Some of them seem like actual lyrics, e.g.
#
# **"to get us locked up up up up up up in bust in and knowledge and lies and kick and me if don't you well"**
#
# The now export the new encoder and decoder to our module **tools.training**
#
# Let's see how a multi layered LSTM performs in the next notebook
