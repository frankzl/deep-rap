# %% [markdown]
# # Pretrained embeddings for our words

# %%
import tools.processing as pre
import numpy as np

path = "data/embeddings/glove.840B.300d.txt"

def get_glove(path_to_glove,word2index_map):
    embedding_weights = {}
    count_all_words = 0
    with open(path_to_glove,'r') as f:
        for line in f:
            vals = line.split(' ')
            word = str(vals[0])
            if word in word2index_map:                
                count_all_words += 1                                 
                coefs = np.asarray(vals[1:],dtype='float32')
                coefs /= np.linalg.norm(coefs)
                embedding_weights[word] = coefs
            if count_all_words== len(word2index_map) -1:
                break
    return embedding_weights

# %%
text = pre.get_text("data/ref_text3.txt")
vocab = pre.Vocabulary(text)

words_alpha = pre.get_text("data/words_alpha.txt")
alpha_vocab = pre.Vocabulary(words_alpha)

# %%
unk = []
for key in vocab._dict.keys():
    if(key not in alpha_vocab._dict):
        unk.append(key)

# %%
unk
# Out:
# ['threesixty',
#  'skanless',
#  'jackmack',
#  'varmits',
#  'travie',
#  'matress',
#  'hussien',
#  'lucious',
#  'wowie',
#  'evers',
#  'hafta',
#  'sekon',
#  'anyday',
#  'yoasiatics',
#  'gameplan',
#  'ceelo',
#  'furier',
#  'vette',
#  'quizzin',
#  'huxtables',
#  'edamame',
#  'trippy',
#  'ohhohohohwhoa',
#  'halfblack',
#  'raaaaaaager',
#  'heheheyah',
#  'muhfuckers',
#  'streetz',
#  'booya',
#  'darkskinned',
#  'lizzane',
#  'disrepect',
#  'bonebonebonebone',
#  'togination',
#  'epps',
#  'crusing',
#  'raprelated',
#  'dunn',
#  'problemo',
#  'wyndanch',
#  'mackers',
#  'threefourths',
#  'mudering',
#  'eightynine',
#  'ahhhh',
#  'posturepedic',
#  'heffers',
#  'wieghts',
#  'hennessy',
#  'timebomb',
#  'christenin',
#  'arguements',
#  'lexxxus',
#  'gomars',
#  'peformin',
#  'yuppers',
#  'busta',
#  'majorly',
#  'steelo',
#  'reknowned',
#  'bumba',
#  'macaveli',
#  'eyez',
#  'pinkle',
#  'preoccuppied',
#  'disrespecting',
#  'ohhhhhh',
#  'exray',
#  'tingaling',
#  'glocks',
#  'puba',
#  'montell',
#  'splifted',
#  'lowlows',
#  'hawkin',
#  'nefretiti',
#  'amibitions',
#  'comprimising',
#  'uhyeah',
#  'aruba',
#  'bassuntill',
#  'latasha',
#  'carressing',
#  'wesson',
#  'twentyfourseven',
#  'mothafucking',
#  'baybay',
#  'overthugging',
#  'fearified',
#  'obama',
#  'negotiatin',
#  'gogetter',
#  'mny',
#  'hellbound',
#  'dissing',
#  'headbanger',
#  'thes',
#  'blurried',
#  "young'uns",
#  'jojo',
#  'twitterin',
#  'strugala',
#  'assasinator',
#  'bearthem',
#  'haging',
#  'bzzzz',
#  'kahn',
#  'llello',
#  'papermates',
#  'plainpat',
#  'mophreme',
#  'oahhhohh',
#  'henessee',
#  'hyperchrondriac',
#  'walters',
#  'nikes',
#  'ooohooooh',
#  'globalwarming',
#  'oahhhahh',
#  'guiness',
#  'wowwowwow',
#  'presidentials',
#  'sleeezy',
#  'stresed',
#  'vorhees',
#  'dru',
#  'mastercrash',
#  'notthinki',
#  'giseles',
#  'ninetynine',
#  'oooooooooohhhh',
#  'heirem',
#  'rainbut',
#  'paragraphologist',
#  'aiyyo',
#  'upteenth',
#  'valenti',
#  'toastses',
#  'ahahahohoh',
#  'osa',
#  'stevie',
#  'indentification',
#  'swoll',
#  'rosecranz',
#  'masterplan',
#  'whodini',
#  'melodiesunmakable',
#  'definitly',
#  'carcuses',
#  'originations',
#  "muh'fucking",
#  'booyaa',
#  'reperations',
#  'patternunecscapable',
#  'dramacy',
#  'deisel',
#  'imortal',
#  'dripdrop',
#  'hoochercoocher',
#  'hennessey',
#  'gators',
#  'ninetyy',
#  'stip',
#  'asskissing',
#  'multived',
#  'miccops',
#  'hiphoppers',
#  'droptop',
#  'popos',
#  'thuging',
#  'dubar',
#  'killorbekilled',
#  'tiva',
#  'vallejo',
#  'raiseed',
#  'carmelo',
#  'crakers',
#  'beatbreaks',
#  'sixone',
#  'deniro',
#  'instutionalized',
#  'gangstas',
#  'mobb',
#  'jabebecausezi',
#  'dialation',
#  'remainable',
#  'jeapordizing',
#  'weakrhymer',
#  'ninetysix',
#  'pacino',
#  'lizzight',
#  'bidness',
#  'medgar',
#  'copywritten',
#  '501',
#  'twentyfo',
#  'scarfo',
#  'quayle',
#  'lyte',
#  'rahrah',
#  'towerin',
#  'ses',
#  'fiveoh',
#  'mainooooo',
#  'threefiftyseven',
#  'kosugi',
#  'coastwest',
#  '88',
#  'boricua',
#  'crackhead',
#  'atttention',
#  'gambino',
#  'minutemaid',
#  'chitown',
#  'tanqueray',
#  'swerl',
#  'napolean',
#  'slobbin',
#  'whorider',
#  'fufilling',
#  'blidge',
#  'goines',
#  'topranked',
#  'fugazi',
#  'groupy',
#  'surveyin',
#  'benzes',
#  'kotex',
#  'mothafuckers',
#  'hardrap',
#  'sidewest',
#  'tre',
#  'kunta',
#  'knahmean',
#  'nas',
#  'yaknahmean',
#  'thang',
#  'sadicious',
#  'hmmmmmm',
#  'toolies',
#  'rigarmortis',
#  'punchline',
#  'kapow',
#  'flatline',
#  'novicane',
#  'fiending',
#  'becasue',
#  'landmines',
#  'isoh',
#  'ratpack',
#  'godzilla',
#  'supression',
#  'unconciousness',
#  'djing',
#  'copastetic',
#  'iiiiiiiii',
#  'hoopala',
#  'knowitall',
#  'punchlines',
#  'sanging',
#  'ziploc',
#  'heeee',
#  'hennesse',
#  'haffa',
#  'facebook',
#  'sajak',
#  'deez',
#  'allnightlong',
#  'golddigging',
#  'betcha',
#  'thangs',
#  'niggaslashrap',
#  'rocketship',
#  'indo',
#  'eskimys',
#  'twothou',
#  'xthree',
#  'quaid',
#  'flizzight',
#  'edi',
#  'perignon',
#  'hos',
#  'jewell',
#  'dopeness',
#  'ninetytwo',
#  'childern',
#  'nuckas',
#  'redman',
#  'wwwrakimcom',
#  'klow',
#  'klacka',
#  'penals',
#  'fantansy',
#  'determinely',
#  'mcdonalds',
#  'frontpage',
#  'liberace',
#  'bootycalls',
#  'homeyg',
#  'oftb',
#  'prada',
#  'moneymakinmachines',
#  'narratin',
#  'mentallect',
#  'adolecents',
#  'devestating',
#  'mictomouth',
#  'exsisted',
#  'ehhm',
#  'tearthem',
#  'smokethem',
#  'ceo',
#  'inglewatts',
#  'shabazz',
#  'pachenga',
#  'inducis',
#  'spraypainting',
#  'cbo',
#  'plinkling',
#  'oahahhhh',
#  'whooo',
#  "you're",
#  'energentic',
#  'heyyyayyy',
#  'temptingwhatever',
#  'microphonist',
#  'ayo',
#  'grayskull',
#  'ransome',
#  'rugrat',
#  'uzzie',
#  'heffing',
#  'rolex',
#  'mista',
#  'periphereal',
#  'hahahahah',
#  'clarkworld',
#  'mynin',
#  'theeese',
#  'telekenesis',
#  'craaazy',
#  'microphonethat',
#  'hahahahaha',
#  'ixnay',
#  'hollar',
#  'happend',
#  'dooder',
#  "hand'sll",
#  'scantron',
#  'doubleedging',
#  'delores',
#  'hellraising',
#  'milleni',
#  'penitentary',
#  'filas',
#  'gucci',
#  'daz',
#  'trendsetter',
#  'excersising',
#  'leavey',
#  'kastro',
#  'ludacris',
#  'klu',
#  'kaboom',
#  'motherfuckersdid',
#  'papapoker',
#  'zoot',
#  'interchart',
#  'locs',
#  'pennys',
#  'cochran',
#  'itty',
#  'hiv',
#  'excuseamoi',
#  'heartlessass',
#  'luda',
#  'playerhaters',
#  'buckfifty',
#  'californiaknows',
#  'pasttime',
#  'muuuuzik',
#  'bluried',
#  'beyotch',
#  'claat',
#  'googled',
#  'blurredmumbled',
#  'conveyin',
#  'brawhat',
#  'riight',
#  'tated',
#  'posession',
#  'peuente',
#  'afeni',
#  'magnificient',
#  'rentarapper',
#  'swayze',
#  'icey',
#  'lemme',
#  'beitch',
#  'aightaight',
#  'ufc',
#  'nino',
#  'phd',
#  'grabed',
#  'hussein',
#  'souljah',
#  'oj',
#  'followin',
#  'cockhounds',
#  'hiphop',
#  'ecstacy',
#  'guap',
#  'nananananananana',
#  'loked',
#  'rockin',
#  'hollowpoint',
#  'hahah',
#  'mothercrookedfucking',
#  'ninetyseven',
#  'alahahalahalcohol',
#  'cindi',
#  'downest',
#  'boogy',
#  'maaaannnn',
#  'iverson',
#  'fuckboys',
#  'efx',
#  'trickass',
#  'fantansies',
#  'finga',
#  'mindgames',
#  'zoninnnnnnnn',
#  'hindsite',
#  'nonplayers',
#  'khomeini',
#  'ethchasketch',
#  'timbs',
#  'ohah',
#  'tooollll',
#  'facepoke',
#  'breakbeats',
#  'totions',
#  'sheeit',
#  'wonderous',
#  'anwar',
#  'hypertone',
#  'luv',
#  'runon',
#  "wasn't",
#  'stetsasonic',
#  'crenshaw',
#  'treytrey',
#  'lopez',
#  'mescudi',
#  'gangbangers',
#  'tymel',
#  'southside',
#  'homeboy',
#  'eleviates',
#  'hollowtip',
#  'compton',
#  'basicaly',
#  'airforce',
#  'akai',
#  'motherfuck',
#  'weisel',
#  'trefo',
#  'chickenheads',
#  'selfesteem',
#  'hahahahahahahaha',
#  'suffocator',
#  'collaspe',
#  'hamptons',
#  'shangrila',
#  'advaced',
#  'limbwalk',
#  'bvd',
#  'youuuuu',
#  'swolls',
#  'kday',
#  'disapear',
#  'blackstreets',
#  'sumping',
#  'backroom',
#  'knowyou',
#  'alchol',
#  'amaru',
#  'outtie',
#  'penaltyand',
#  'murdererbefore',
#  'jayz',
#  'larock',
#  'cliquot',
#  'elel',
#  'ladadadah',
#  'bumrushed',
#  '2fifth',
#  'courpse',
#  'interveen',
#  'beha',
#  'conceils',
#  'widdit',
#  'rogaine',
#  'souja',
#  'imeem',
#  'remy',
#  'bucktown',
#  'skypage',
#  'doogie',
#  'funhouse',
#  ';',
#  'shoewear',
#  'jewelery',
#  'toginations',
#  'accesory',
#  'barracade',
#  'sside',
#  'rickashay',
#  'nowww',
#  'hoties',
#  'scoliosisskulliosis',
#  "'rari",
#  'heaty',
#  'reposess',
#  'scarifice',
#  'beatdown',
#  'yanamean',
#  'pauletta',
#  'tlc',
#  'battleowow',
#  'handheld',
#  'urkel',
#  "fo'fo'",
#  'penetentiaries',
#  'michaelangelo',
#  'optimos',
#  'shakur',
#  'converstion',
#  'lbc',
#  'hahahahahaha',
#  'musta',
#  'tarvue',
#  'odinga',
#  'rikers',
#  'herron',
#  'oooooooohooooooooh',
#  'prprpretty',
#  'funkdified',
#  'heheheheheheh',
#  'reala',
#  'gandalf',
#  'topling',
#  'reconize',
#  'oneday',
#  'dancefloor',
#  'khadafi',
#  'todosomethinass',
#  'babygirl',
#  'heeey',
#  'penetentiary',
#  'playplay',
#  'slowmo',
#  'sestruct',
#  'garvin',
#  'baaaaaaaaby',
#  'brendas',
#  'homie',
#  'blaow',
#  'eveready',
#  'neigborhood',
#  'diggi',
#  'motorola',
#  'hooptee',
#  'heheheheheh',
#  'yayo',
#  'bullshiting',
#  'gank',
#  'ovius',
#  'realeast',
#  'deathrow',
#  'bizzy',
#  'bombass',
#  'rigormortis',
#  'rangea',
#  'robery',
#  'nefertiti',
#  'flamable',
#  'dinayros',
#  'seperated',
#  'hennesee',
#  'ty',
#  'disrespected',
#  'sactown',
#  'centpac',
#  'temptaion',
#  'posessed',
#  'twentythree',
#  'neccesary',
#  'tugawar',
#  'nighttrain',
#  'doomstick',
#  'immortalz',
#  'marin',
#  'quran',
#  'yeaaaaaaaah',
#  'bizar',
#  'pandemical',
#  'loooove',
#  'batteram',
#  'heavyheavyheavy',
#  'inglewood',
#  'scamming',
#  'fuckniggaz',
#  'poonannynans',
#  'fing',
#  'riker',
#  'toni',
#  'adolecsent',
#  'togine',
#  'tyson',
#  'heneesee',
#  'fortyfour',
#  'editorforever',
#  'gooshy',
#  'wanksters',
#  'ninetythree',
#  'kci',
#  'doublei',
#  'equisite',
#  'severly',
#  'gunslang',
#  'straightass',
#  'mgmt',
#  'buntry',
#  'walkby',
#  'lexus',
#  'bodybags',
#  'rottwilers',
#  'needbeen',
#  'lastlast',
#  'dre',
#  'kinda',
#  'grafitti',
#  'adrendaline',
#  'yg',
#  'twodollar',
#  'milita',
#  'ariadiarrhea',
#  'chasen',
#  'choo',
#  'mmm',
#  'skeezing',
#  'topicless',
#  'decieve',
#  'foolies',
#  'burrying',
#  'maj',
#  'atmopshere',
#  'outlawz',
#  'killa',
#  'cooke',
#  'assed',
#  'oneeightyfive',
#  'megathesis',
#  'ballsac',
#  "mc'sll",
#  'rollies',
#  'aaliyah',
#  'blegit',
#  'stonefacing',
#  'stratego',
#  'mumar',
#  'magellen',
#  'bangathon',
#  'shoutout',
#  'knowhati',
#  'burried',
#  'neccessary',
#  'dopefiend',
#  'threehundred',
#  'hehahahahaha',
#  'hoochie',
#  'mamama',
#  'cudders',
#  'repping',
#  'doubleups',
#  'gatorade',
#  'devante',
#  'mackaveli',
#  'fivedoubleoh',
#  'glistenin',
#  'carlito',
#  'muah',
#  'jocking',
#  'konfusion',
#  "o'jays",
#  'nah',
#  'sixeight',
#  'comparethem',
#  'reminsce',
#  'gogetters',
#  'showtime',
#  'uhm',
#  'alcholics',
#  'peticular',
#  'cri',
#  'crookedass',
#  'lovetraps',
#  'trifeass',
#  'comatoses',
#  'oaktown',
#  'askses',
#  'sticthes',
#  'twentysomeodd',
#  'dopeman',
#  'gaye',
#  'wearin',
#  'bangbang',
#  'jodeci',
#  'beyatch',
#  'yeauhh',
#  'wannabe',
#  'dro',
#  'smugglin',
#  'prolly',
#  'carots',
#  'nanananananana',
#  'rrrrright',
#  'nitti',
#  'stayinliner',
#  'existance',
#  'concorde',
#  'tonguekissing',
#  'trigg',
#  'nobry',
#  'hennesey',
#  'digestthem',
#  'booyaow',
#  'biya',
#  'boonie',
#  'fetti',
#  'alot',
#  'breakdancing',
#  'bitchass',
#  'sixo',
#  'citaaay',
#  'bootsy',
#  'seaching',
#  'los',
#  'cowardass',
#  'hess',
#  'introchorus',
#  'audi',
#  'simping',
#  'seagel',
#  'heheheh',
#  'againagain',
#  'stayyayyayyy',
#  'everday',
#  'drivebys',
#  'apoli',
#  'noshow',
#  'kausion',
#  'beeeyatch',
#  'stayyayyyayy',
#  'ooohh',
#  'dissapear',
#  'henessey',
#  'parteners',
#  'indica',
#  'backstabbers',
#  'tutankhamuns',
#  'chardonnay',
#  'abandonded',
#  'payup',
#  'beadie',
#  'rottwillers',
#  'learedn',
#  'dissed',
#  'contestent',
#  'hehehe',
#  'imitaters',
#  'questionwhat',
#  'usta',
#  'lambsbread',
#  'treach',
#  'skandalous',
#  'shermed',
#  'tms',
#  'alazhay',
#  'doowop',
#  'owwowwwowwww',
#  'comming',
#  'camaflouge',
#  'exconvicts',
#  'circumfrence',
#  'hehehehe',
#  'rehearsin',
#  'porsche',
#  'clickilation',
#  'roct',
#  'throwed',
#  'kayninefourths',
#  'vibing',
#  'neckbone',
#  'hyprocrisy',
#  'dosia',
#  'styleoriginator',
#  'jonesing',
#  'celcius',
#  'isley',
#  'guntoter',
#  'enought',
#  'braingsll',
#  'metamorphis',
#  'kato',
#  'fifi',
#  'drapped',
#  'infact',
#  'battlecat',
#  'fakeass',
#  'errorfiles',
#  'showbiz',
#  'hoboken',
#  'dyingterrifying',
#  'fatass',
#  'yothe',
#  'jamal',
#  'coochie',
#  'heheaha',
#  'disasterous',
#  'bizzalls',
#  'clusterfuck',
#  'fuckacop',
#  'jheri',
#  'backstreets',
#  'tretch',
#  'everymotherfuckinbody',
#  'hunnid',
#  'soulja',
#  'accapella',
#  'whiskee',
#  'yeaheheh',
#  'mamoon',
#  'tito',
#  'hawalian',
#  'mics',
#  'creeped',
#  'ayoyo',
#  'jerdy',
#  'unfuckwittable',
#  'dagz',
#  'cudder',
#  'riiiiide',
#  'sunking',
#  'indicatin',
#  'parvo',
#  'comense',
#  'hoochies',
#  'benz',
#  'hahahah',
#  'conisseur',
#  'pitbull',
#  'hightech',
#  'stanton',
#  'whatchu',
#  'suckerass',
#  'westside',
#  'braincells',
#  'iwasfinsttoask',
#  'chrystal',
#  'straightseven',
#  'vaughan',
#  'alize',
#  'mishy',
#  'yeaaaaaaah',
#  'viennas',
#  'terminater',
#  'jadakiss',
#  'negroos',
#  'wurd',
#  'papapapart',
#  'ammunitions',
#  'eforty',
#  'brainscan',
#  'firstheh',
#  'beugard',
#  'mindframe',
#  'nowin',
#  'zigandzag',
#  'stressen',
#  'fuckin',
#  'gangbanging',
#  'acas',
#  'eightysix',
#  'cancun',
#  'nametags',
#  'sckrillas',
#  'heavnly',
#  'steello',
#  'sauteein',
#  'bugginand',
#  'twentyone',
#  'dramacydal',
#  'asada',
#  'mutherfuckers',
#  'caz',
#  'dimentional',
#  'chizzange',
#  'ooohooo',
#  'motherfucka',
#  'gorden',
#  'assbackwards',
#  'hatemail',
#  'luci',
#  'bodygurad',
#  'staten',
#  'doubleohseven',
#  'bustaz',
#  'jenner',
#  'pizzaint',
#  'biblicle',
#  'basshead',
#  'paladium',
#  'horton',
#  'driveby',
#  'fiveo',
#  'likeah',
#  'ahhahahah',
#  'jeapordy',
#  'niggarino',
#  'coppola',
#  'cuwop',
#  'ruuumbllle',
#  'mopreme',
#  'smokescreens',
#  'pleeeeeease',
#  'ohwe',
#  'mossberg',
#  'ogs',
#  'extremly',
#  'waaaay',
#  'oughta',
#  'reminice',
#  'latifah',
#  'hesitiation',
#  'laywers',
#  'catchphrases',
#  'schooool',
#  'outreal',
#  'killuminati',
#  'malcom',
#  'ruger',
#  'marlboros',
#  'fuckingporcupine',
#  'balmay',
#  'afterparties',
#  'crackfiend',
#  'arrrrggggh',
#  'neva',
#  'monosize',
#  'patton',
#  'letthem',
#  'fofifth',
#  'adderall',
#  'rrightrightright',
#  'ultamatum',
#  'trampass',
#  'deloris',
#  'salutedyeah',
#  'cnote',
#  'kinte',
#  'lavishist',
#  'penn',
#  'levantore',
#  'gotti',
#  'doubleop',
#  'ruffneck',
#  'dred',
#  'splifs',
#  'pizznac',
#  'murderd',
#  'merrygoround',
#  'taketaketaketake',
#  'sherm',
#  'doughless',
#  'indepth',
#  'infared',
#  'papes',
#  'sixthree',
#  'shoulda',
#  'cosby',
#  'everbody',
#  'ladidadi',
#  'zayros',
#  'swanging',
#  'benzy',
#  'rockafella',
#  'nearthem',
#  'adidas',
#  ...]

# %% [markdown]
# ## Problem: toooollll

# %%
from nltk.corpus import wordnet
import re

def remove_repeated_characters(tokens):
    repeat_pattern = re.compile(r'(\w*)(\w)\2(\w*)')
    match_substitution = r'\1\2\3'
    def replace(old_word):
        if wordnet.synsets(old_word) or old_word in alpha_vocab._dict:
            return old_word
        new_word = repeat_pattern.sub(match_substitution, old_word)
        return replace(new_word) if new_word != old_word else new_word
            
    correct_tokens = [replace(word) for word in tokens]
    return correct_tokens

repeated_removed = remove_repeated_characters(text.split(" "))
repeated_removed = " ".join( repeated_removed )

# %%
remove_repeated_characters( ["tooooolll"] )
# Out:
# ['tool']

# %%
pre.write_text("data/removed_repeated.txt", repeated_removed)

# %%
text = pre.get_text("data/ref_text3.txt")
final_vocabulary = pre.Vocabulary(text)

embedding_weights = get_glove(path, final_vocabulary._dict)

# %%
print( "number of recognized words: " + str(len(list(embedding_weights.keys())) ))
# Out:
# number of recognized words: 8088

# %%
len(final_vocabulary._dict.keys())
# Out:
# 8668

# %%
unk = []
for key in final_vocabulary._dict.keys():
    if(key not in embedding_weights):
        unk.append(key)

# %%
unk
# Out:
# ['',
#  'skanless',
#  'jackmack',
#  'sekon',
#  'yoasiatics',
#  'furier',
#  'quizzin',
#  'huxtables',
#  'ohhohohohwhoa',
#  'halfblack',
#  'raaaaaaager',
#  'heheheyah',
#  'muhfuckers',
#  'lizzane',
#  'bonebonebonebone',
#  'togination',
#  'raprelated',
#  'wyndanch',
#  'mackers',
#  'threefourths',
#  'eightynine',
#  'christenin',
#  'lexxxus',
#  'gomars',
#  'peformin',
#  'macaveli',
#  'pinkle',
#  'preoccuppied',
#  'tingaling',
#  'splifted',
#  'lowlows',
#  'nefretiti',
#  'amibitions',
#  'uhyeah',
#  'bassuntill',
#  'twentyfourseven',
#  'overthugging',
#  'fearified',
#  'gogetter',
#  'blurried',
#  "young'uns",
#  'twitterin',
#  'strugala',
#  'assasinator',
#  'bearthem',
#  'llello',
#  'papermates',
#  'plainpat',
#  'mophreme',
#  'oahhhohh',
#  'henessee',
#  'hyperchrondriac',
#  'ooohooooh',
#  'oahhhahh',
#  'wowwowwow',
#  'sleeezy',
#  'stresed',
#  'mastercrash',
#  'notthinki',
#  'giseles',
#  'oooooooooohhhh',
#  'heirem',
#  'rainbut',
#  'paragraphologist',
#  'toastses',
#  'ahahahohoh',
#  'rosecranz',
#  'melodiesunmakable',
#  'carcuses',
#  "muh'fucking",
#  'patternunecscapable',
#  'dramacy',
#  'dripdrop',
#  'hoochercoocher',
#  'ninetyy',
#  'multived',
#  'miccops',
#  'hiphoppers',
#  'thuging',
#  'dubar',
#  'killorbekilled',
#  'raiseed',
#  'beatbreaks',
#  'sixone',
#  'instutionalized',
#  'jabebecausezi',
#  'remainable',
#  'jeapordizing',
#  'weakrhymer',
#  'ninetysix',
#  'lizzight',
#  'twentyfo',
#  'scarfo',
#  'rahrah',
#  'towerin',
#  'fiveoh',
#  'mainooooo',
#  'threefiftyseven',
#  'kosugi',
#  'coastwest',
#  'minutemaid',
#  'swerl',
#  'whorider',
#  'topranked',
#  'surveyin',
#  'hardrap',
#  'sidewest',
#  'knahmean',
#  'yaknahmean',
#  'sadicious',
#  'rigarmortis',
#  'novicane',
#  'isoh',
#  'copastetic',
#  'iiiiiiiii',
#  'hoopala',
#  'hennesse',
#  'haffa',
#  'allnightlong',
#  'niggaslashrap',
#  'eskimys',
#  'twothou',
#  'xthree',
#  'flizzight',
#  'sportable',
#  'ninetytwo',
#  'nuckas',
#  'wwwrakimcom',
#  'klow',
#  'klacka',
#  'penals',
#  'fantansy',
#  'determinely',
#  'homeyg',
#  'oftb',
#  'moneymakinmachines',
#  'narratin',
#  'mentallect',
#  'mictomouth',
#  'ehhm',
#  'tearthem',
#  'smokethem',
#  'inglewatts',
#  'pachenga',
#  'inducis',
#  'plinkling',
#  'oahahhhh',
#  'heyyyayyy',
#  'temptingwhatever',
#  'microphonist',
#  'uzzie',
#  'heffing',
#  'periphereal',
#  'clarkworld',
#  'mynin',
#  'theeese',
#  'microphonethat',
#  'dooder',
#  "hand'sll",
#  'doubleedging',
#  'milleni',
#  'leavey',
#  'motherfuckersdid',
#  'papapoker',
#  'interchart',
#  'excuseamoi',
#  'heartlessass',
#  'playerhaters',
#  'buckfifty',
#  'californiaknows',
#  'muuuuzik',
#  'bluried',
#  'blurredmumbled',
#  'conveyin',
#  'brawhat',
#  'peuente',
#  'afeni',
#  'rentarapper',
#  'beitch',
#  'aightaight',
#  'cockhounds',
#  'nananananananana',
#  'mothercrookedfucking',
#  'ninetyseven',
#  'alahahalahalcohol',
#  'downest',
#  'maaaannnn',
#  'fuckboys',
#  'trickass',
#  'fantansies',
#  'zoninnnnnnnn',
#  'nonplayers',
#  'ethchasketch',
#  'ohah',
#  'tooollll',
#  'facepoke',
#  'totions',
#  'hypertone',
#  "wasn't",
#  'stetsasonic',
#  'treytrey',
#  'mescudi',
#  'extorters',
#  'tymel',
#  'eleviates',
#  'hollowtip',
#  'trefo',
#  'inflex',
#  'suffocator',
#  'limbwalk',
#  'swolls',
#  'kday',
#  'blackstreets',
#  'sumping',
#  'penaltyand',
#  'murdererbefore',
#  'cliquot',
#  'elel',
#  'ladadadah',
#  '2fifth',
#  'courpse',
#  'interveen',
#  'conceils',
#  'skypage',
#  'toginations',
#  'rickashay',
#  'scoliosisskulliosis',
#  "'rari",
#  'yanamean',
#  'pauletta',
#  'battleowow',
#  "fo'fo'",
#  'penetentiaries',
#  'optimos',
#  'tarvue',
#  'oooooooohooooooooh',
#  'prprpretty',
#  'funkdified',
#  'topling',
#  'todosomethinass',
#  'sestruct',
#  'baaaaaaaaby',
#  'hooptee',
#  'jailhouses',
#  'ovius',
#  'realeast',
#  'bombass',
#  'rigormortis',
#  'rangea',
#  'dinayros',
#  'hennesee',
#  'centpac',
#  'tugawar',
#  'doomstick',
#  'immortalz',
#  'yeaaaaaaaah',
#  'pandemical',
#  'batteram',
#  'heavyheavyheavy',
#  'fuckniggaz',
#  'poonannynans',
#  'adolecsent',
#  'togine',
#  'heneesee',
#  'fortyfour',
#  'editorforever',
#  'wanksters',
#  'ninetythree',
#  'doublei',
#  'gunslang',
#  'straightass',
#  'buntry',
#  'walkby',
#  'rottwilers',
#  'needbeen',
#  'lastlast',
#  'adrendaline',
#  'twodollar',
#  'ariadiarrhea',
#  'skeezing',
#  'topicless',
#  'foolies',
#  'oneeightyfive',
#  'megathesis',
#  "mc'sll",
#  'blegit',
#  'stonefacing',
#  'mumar',
#  'magellen',
#  'bangathon',
#  'knowhati',
#  'dopefiend',
#  'ticktocking',
#  'hehahahahaha',
#  'cudders',
#  'doubleups',
#  'mackaveli',
#  'fivedoubleoh',
#  "o'jays",
#  'sixeight',
#  'comparethem',
#  'reminsce',
#  'gogetters',
#  'crookedass',
#  'lovetraps',
#  'trifeass',
#  'comatoses',
#  'askses',
#  'sticthes',
#  'twentysomeodd',
#  'yeauhh',
#  'nanananananana',
#  'rrrrright',
#  'stayinliner',
#  'tonguekissing',
#  'nobry',
#  'digestthem',
#  'booyaow',
#  'sixo',
#  'citaaay',
#  'cowardass',
#  'introchorus',
#  'simping',
#  'seagel',
#  'againagain',
#  'stayyayyayyy',
#  'apoli',
#  'kausion',
#  'beeeyatch',
#  'stayyayyyayy',
#  'henessey',
#  'tutankhamuns',
#  'beadie',
#  'rottwillers',
#  'learedn',
#  'imitaters',
#  'questionwhat',
#  'lambsbread',
#  'skandalous',
#  'shermed',
#  'alazhay',
#  'owwowwwowwww',
#  'camaflouge',
#  'exconvicts',
#  'rehearsin',
#  'clickilation',
#  'roct',
#  'kayninefourths',
#  'dosia',
#  'unevil',
#  'styleoriginator',
#  'guntoter',
#  'braingsll',
#  'errorfiles',
#  'dyingterrifying',
#  'yothe',
#  'heheaha',
#  'bizzalls',
#  'jimminy',
#  'fuckacop',
#  'tretch',
#  'everymotherfuckinbody',
#  'whiskee',
#  'yeaheheh',
#  'mamoon',
#  'stolider',
#  'hawalian',
#  'ayoyo',
#  'jerdy',
#  'unfuckwittable',
#  'dagz',
#  'riiiiide',
#  'sunking',
#  'indicatin',
#  'comense',
#  'conisseur',
#  'suckerass',
#  'iwasfinsttoask',
#  'straightseven',
#  'viennas',
#  'negroos',
#  'papapapart',
#  'eforty',
#  'firstheh',
#  'beugard',
#  'zigandzag',
#  'stressen',
#  'eightysix',
#  'sckrillas',
#  'heavnly',
#  'steello',
#  'sauteein',
#  'bugginand',
#  'dramacydal',
#  'chizzange',
#  'ooohooo',
#  'bodygurad',
#  'doubleohseven',
#  'bustaz',
#  'pizzaint',
#  'biblicle',
#  'inchant',
#  'fiveo',
#  'likeah',
#  'niggarino',
#  'cuwop',
#  'ruuumbllle',
#  'mopreme',
#  'ohwe',
#  'hesitiation',
#  'outreal',
#  'fuckingporcupine',
#  'balmay',
#  'crackfiend',
#  'arrrrggggh',
#  'monosize',
#  'knowledging',
#  'letthem',
#  'fofifth',
#  'rrightrightright',
#  'ultamatum',
#  'trampass',
#  'deloris',
#  'salutedyeah',
#  'cnote',
#  'lavishist',
#  'levantore',
#  'doubleop',
#  'splifs',
#  'pizznac',
#  'taketaketaketake',
#  'sixthree',
#  'ladidadi',
#  'zayros',
#  'benzy',
#  'nearthem',
#  'calisthetics',
#  'overdemanding',
#  'ohhahhh',
#  'restitchin',
#  'hilfigers',
#  'fournickel',
#  'lelelet',
#  'khomani',
#  'ditnirt',
#  'taketake',
#  'lyricst',
#  'ungggh',
#  'sixtysix',
#  'yousea',
#  'oneletter',
#  'brainstormin',
#  'jiveass',
#  'explizzit',
#  'icegrill',
#  'battlezones',
#  'dopefiends',
#  'magnatize',
#  'furified',
#  'crima',
#  'hehehahaha',
#  'midnught',
#  'navalet',
#  'faaaaaaace',
#  'nimth',
#  'youoohoohohh',
#  'prophalaks',
#  'withchu',
#  'westsiiiiiide',
#  'haterskeep',
#  'poohbutts',
#  'setchu',
#  'yaknahmsayin',
#  'benzito',
#  'rhymefumble',
#  'cudois',
#  'sixfigure',
#  'mutulu',
#  'hardings',
#  'pollitic',
#  'heywhoaaaaaa',
#  'crimedanch',
#  'delightah',
#  'baldinass',
#  'togined',
#  'eazye',
#  'neccesarry',
#  'risci',
#  'alazay',
#  'zigga',
#  'spectactale',
#  'poohbutt',
#  'selfexplanatory',
#  'raahaaaah',
#  'tupacalypse',
#  'consoloist',
#  'openheart',
#  'kusher',
#  'ziggaziggas',
#  'sixfo',
#  'hardcorereal',
#  'macadoshis',
#  'ohwhoawhoawhoa',
#  'wessons',
#  'fourfive',
#  'triggar',
#  'skypager',
#  'bobobee',
#  'coochiecoo',
#  'illtrip',
#  'dirtyass',
#  'threefiftysevens',
#  'offtherack',
#  'gimminy',
#  'magnatized',
#  'benificent',
#  'utilalize',
#  'aplogizies',
#  'motherrun',
#  'killthem',
#  'themthere',
#  '\n',
#  'wearthem',
#  'wildass',
#  'ninenickel',
#  'corrolate',
#  'methical',
#  'lopole',
#  'domepiece',
#  'schoolis',
#  'krsone',
#  'thuuug',
#  'indispute',
#  'zakia',
#  'baybayyyy',
#  'intellectionist',
#  'clizzoud',
#  'paragraphical',
#  'lowlow',
#  'papapapoker',
#  'culturized',
#  'sanderford',
#  'oneeightseven',
#  'xannies',
#  'quitraple',
#  'jealousass',
#  'scheaming',
#  'whoosah',
#  'naploleon',
#  'tonguetied',
#  'lewinski',
#  'terrordome',
#  'borhters',
#  'reanamator',
#  'elpee',
#  'katruple',
#  'cardiacs',
#  'henni',
#  'clentin',
#  'yamming',
#  'ninehundred',
#  'hypetip',
#  'slizow',
#  "deadmc'ing",
#  'doggfather',
#  'usabi',
#  'liebury',
#  'motionfrozen',
#  'heyyyeah',
#  'ageiathic',
#  'rushtown',
#  'aliviate',
#  'multimillionare',
#  'mardygraud',
#  'penmate',
#  'thuged',
#  'mantronix',
#  'mealticket',
#  'heyyyyyummmmmm',
#  'dshot']

# %%
import tools.spell_correction as spell

recorrected = spell.recorrect_text(" ".join(unk), words_alpha)

# %%
comparison = zip (recorrected.split(" "), unk)
for after,before in comparison:
    print(before + " \t " + after)
# Out:
#  	 o
# skanless 	 skinless
# jackmack 	 hackmack
# sekon 	 seton
# yoasiatics 	 yoasiatics
# furier 	 furies
# quizzin 	 quizzing
# huxtables 	 hurtable
# ohhohohohwhoa 	 ohhohohohwhoa
# halfblack 	 halfback
# raaaaaaager 	 raaaaaaager
# heheheyah 	 heheheyah
# muhfuckers 	 muhfuckers
# lizzane 	 lizzie
# bonebonebonebone 	 bonebonebonebone
# togination 	 domination
# raprelated 	 raprelated
# wyndanch 	 wyndanch
# mackers 	 backers
# threefourths 	 threefourths
# eightynine 	 eightynine
# christenin 	 christening
# lexxxus 	 lexxxus
# gomars 	 gomart
# peformin 	 formin
# macaveli 	 maravedi
# pinkle 	 pickle
# preoccuppied 	 preoccupied
# tingaling 	 tingling
# splifted 	 splinted
# lowlows 	 wowwows
# nefretiti 	 nefretiti
# amibitions 	 ambitions
# uhyeah 	 whydah
# bassuntill 	 bassuntill
# twentyfourseven 	 twentyfourseven
# overthugging 	 overthugging
# fearified 	 metrified
# gogetter 	 forgetter
# blurried 	 blurred
# young'uns 	 youngun
# twitterin 	 twittering
# strugala 	 strigal
# assasinator 	 assassinator
# bearthem 	 berther
# llello 	 hello
# papermates 	 papermaker
# plainpat 	 plainest
# mophreme 	 morpheme
# oahhhohh 	 oahhhohh
# henessee 	 tennessee
# hyperchrondriac 	 hyperchrondriac
# ooohooooh 	 ooohooooh
# oahhhahh 	 oahhhahh
# wowwowwow 	 wowwowwow
# sleeezy 	 sleezy
# stresed 	 stressed
# mastercrash 	 mastercrash
# notthinki 	 notthinki
# giseles 	 cisele
# oooooooooohhhh 	 oooooooooohhhh
# heirem 	 herem
# rainbut 	 rainout
# paragraphologist 	 paragraphologist
# toastses 	 toaster
# ahahahohoh 	 ahahahohoh
# rosecranz 	 rosecranz
# melodiesunmakable 	 melodiesunmakable
# carcuses 	 arcuses
# muh'fucking 	 muh'fucking
# patternunecscapable 	 patternunecscapable
# dramacy 	 drammach
# dripdrop 	 dripdrop
# hoochercoocher 	 hoochercoocher
# ninetyy 	 ninety
# multived 	 multiped
# miccops 	 micros
# hiphoppers 	 hiphoppers
# thuging 	 thugging
# dubar 	 tubar
# killorbekilled 	 killorbekilled
# raiseed 	 raised
# beatbreaks 	 heartbreaks
# sixone 	 sissone
# instutionalized 	 institutionalized
# jabebecausezi 	 jabebecausezi
# remainable 	 regainable
# jeapordizing 	 jeopardizing
# weakrhymer 	 weakrhymer
# ninetysix 	 ninetyish
# lizzight 	 lizzight
# twentyfo 	 twentymo
# scarfo 	 scarfy
# rahrah 	 rayah
# towerin 	 towering
# fiveoh 	 five
# mainooooo 	 mainooooo
# threefiftyseven 	 threefiftyseven
# kosugi 	 sugi
# coastwest 	 coastwise
# minutemaid 	 minuteman
# swerl 	 sweal
# whorider 	 wordier
# topranked 	 unpranked
# surveyin 	 surveying
# hardrap 	 eardrop
# sidewest 	 midwest
# knahmean 	 knahmean
# yaknahmean 	 yaknahmean
# sadicious 	 judicious
# rigarmortis 	 rigarmortis
# novicane 	 novice
# isoh 	 ish
# copastetic 	 copasetic
# iiiiiiiii 	 iiiiiiiii
# hoopala 	 hoopla
# hennesse 	 hennes
# haffa 	 affa
# allnightlong 	 allnightlong
# niggaslashrap 	 niggaslashrap
# eskimys 	 eskimos
# twothou 	 twothou
# xthree 	 three
# flizzight 	 flizzight
# sportable 	 sportable
# ninetytwo 	 ninetytwo
# nuckas 	 nuchal
# wwwrakimcom 	 wwwrakimcom
# klow 	 klom
# klacka 	 blacky
# penals 	 penal
# fantansy 	 fantasy
# determinely 	 determinedly
# homeyg 	 homey
# oftb 	 oft
# moneymakinmachines 	 moneymakinmachines
# narratin 	 narrating
# mentallect 	 mentallect
# mictomouth 	 mictomouth
# ehhm 	 elem
# tearthem 	 tearthumb
# smokethem 	 smokethem
# inglewatts 	 inglewatts
# pachenga 	 pachanga
# inducis 	 induces
# plinkling 	 plinking
# oahahhhh 	 oahahhhh
# heyyyayyy 	 heyyyayyy
# temptingwhatever 	 temptingwhatever
# microphonist 	 microphonism
# uzzie 	 cunzie
# heffing 	 hefting
# periphereal 	 peripheral
# clarkworld 	 clarkworld
# mynin 	 bynin
# theeese 	 therese
# microphonethat 	 microphonethat
# dooder 	 doodler
# hand'sll 	 handsel
# doubleedging 	 doubleedging
# milleni 	 millenia
# leavey 	 peavey
# motherfuckersdid 	 motherfuckersdid
# papapoker 	 papapoker
# interchart 	 interchaff
# excuseamoi 	 excuseamoi
# heartlessass 	 heartlessness
# playerhaters 	 playerhaters
# buckfifty 	 buckfifty
# californiaknows 	 californiaknows
# muuuuzik 	 muuuuzik
# bluried 	 blurred
# blurredmumbled 	 blurredmumbled
# conveyin 	 conveying
# brawhat 	 brachet
# peuente 	 peenge
# afeni 	 afenil
# rentarapper 	 entrapper
# beitch 	 bewitch
# aightaight 	 lighttight
# cockhounds 	 coonhounds
# nananananananana 	 nananananananana
# mothercrookedfucking 	 mothercrookedfucking
# ninetyseven 	 ninetyseven
# alahahalahalcohol 	 alahahalahalcohol
# downest 	 downset
# maaaannnn 	 maaaannnn
# fuckboys 	 fuckboys
# trickass 	 tricks
# fantansies 	 fantasies
# zoninnnnnnnn 	 zoninnnnnnnn
# nonplayers 	 nonpayer
# ethchasketch 	 ethchasketch
# ohah 	 shah
# tooollll 	 tooollll
# facepoke 	 facepoke
# totions 	 lotions
# hypertone 	 hypercone
# wasn't 	 wasnt
# stetsasonic 	 stetsasonic
# treytrey 	 treitre
# mescudi 	 musculi
# extorters 	 extorters
# tymel 	 gymel
# eleviates 	 eluviates
# hollowtip 	 hollowtip
# trefo 	 tref
# inflex 	 inflex
# suffocator 	 suffocate
# limbwalk 	 limbal
# swolls 	 swills
# kday 	 aday
# blackstreets 	 backstreet
# sumping 	 summing
# penaltyand 	 penaltyand
# murdererbefore 	 murdererbefore
# cliquot 	 aliquot
# elel 	 eel
# ladadadah 	 ladadadah
# 2fifth 	 fifth
# courpse 	 course
# interveen 	 intervein
# conceils 	 conceits
# skypage 	 kipage
# toginations 	 cogitations
# rickashay 	 rickshaw
# scoliosisskulliosis 	 scoliosisskulliosis
# 'rari 	 urari
# yanamean 	 panaman
# pauletta 	 epaulette
# battleowow 	 battleowow
# fo'fo' 	 fo'fo'
# penetentiaries 	 penitentiaries
# optimos 	 optimes
# tarvue 	 tarve
# oooooooohooooooooh 	 oooooooohooooooooh
# prprpretty 	 prprpretty
# funkdified 	 unedified
# topling 	 toppling
# todosomethinass 	 todosomethinass
# sestruct 	 destruct
# baaaaaaaaby 	 baaaaaaaaby
# hooptee 	 adoptee
# jailhouses 	 jailhouses
# ovius 	 ovis
# realeast 	 realest
# bombass 	 bumbass
# rigormortis 	 rigormortis
# rangea 	 ranges
# dinayros 	 dineros
# hennesee 	 tennessee
# centpac 	 cental
# tugawar 	 turwar
# doomstick 	 hoopstick
# immortalz 	 immortals
# yeaaaaaaaah 	 yeaaaaaaaah
# pandemical 	 pandemic
# batteram 	 bartram
# heavyheavyheavy 	 heavyheavyheavy
# fuckniggaz 	 fuckniggaz
# poonannynans 	 poonannynans
# adolecsent 	 adolescent
# togine 	 toxine
# heneesee 	 genesee
# fortyfour 	 fortyfold
# editorforever 	 editorforever
# wanksters 	 ganisters
# ninetythree 	 ninetythree
# doublei 	 double
# gunslang 	 gunsling
# straightass 	 straightens
# buntry 	 bunty
# walkby 	 walkie
# rottwilers 	 rottweiler
# needbeen 	 peebeen
# lastlast 	 laglast
# adrendaline 	 adrenaline
# twodollar 	 twodollar
# ariadiarrhea 	 ariadiarrhea
# skeezing 	 sneezing
# topicless 	 tunicless
# foolies 	 follies
# oneeightyfive 	 oneeightyfive
# megathesis 	 metathesis
# mc'sll 	 mc'sll
# blegit 	 legit
# stonefacing 	 stonelaying
# mumar 	 mymar
# magellen 	 magellan
# bangathon 	 bangathon
# knowhati 	 kowhai
# dopefiend 	 dopefiend
# ticktocking 	 ticktocking
# hehahahahaha 	 hehahahahaha
# cudders 	 udders
# doubleups 	 doublets
# mackaveli 	 mackaveli
# fivedoubleoh 	 fivedoubleoh
# o'jays 	 ofays
# sixeight 	 sleight
# comparethem 	 comparethem
# reminsce 	 reminisce
# gogetters 	 begetters
# crookedass 	 crookedness
# lovetraps 	 livetraps
# trifeass 	 trifeass
# comatoses 	 comatose
# askses 	 asses
# sticthes 	 stitches
# twentysomeodd 	 twentysomeodd
# yeauhh 	 yearth
# nanananananana 	 nanananananana
# rrrrright 	 rrrrright
# stayinliner 	 stayinliner
# tonguekissing 	 tonguekissing
# nobry 	 norry
# digestthem 	 digestthem
# booyaow 	 booyaow
# sixo 	 cixo
# citaaay 	 cutaway
# cowardass 	 cowardish
# introchorus 	 introchorus
# simping 	 siping
# seagel 	 peage
# againagain 	 againagain
# stayyayyayyy 	 stayyayyayyy
# apoli 	 aoli
# kausion 	 nasion
# beeeyatch 	 beeeyatch
# stayyayyyayy 	 stayyayyyayy
# henessey 	 henessey
# tutankhamuns 	 tutankhamen
# beadie 	 beadle
# rottwillers 	 rottwillers
# learedn 	 leafed
# imitaters 	 imitators
# questionwhat 	 questionwhat
# lambsbread 	 lambsbread
# skandalous 	 scandalous
# shermed 	 sharped
# alazhay 	 alachah
# owwowwwowwww 	 owwowwwowwww
# camaflouge 	 camaflouge
# exconvicts 	 convicts
# rehearsin 	 rehearsing
# clickilation 	 clickilation
# roct 	 rot
# kayninefourths 	 kayninefourths
# dosia 	 doria
# unevil 	 unevil
# styleoriginator 	 styleoriginator
# guntoter 	 gunpower
# braingsll 	 bringall
# errorfiles 	 errorfiles
# dyingterrifying 	 dyingterrifying
# yothe 	 yote
# heheaha 	 heheaha
# bizzalls 	 bizzalls
# jimminy 	 jimminy
# fuckacop 	 fuckacop
# tretch 	 wretch
# everymotherfuckinbody 	 everymotherfuckinbody
# whiskee 	 whisked
# yeaheheh 	 yeaheheh
# mamoon 	 mammon
# stolider 	 stolider
# hawalian 	 hawaiian
# ayoyo 	 yoyo
# jerdy 	 jerry
# unfuckwittable 	 unfuckwittable
# dagz 	 dags
# riiiiide 	 riiiiide
# sunking 	 subking
# indicatin 	 indicating
# comense 	 compense
# conisseur 	 connaisseur
# suckerass 	 suckers
# iwasfinsttoask 	 iwasfinsttoask
# straightseven 	 straightseven
# viennas 	 vienna
# negroos 	 negros
# papapapart 	 papapapart
# eforty 	 forty
# firstheh 	 firster
# beugard 	 belgard
# zigandzag 	 zigandzag
# stressen 	 stresses
# eightysix 	 eightysix
# sckrillas 	 scillas
# heavnly 	 heavily
# steello 	 steelie
# sauteein 	 hautein
# bugginand 	 bugginand
# dramacydal 	 dramacydal
# chizzange 	 chizzange
# ooohooo 	 boohoo
# bodygurad 	 bodyguard
# doubleohseven 	 doubleohseven
# bustaz 	 bustic
# pizzaint 	 pizaine
# biblicle 	 biblical
# inchant 	 inchant
# fiveo 	 five
# likeah 	 likes
# niggarino 	 niggarding
# cuwop 	 cwo
# ruuumbllle 	 ruuumbllle
# mopreme 	 supreme
# ohwe 	 howe
# hesitiation 	 hesitation
# outreal 	 outread
# fuckingporcupine 	 fuckingporcupine
# balmay 	 balmy
# crackfiend 	 crackfiend
# arrrrggggh 	 arrrrggggh
# monosize 	 monodize
# knowledging 	 knowledging
# letthem 	 letches
# fofifth 	 fifth
# rrightrightright 	 rrightrightright
# ultamatum 	 ultimatum
# trampass 	 trampess
# deloris 	 dehors
# salutedyeah 	 salutedyeah
# cnote 	 cenote
# lavishist 	 lavishest
# levantore 	 levantine
# doubleop 	 double
# splifs 	 splits
# pizznac 	 pizza
# taketaketaketake 	 taketaketaketake
# sixthree 	 sixthet
# ladidadi 	 ladidadi
# zayros 	 zeros
# benzy 	 bendy
# nearthem 	 narthex
# calisthetics 	 calisthenics
# overdemanding 	 overdemandingly
# ohhahhh 	 ohhahhh
# restitchin 	 restitch
# hilfigers 	 hilfigers
# fournickel 	 fournickel
# lelelet 	 linelet
# khomani 	 khokani
# ditnirt 	 ditnirt
# taketake 	 caretake
# lyricst 	 lyrics
# ungggh 	 ungag
# sixtysix 	 sixtysix
# yousea 	 youse
# oneletter 	 beletter
# brainstormin 	 brainstorming
# jiveass 	 jiveass
# explizzit 	 explicit
# icegrill 	 icegrill
# battlezones 	 rattlebones
# dopefiends 	 dopefiends
# magnatize 	 magnetize
# furified 	 aurified
# crima 	 rima
# hehehahaha 	 hehehahaha
# midnught 	 midnight
# navalet 	 naval
# faaaaaaace 	 faaaaaaace
# nimth 	 ninth
# youoohoohohh 	 youoohoohohh
# prophalaks 	 prophalaks
# withchu 	 witchy
# westsiiiiiide 	 westsiiiiiide
# haterskeep 	 haterskeep
# poohbutts 	 poohbutts
# setchu 	 sitch
# yaknahmsayin 	 yaknahmsayin
# benzito 	 benzo
# rhymefumble 	 rhymefumble
# cudois 	 cados
# sixfigure 	 subfigure
# mutulu 	 mutule
# hardings 	 cardings
# pollitic 	 poplitic
# heywhoaaaaaa 	 heywhoaaaaaa
# crimedanch 	 crimedanch
# delightah 	 delighter
# baldinass 	 bandiness
# togined 	 opined
# eazye 	 dazy
# neccesarry 	 neccesarry
# risci 	 disci
# alazay 	 alala
# zigga 	 ziega
# spectactale 	 spectacle
# poohbutt 	 poohbutt
# selfexplanatory 	 selfexplanatory
# raahaaaah 	 raahaaaah
# tupacalypse 	 tupacalypse
# consoloist 	 consoloist
# openheart 	 enheart
# kusher 	 kosher
# ziggaziggas 	 ziggaziggas
# sixfo 	 sixmo
# hardcorereal 	 hardcorereal
# macadoshis 	 macadoshis
# ohwhoawhoawhoa 	 ohwhoawhoawhoa
# wessons 	 weasons
# fourfive 	 forcive
# triggar 	 trigger
# skypager 	 skypager
# bobobee 	 bobotee
# coochiecoo 	 coochiecoo
# illtrip 	 illyric
# dirtyass 	 dirtyass
# threefiftysevens 	 threefiftysevens
# offtherack 	 offtrack
# gimminy 	 jimminy
# magnatized 	 magnetized
# benificent 	 beneficent
# utilalize 	 utilize
# aplogizies 	 apologizes
# motherrun 	 motherkin
# killthem 	 killthem
# themthere 	 themthere
#
#  	 ;
# wearthem 	 werther
# wildass 	 windlass
# ninenickel 	 ninenickel
# corrolate 	 correlate
# methical 	 metrical
# lopole 	 hopple
# domepiece 	 forepiece
# schoolis 	 schools
# krsone 	 ursone
# thuuug 	 thug
# indispute 	 indisputed
# zakia 	 akia
# baybayyyy 	 baybayyyy
# intellectionist 	 intellectionist
# clizzoud 	 clizzoud
# paragraphical 	 paragraphical
# lowlow 	 jowlop
# papapapoker 	 papapapoker
# culturized 	 culturize
# sanderford 	 sanderford
# oneeightseven 	 oneeightseven
# xannies 	 nannies
# quitraple 	 quittable
# jealousass 	 jealousness
# scheaming 	 screaming
# whoosah 	 whoosh
# naploleon 	 napoleon
# tonguetied 	 tonguebird
# lewinski 	 lewinski
# terrordome 	 terrorsome
# borhters 	 brothers
# reanamator 	 reanamator
# elpee 	 epee
# katruple 	 katruple
# cardiacs 	 cardiacs
# henni 	 benni
# clentin 	 cleating
# yamming 	 jamming
# ninehundred 	 ninehundred
# hypetip 	 hyperin
# slizow 	 seizor
# deadmc'ing 	 deadmc'ing
# doggfather 	 doggfather
# usabi 	 tsadi
# liebury 	 bigbury
# motionfrozen 	 motionfrozen
# heyyyeah 	 heyyyeah
# ageiathic 	 agnathic
# rushtown 	 pushdown
# aliviate 	 eluviate
# multimillionare 	 multimillionaire
# mardygraud 	 mardygraud
# penmate 	 pewmate
# thuged 	 thugged
# mantronix 	 mantronix
# mealticket 	 mealticket
# heyyyyyummmmmm 	 heyyyyyummmmmm
# dshot 	 ashot

# %%
corrected_weights = get_glove(path, recorrected.split(" "))

# %%
(corrected_weights.keys())
# Out:
# dict_keys(['opined', 'sharped', 'reminisce', 'furies', 'asses', 'howe', 'thugging', 'spectacle', 'sleezy', 'copasetic', 'youngun', 'magnetize', 'hesitation', 'hawaiian', 'metrical', 'cleating', 'balmy', 'toppling', 'forty', 'assassinator', 'dazy', 'adrenaline', 'whisked', 'swills', 'nannies', 'yoyo', 'ninety', 'toaster', 'rot', 'midnight', 'beneficent', 'downset', 'negros', 'suckers', 'quizzing', 'preoccupied', 'formin', 'heartbreaks', 'penitentiaries', 'morpheme', 'subfigure', 'doodler', 'napoleon', 'ashot', 'cogitations', 'dineros', 'alala', 'eel', 'five', 'conveying', 'course', 'pachanga', 'imitators', 'supreme', 'realest', 'firster', 'splinted', 'brainstorming', 'backers', 'therese', 'trigger', 'nuchal', 'bewitch', 'leafed', 'sitch', 'biblical', 'explicit', 'elem', 'mammon', 'lyrics', 'disci', 'aliquot', 'offtrack', 'christening', 'lotions', 'coonhounds', 'tingling', ';', 'multimillionaire', 'ranges', 'jeopardizing', 'rickshaw', 'akia', 'cwo', 'udders', 'blurred', 'stresses', 'three', 'novice', 'suffocate', 'rayah', 'seton', 'pickle', 'homey', 'walkie', 'rima', 'conceits', 'hennes', 'ninth', 'vienna', 'affa', 'screaming', 'minuteman', 'peavey', 'aoli', 'micros', 'coastwise', 'peripheral', 'bendy', 'splits', 'youse', 'summing', 'jealousness', 'thugged', 'ovis', 'eskimos', 'determinedly', 'werther', 'tennessee', 'magellan', 'plainest', 'forgetter', 'blacky', 'penal', 'judicious', 'backstreet', 'doublets', 'connaisseur', 'eardrop', 'sneezing', 'narthex', 'steelie', 'surveying', 'lizzie', 'towering', 'stressed', 'halfback', 'epaulette', 'midwest', 'benni', 'dags', 'hefting', 'cutaway', 'bodyguard', 'caretake', 'genesee', 'zeros', 'levantine', 'yote', 'siping', 'narrating', 'likes', 'ambitions', 'rottweiler', 'fantasies', 'ish', 'comatose', 'whoosh', 'nasion', 'stitches', 'sleight', 'kosher', 'crookedness', 'gunpower', 'bunty', 'bartram', 'immortals', 'millenia', 'double', 'restitch', 'benzo', 'schools', 'tutankhamen', 'induces', 'oft', 'skinless', 'utilize', 'o', 'follies', 'heartlessness', 'destruct', 'pandemic', 'dehors', 'hello', 'rainout', 'wretch', 'boohoo', 'cenote', 'limbal', 'kowhai', 'thug', 'legit', 'brothers', 'hoopla', 'correlate', 'domination', 'tricks', 'windlass', 'jamming', 'pushdown', 'doria', 'beadle', 'cental', 'apologizes', 'scandalous', 'metathesis', 'plinking', 'wordier', 'rehearsing', 'indicating', 'papermaker', 'shah', 'straightens', 'ultimatum', 'sugi', 'convicts', 'adoptee', 'magnetized', 'wasnt', 'aday', 'twittering', 'fantasy', 'raised', 'pizza', 'fifth', 'herem', 'epee', 'witchy', 'naval', 'tref', 'jerry', 'institutionalized', 'heavily', 'calisthenics', 'adolescent'])

# %%
len(corrected_weights)
# Out:
# 235

# %%
unk = []
for key in recorrected.split(" "):
    if(key not in corrected_weights):
        unk.append(key)

# %%
repeated_removed = remove_repeated_characters(unk)
comparison = zip (repeated_removed, unk)
for after,before in comparison:
    print(before + " \t " + after)
# Out:
# hackmack 	 hackmack
# yoasiatics 	 yoasiatics
# hurtable 	 hurtable
# ohhohohohwhoa 	 ohohohohwhoa
# raaaaaaager 	 rager
# heheheyah 	 heheheyah
# muhfuckers 	 muhfuckers
# bonebonebonebone 	 bonebonebonebone
# raprelated 	 raprelated
# wyndanch 	 wyndanch
# threefourths 	 threfourths
# eightynine 	 eightynine
# lexxxus 	 lexus
# gomart 	 gomart
# maravedi 	 maravedi
# wowwows 	 wowwows
# nefretiti 	 nefretiti
# whydah 	 whydah
# bassuntill 	 basuntil
# twentyfourseven 	 twentyfourseven
# overthugging 	 overthuging
# metrified 	 metrified
# strigal 	 strigal
# berther 	 berther
# oahhhohh 	 oahoh
# hyperchrondriac 	 hyperchrondriac
# ooohooooh 	 ohoh
# oahhhahh 	 oahah
# wowwowwow 	 wowowow
# mastercrash 	 mastercrash
# notthinki 	 nothinki
# cisele 	 cisele
# oooooooooohhhh 	 ooh
# paragraphologist 	 paragraphologist
# ahahahohoh 	 ahahahohoh
# rosecranz 	 rosecranz
# melodiesunmakable 	 melodiesunmakable
# arcuses 	 arcuses
# muh'fucking 	 muh'fucking
# patternunecscapable 	 paternunecscapable
# drammach 	 drammach
# dripdrop 	 dripdrop
# hoochercoocher 	 hochercocher
# multiped 	 multiped
# hiphoppers 	 hiphopers
# tubar 	 tubar
# killorbekilled 	 kilorbekiled
# sissone 	 sissone
# jabebecausezi 	 jabebecausezi
# regainable 	 regainable
# weakrhymer 	 weakrhymer
# ninetyish 	 ninetyish
# lizzight 	 lizight
# twentymo 	 twentymo
# scarfy 	 scarfy
# mainooooo 	 maino
# threefiftyseven 	 threfiftyseven
# sweal 	 sweal
# unpranked 	 unpranked
# knahmean 	 knahmean
# yaknahmean 	 yaknahmean
# rigarmortis 	 rigarmortis
# iiiiiiiii 	 iii
# allnightlong 	 alnightlong
# niggaslashrap 	 nigaslashrap
# twothou 	 twothou
# flizzight 	 flizight
# sportable 	 sportable
# ninetytwo 	 ninetytwo
# wwwrakimcom 	 wrakimcom
# klom 	 klom
# moneymakinmachines 	 moneymakinmachines
# mentallect 	 mentalect
# mictomouth 	 mictomouth
# tearthumb 	 tearthumb
# smokethem 	 smokethem
# inglewatts 	 inglewats
# oahahhhh 	 oahah
# heyyyayyy 	 heyay
# temptingwhatever 	 temptingwhatever
# microphonism 	 microphonism
# cunzie 	 cunzie
# clarkworld 	 clarkworld
# bynin 	 bynin
# microphonethat 	 microphonethat
# handsel 	 handsel
# doubleedging 	 doubledging
# motherfuckersdid 	 motherfuckersdid
# papapoker 	 papapoker
# interchaff 	 interchaff
# excuseamoi 	 excuseamoi
# playerhaters 	 playerhaters
# buckfifty 	 buckfifty
# californiaknows 	 californiaknows
# muuuuzik 	 muzik
# blurredmumbled 	 bluredmumbled
# brachet 	 brachet
# peenge 	 peenge
# afenil 	 afenil
# entrapper 	 entrapper
# lighttight 	 lighttight
# nananananananana 	 nananananananana
# mothercrookedfucking 	 mothercrokedfucking
# ninetyseven 	 ninetyseven
# alahahalahalcohol 	 alahahalahalcohol
# maaaannnn 	 man
# fuckboys 	 fuckboys
# zoninnnnnnnn 	 zonin
# nonpayer 	 nonpayer
# ethchasketch 	 ethchasketch
# tooollll 	 tool
# facepoke 	 facepoke
# hypercone 	 hypercone
# stetsasonic 	 stetsasonic
# treitre 	 treitre
# musculi 	 musculi
# extorters 	 extorters
# gymel 	 gymel
# eluviates 	 eluviates
# hollowtip 	 holowtip
# inflex 	 inflex
# penaltyand 	 penaltyand
# murdererbefore 	 murdererbefore
# ladadadah 	 ladadadah
# intervein 	 intervein
# kipage 	 kipage
# scoliosisskulliosis 	 scoliosiskuliosis
# urari 	 urari
# panaman 	 panaman
# battleowow 	 batleowow
# fo'fo' 	 fo'fo'
# optimes 	 optimes
# tarve 	 tarve
# oooooooohooooooooh 	 ohoh
# prprpretty 	 prprprety
# unedified 	 unedified
# todosomethinass 	 todosomethinas
# baaaaaaaaby 	 baby
# jailhouses 	 jailhouses
# bumbass 	 bumbass
# rigormortis 	 rigormortis
# turwar 	 turwar
# hoopstick 	 hoopstick
# yeaaaaaaaah 	 yeah
# heavyheavyheavy 	 heavyheavyheavy
# fuckniggaz 	 fucknigaz
# poonannynans 	 ponanynans
# toxine 	 toxine
# fortyfold 	 fortyfold
# editorforever 	 editorforever
# ganisters 	 ganisters
# ninetythree 	 ninetythre
# gunsling 	 gunsling
# peebeen 	 peebeen
# laglast 	 laglast
# twodollar 	 twodolar
# ariadiarrhea 	 ariadiarhea
# tunicless 	 tunicless
# oneeightyfive 	 oneightyfive
# mc'sll 	 mc'sl
# stonelaying 	 stonelaying
# mymar 	 mymar
# bangathon 	 bangathon
# dopefiend 	 dopefiend
# ticktocking 	 ticktocking
# hehahahahaha 	 hehahahahaha
# mackaveli 	 mackaveli
# fivedoubleoh 	 fivedoubleoh
# ofays 	 ofays
# comparethem 	 comparethem
# begetters 	 begetters
# livetraps 	 livetraps
# trifeass 	 trifeas
# twentysomeodd 	 twentysomeod
# yearth 	 yearth
# nanananananana 	 nanananananana
# rrrrright 	 right
# stayinliner 	 stayinliner
# tonguekissing 	 tonguekising
# norry 	 norry
# digestthem 	 digesthem
# booyaow 	 boyaow
# cixo 	 cixo
# cowardish 	 cowardish
# introchorus 	 introchorus
# peage 	 peage
# againagain 	 againagain
# stayyayyayyy 	 stayayay
# beeeyatch 	 beyatch
# stayyayyyayy 	 stayayay
# henessey 	 henesey
# rottwillers 	 rotwilers
# questionwhat 	 questionwhat
# lambsbread 	 lambsbread
# alachah 	 alachah
# owwowwwowwww 	 owowow
# camaflouge 	 camaflouge
# clickilation 	 clickilation
# kayninefourths 	 kayninefourths
# unevil 	 unevil
# styleoriginator 	 styleoriginator
# bringall 	 bringall
# errorfiles 	 erorfiles
# dyingterrifying 	 dyingterifying
# heheaha 	 heheaha
# bizzalls 	 bizals
# jimminy 	 jimminy
# fuckacop 	 fuckacop
# everymotherfuckinbody 	 everymotherfuckinbody
# yeaheheh 	 yeaheheh
# stolider 	 stolider
# unfuckwittable 	 unfuckwitable
# riiiiide 	 ride
# subking 	 subking
# compense 	 compense
# iwasfinsttoask 	 iwasfinstoask
# straightseven 	 straightseven
# papapapart 	 papapapart
# belgard 	 belgard
# zigandzag 	 zigandzag
# eightysix 	 eightysix
# scillas 	 scillas
# hautein 	 hautein
# bugginand 	 buginand
# dramacydal 	 dramacydal
# chizzange 	 chizange
# doubleohseven 	 doubleohseven
# bustic 	 bustic
# pizaine 	 pizaine
# inchant 	 inchant
# niggarding 	 niggarding
# ruuumbllle 	 rumble
# outread 	 outread
# fuckingporcupine 	 fuckingporcupine
# crackfiend 	 crackfiend
# arrrrggggh 	 argh
# monodize 	 monodize
# knowledging 	 knowledging
# letches 	 letches
# rrightrightright 	 rightrightright
# trampess 	 trampess
# salutedyeah 	 salutedyeah
# lavishest 	 lavishest
# taketaketaketake 	 taketaketaketake
# sixthet 	 sixthet
# ladidadi 	 ladidadi
# overdemandingly 	 overdemandingly
# ohhahhh 	 ohah
# hilfigers 	 hilfigers
# fournickel 	 fournickel
# linelet 	 linelet
# khokani 	 khokani
# ditnirt 	 ditnirt
# ungag 	 ungag
# sixtysix 	 sixtysix
# beletter 	 beletter
# jiveass 	 jiveass
# icegrill 	 icegril
# rattlebones 	 rattlebones
# dopefiends 	 dopefiends
# aurified 	 aurified
# hehehahaha 	 hehehahaha
# faaaaaaace 	 face
# youoohoohohh 	 youohohoh
# prophalaks 	 prophalaks
# westsiiiiiide 	 westside
# haterskeep 	 haterskep
# poohbutts 	 pohbuts
# yaknahmsayin 	 yaknahmsayin
# rhymefumble 	 rhymefumble
# cados 	 cados
# mutule 	 mutule
# cardings 	 cardings
# poplitic 	 poplitic
# heywhoaaaaaa 	 heywhoa
# crimedanch 	 crimedanch
# delighter 	 delighter
# bandiness 	 bandiness
# neccesarry 	 necesary
# ziega 	 ziega
# poohbutt 	 pohbut
# selfexplanatory 	 selfexplanatory
# raahaaaah 	 rahah
# tupacalypse 	 tupacalypse
# consoloist 	 consoloist
# enheart 	 enheart
# ziggaziggas 	 zigazigas
# sixmo 	 sixmo
# hardcorereal 	 hardcorereal
# macadoshis 	 macadoshis
# ohwhoawhoawhoa 	 ohwhoawhoawhoa
# weasons 	 weasons
# forcive 	 forcive
# skypager 	 skypager
# bobotee 	 bobotee
# coochiecoo 	 cochieco
# illyric 	 illyric
# dirtyass 	 dirtyas
# threefiftysevens 	 threfiftysevens
# jimminy 	 jimminy
# motherkin 	 motherkin
# killthem 	 kilthem
# themthere 	 themthere
# ninenickel 	 ninenickel
# hopple 	 hopple
# forepiece 	 forepiece
# ursone 	 ursone
# indisputed 	 indisputed
# baybayyyy 	 baybay
# intellectionist 	 intelectionist
# clizzoud 	 clizoud
# paragraphical 	 paragraphical
# jowlop 	 jowlop
# papapapoker 	 papapapoker
# culturize 	 culturize
# sanderford 	 sanderford
# oneeightseven 	 oneightseven
# quittable 	 quittable
# tonguebird 	 tonguebird
# lewinski 	 lewinski
# terrorsome 	 terrorsome
# reanamator 	 reanamator
# katruple 	 katruple
# cardiacs 	 cardiacs
# ninehundred 	 ninehundred
# hyperin 	 hyperin
# seizor 	 seizor
# deadmc'ing 	 deadmc'ing
# doggfather 	 dogfather
# tsadi 	 tsadi
# bigbury 	 bigbury
# motionfrozen 	 motionfrozen
# heyyyeah 	 heyeah
# agnathic 	 agnathic
# eluviate 	 eluviate
# mardygraud 	 mardygraud
# pewmate 	 pewmate
# mantronix 	 mantronix
# mealticket 	 mealticket
# heyyyyyummmmmm 	 heyum

# %%
recorrected = spell.recorrect_text(" ".join(repeated_removed), words_alpha)

# %%
corrected_weights = get_glove(path, recorrected.split(" "))
len(corrected_weights)
# Out:
# 40

# %%
len(recorrected.split(" "))
# Out:
# 340
