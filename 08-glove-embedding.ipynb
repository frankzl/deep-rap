# %% [markdown]
# # 08 - Glovely Embedded
#
# Since our own word2vec embedding didn't work out so nicely, we'll have a look at Glove!

# %%
import tools.processing as pre
import numpy as np

path = "data/embeddings/glove.840B.300d.txt"

def get_glove(path_to_glove,word2index_map):
    embedding_weights = {}
    count_all_words = 0
    
    with open(path_to_glove,'r') as f:
        for line in f:
            vals = line.split(' ')
            word = str(vals[0])
            if word in word2index_map:                
                count_all_words += 1                                 
                coefs = np.asarray(vals[1:],dtype='float32')
                coefs /= np.linalg.norm(coefs)
                embedding_weights[word] = coefs
            if count_all_words== len(word2index_map) -1:
                break
    return embedding_weights

# %%
text = pre.get_text("data/ref_text3.txt")
vocab = pre.Vocabulary(text)

words_alpha = pre.get_text("data/words_alpha.txt")
alpha_vocab = pre.Vocabulary(words_alpha)

# %% [markdown]
# ## Problem: repeated character toooollll

# %%
from nltk.corpus import wordnet
import re

def remove_repeated_characters(tokens):
    repeat_pattern = re.compile(r'(\w*)(\w)\2(\w*)')
    match_substitution = r'\1\2\3'
    def replace(old_word):
        if wordnet.synsets(old_word) or old_word in alpha_vocab._dict:
            return old_word
        new_word = repeat_pattern.sub(match_substitution, old_word)
        return replace(new_word) if new_word != old_word else new_word
            
    correct_tokens = [replace(word) for word in tokens]
    return correct_tokens

repeated_removed = remove_repeated_characters(text.split(" "))
repeated_removed = " ".join( repeated_removed )

# %%
print(remove_repeated_characters( ["tooooolll"] ))
print(remove_repeated_characters( ["schhhhooooll"] ))
# Out:
# ['tool']
# ['schol']

# %% [markdown]
# **Unfortunately, we also have bad corrections: schol should have been school instead**
#
# We can try to recorrect it using our initial text dictionary

# %%
import tools.spell_correction as spell

recorrected = spell.recorrect_text(repeated_removed, text)

# %%
# pre.write_text("data/removed_repeated.txt", recorrected)

# %% [markdown]
# ### Use Glove Embedding to look up our vocabulary and translate it into the feature space

# %%
text = pre.get_text("data/removed_repeated.txt")
final_vocabulary = pre.Vocabulary(text)

embedding_weights = get_glove(path, final_vocabulary._dict)

# %%
words_recognized = len((embedding_weights.keys())) 
words_total      = len(final_vocabulary._dict.keys())
print( f"recognized words: {words_recognized} / {words_total} ")
# Out:
# recognized words: 8011 / 8518

# %%
my_vocab       = set(final_vocabulary._dict.keys())
accepted_vocab = set(embedding_weights.keys())

unk = list( my_vocab - accepted_vocab )
unk.sort()

print( unk [:5])
print( f"#unknowns: {len(unk)}")
# Out:
# ['\n', '2fifth', 'adolecsent', 'adrendaline', 'afeni']
# #unknowns: 507

# %% [markdown]
# ### Drop the "\n" since it is irrelevant. In our final input we will replace all linebreaks with ";"

# %%
unk = unk[1:]

# %% [markdown]
# ### We now run our spell correction on the words that have not been recognized

# %%
import tools.spell_correction as spell

recorrected = spell.recorrect_text(" ".join(unk), words_alpha).split(" ")

recorrected_weights = get_glove(path, recorrected)

recorrected_vocab = set(recorrected)
reaccepted_vocab  = set(recorrected_weights.keys())

acceptance_list = [ (word in reaccepted_vocab) for word in recorrected ]

residual_unk = list( recorrected_vocab - reaccepted_vocab )
residual_unk.sort()

print( residual_unk [:5])
print( f"#unknowns: {len(residual_unk)} / {len(recorrected)}")
# Out:
# ['afenil', 'againagain', 'agnathic', 'agrah', 'ahahahohoh']
# #unknowns: 300 / 506

# %% [markdown]
# ### Out of the previous 506 unknowns, we are now left with 300! We managed to correct 206 words, but let's see if the corrections make sense

# %%
import texttable as tt
tab = tt.Texttable()

headings = ['Unknown','Corrected', 'Accepted?']
tab.header(headings)

unit_costs = [40.0, 50.0, 12.0]

comparison = list(zip (unk, recorrected, acceptance_list))

for row in comparison:
    tab.add_row(row)

s = tab.draw()
print (s)
# Out:
# +-----------------------+-----------------------+-----------+
# |        Unknown        |       Corrected       | Accepted? |
# +=======================+=======================+===========+
# | 2fifth                | fifth                 | 1         |
# +-----------------------+-----------------------+-----------+
# | adolecsent            | adolescent            | 1         |
# +-----------------------+-----------------------+-----------+
# | adrendaline           | adrenaline            | 1         |
# +-----------------------+-----------------------+-----------+
# | afeni                 | afenil                | 0         |
# +-----------------------+-----------------------+-----------+
# | againagain            | againagain            | 0         |
# +-----------------------+-----------------------+-----------+
# | ageiathic             | agnathic              | 0         |
# +-----------------------+-----------------------+-----------+
# | ahahahohoh            | ahahahohoh            | 0         |
# +-----------------------+-----------------------+-----------+
# | aightaight            | lighttight            | 0         |
# +-----------------------+-----------------------+-----------+
# | alahahalahalcohol     | alahahalahalcohol     | 0         |
# +-----------------------+-----------------------+-----------+
# | alazay                | glazy                 | 1         |
# +-----------------------+-----------------------+-----------+
# | alazhay               | alachah               | 0         |
# +-----------------------+-----------------------+-----------+
# | aliviate              | bloviate              | 1         |
# +-----------------------+-----------------------+-----------+
# | allnightlong          | allnightlong          | 0         |
# +-----------------------+-----------------------+-----------+
# | amibitions            | ambitions             | 1         |
# +-----------------------+-----------------------+-----------+
# | aplogizies            | apologizes            | 1         |
# +-----------------------+-----------------------+-----------+
# | apoli                 | aioli                 | 1         |
# +-----------------------+-----------------------+-----------+
# | ariadiarrhea          | ariadiarrhea          | 0         |
# +-----------------------+-----------------------+-----------+
# | askses                | asses                 | 1         |
# +-----------------------+-----------------------+-----------+
# | assasinator           | assassinator          | 1         |
# +-----------------------+-----------------------+-----------+
# | ayoyo                 | yoyo                  | 1         |
# +-----------------------+-----------------------+-----------+
# | baldinass             | baldness              | 1         |
# +-----------------------+-----------------------+-----------+
# | balmay                | balmy                 | 1         |
# +-----------------------+-----------------------+-----------+
# | bangathon             | bangathon             | 0         |
# +-----------------------+-----------------------+-----------+
# | bassuntill            | bassuntill            | 0         |
# +-----------------------+-----------------------+-----------+
# | batteram              | batteau               | 1         |
# +-----------------------+-----------------------+-----------+
# | battleowow            | battleowow            | 0         |
# +-----------------------+-----------------------+-----------+
# | battlezones           | rattlebones           | 0         |
# +-----------------------+-----------------------+-----------+
# | beadie                | beadier               | 0         |
# +-----------------------+-----------------------+-----------+
# | bearthem              | earthed               | 1         |
# +-----------------------+-----------------------+-----------+
# | beatbreaks            | heartbreaks           | 1         |
# +-----------------------+-----------------------+-----------+
# | beitch                | bewitch               | 1         |
# +-----------------------+-----------------------+-----------+
# | benificent            | beneficent            | 1         |
# +-----------------------+-----------------------+-----------+
# | benzito               | benzins               | 0         |
# +-----------------------+-----------------------+-----------+
# | benzy                 | benjy                 | 1         |
# +-----------------------+-----------------------+-----------+
# | beugard               | belgard               | 0         |
# +-----------------------+-----------------------+-----------+
# | biblicle              | biblic                | 0         |
# +-----------------------+-----------------------+-----------+
# | blackstreets          | backstreet            | 1         |
# +-----------------------+-----------------------+-----------+
# | blegit                | elegit                | 0         |
# +-----------------------+-----------------------+-----------+
# | bluried               | blurred               | 1         |
# +-----------------------+-----------------------+-----------+
# | blurredmumbled        | blurredmumbled        | 0         |
# +-----------------------+-----------------------+-----------+
# | bobobee               | bobotee               | 0         |
# +-----------------------+-----------------------+-----------+
# | bodygurad             | bodyguard             | 1         |
# +-----------------------+-----------------------+-----------+
# | bonebonebonebone      | bonebonebonebone      | 0         |
# +-----------------------+-----------------------+-----------+
# | booyaow               | booyaow               | 0         |
# +-----------------------+-----------------------+-----------+
# | borhters              | barters               | 1         |
# +-----------------------+-----------------------+-----------+
# | braingsll             | bringall              | 0         |
# +-----------------------+-----------------------+-----------+
# | brainstormin          | brainstorming         | 1         |
# +-----------------------+-----------------------+-----------+
# | brawhat               | braggat               | 0         |
# +-----------------------+-----------------------+-----------+
# | buckfifty             | buckfifty             | 0         |
# +-----------------------+-----------------------+-----------+
# | bugginand             | bugginand             | 0         |
# +-----------------------+-----------------------+-----------+
# | buntry                | bunty                 | 1         |
# +-----------------------+-----------------------+-----------+
# | bustaz                | basta                 | 1         |
# +-----------------------+-----------------------+-----------+
# | californiaknows       | californiaknows       | 0         |
# +-----------------------+-----------------------+-----------+
# | calisthetics          | calisthenics          | 1         |
# +-----------------------+-----------------------+-----------+
# | camaflouge            | camaflouge            | 0         |
# +-----------------------+-----------------------+-----------+
# | carcuses              | circuses              | 1         |
# +-----------------------+-----------------------+-----------+
# | cardiacs              | cardiacs              | 0         |
# +-----------------------+-----------------------+-----------+
# | centpac               | cental                | 1         |
# +-----------------------+-----------------------+-----------+
# | chizzange             | chizzange             | 0         |
# +-----------------------+-----------------------+-----------+
# | christenin            | christening           | 1         |
# +-----------------------+-----------------------+-----------+
# | clarkworld            | clarkworld            | 0         |
# +-----------------------+-----------------------+-----------+
# | clentin               | cleating              | 1         |
# +-----------------------+-----------------------+-----------+
# | clickilation          | clickilation          | 0         |
# +-----------------------+-----------------------+-----------+
# | cliquot               | aliquot               | 1         |
# +-----------------------+-----------------------+-----------+
# | clizzoud              | clizzoud              | 0         |
# +-----------------------+-----------------------+-----------+
# | cnote                 | cenote                | 1         |
# +-----------------------+-----------------------+-----------+
# | coastwest             | toastiest             | 0         |
# +-----------------------+-----------------------+-----------+
# | cockhounds            | buckhounds            | 0         |
# +-----------------------+-----------------------+-----------+
# | comatoses             | comatose              | 1         |
# +-----------------------+-----------------------+-----------+
# | comense               | compense              | 0         |
# +-----------------------+-----------------------+-----------+
# | comparethem           | comparethem           | 0         |
# +-----------------------+-----------------------+-----------+
# | conceils              | conceals              | 1         |
# +-----------------------+-----------------------+-----------+
# | conisseur             | connoisseur           | 1         |
# +-----------------------+-----------------------+-----------+
# | consoloist            | consoloist            | 0         |
# +-----------------------+-----------------------+-----------+
# | conveyin              | conveying             | 1         |
# +-----------------------+-----------------------+-----------+
# | coochiecoo            | coochiecoo            | 0         |
# +-----------------------+-----------------------+-----------+
# | copastetic            | copasetic             | 1         |
# +-----------------------+-----------------------+-----------+
# | corrolate             | correlate             | 1         |
# +-----------------------+-----------------------+-----------+
# | courpse               | course                | 1         |
# +-----------------------+-----------------------+-----------+
# | crackfiend            | crackfiend            | 0         |
# +-----------------------+-----------------------+-----------+
# | crima                 | crime                 | 1         |
# +-----------------------+-----------------------+-----------+
# | crimedanch            | crimedanch            | 0         |
# +-----------------------+-----------------------+-----------+
# | crookedass            | crookedest            | 1         |
# +-----------------------+-----------------------+-----------+
# | cudders               | rudders               | 1         |
# +-----------------------+-----------------------+-----------+
# | cudois                | cadis                 | 0         |
# +-----------------------+-----------------------+-----------+
# | culturized            | culturize             | 0         |
# +-----------------------+-----------------------+-----------+
# | cuwop                 | cuon                  | 1         |
# +-----------------------+-----------------------+-----------+
# | dagz                  | dago                  | 1         |
# +-----------------------+-----------------------+-----------+
# | deadmc'ing            | deadmc'ing            | 0         |
# +-----------------------+-----------------------+-----------+
# | delightah             | delights              | 1         |
# +-----------------------+-----------------------+-----------+
# | deloris               | deplores              | 1         |
# +-----------------------+-----------------------+-----------+
# | determinely           | determinedly          | 1         |
# +-----------------------+-----------------------+-----------+
# | digestthem            | digestthem            | 0         |
# +-----------------------+-----------------------+-----------+
# | dinayros              | dinars                | 1         |
# +-----------------------+-----------------------+-----------+
# | dirtyass              | dirtyass              | 0         |
# +-----------------------+-----------------------+-----------+
# | ditnirt               | ditnirt               | 0         |
# +-----------------------+-----------------------+-----------+
# | doggfather            | doggfather            | 0         |
# +-----------------------+-----------------------+-----------+
# | domepiece             | timepiece             | 1         |
# +-----------------------+-----------------------+-----------+
# | dooder                | dodder                | 1         |
# +-----------------------+-----------------------+-----------+
# | doomstick             | broomstick            | 1         |
# +-----------------------+-----------------------+-----------+
# | dopefiend             | dopefiend             | 0         |
# +-----------------------+-----------------------+-----------+
# | dopefiends            | dopefiends            | 0         |
# +-----------------------+-----------------------+-----------+
# | dosia                 | donia                 | 1         |
# +-----------------------+-----------------------+-----------+
# | doubleedging          | doubleedging          | 0         |
# +-----------------------+-----------------------+-----------+
# | doublei               | doubled               | 1         |
# +-----------------------+-----------------------+-----------+
# | doubleohseven         | doubleohseven         | 0         |
# +-----------------------+-----------------------+-----------+
# | doubleop              | doubleton             | 1         |
# +-----------------------+-----------------------+-----------+
# | doubleups             | doubles               | 1         |
# +-----------------------+-----------------------+-----------+
# | downest               | downset               | 1         |
# +-----------------------+-----------------------+-----------+
# | dramacy               | ramack                | 0         |
# +-----------------------+-----------------------+-----------+
# | dramacydal            | dramacydal            | 0         |
# +-----------------------+-----------------------+-----------+
# | dripdrop              | dripdrop              | 0         |
# +-----------------------+-----------------------+-----------+
# | dshot                 | shot                  | 1         |
# +-----------------------+-----------------------+-----------+
# | dubar                 | tubar                 | 0         |
# +-----------------------+-----------------------+-----------+
# | dyingterrifying       | dyingterrifying       | 0         |
# +-----------------------+-----------------------+-----------+
# | eazye                 | tazze                 | 0         |
# +-----------------------+-----------------------+-----------+
# | editorforever         | editorforever         | 0         |
# +-----------------------+-----------------------+-----------+
# | eforty                | forty                 | 1         |
# +-----------------------+-----------------------+-----------+
# | eightynine            | eightynine            | 0         |
# +-----------------------+-----------------------+-----------+
# | eightysix             | eightysix             | 0         |
# +-----------------------+-----------------------+-----------+
# | elel                  | eel                   | 1         |
# +-----------------------+-----------------------+-----------+
# | eleviates             | elevates              | 1         |
# +-----------------------+-----------------------+-----------+
# | errorfiles            | errorfiles            | 0         |
# +-----------------------+-----------------------+-----------+
# | eskimys               | eskimos               | 1         |
# +-----------------------+-----------------------+-----------+
# | ethchasketch          | ethchasketch          | 0         |
# +-----------------------+-----------------------+-----------+
# | everymotherfuckinbody | everymotherfuckinbody | 0         |
# +-----------------------+-----------------------+-----------+
# | exconvicts            | convicts              | 1         |
# +-----------------------+-----------------------+-----------+
# | excuseamoi            | excuseamoi            | 0         |
# +-----------------------+-----------------------+-----------+
# | extorters             | extorters             | 0         |
# +-----------------------+-----------------------+-----------+
# | facepoke              | facepoke              | 0         |
# +-----------------------+-----------------------+-----------+
# | fantansies            | fantasies             | 1         |
# +-----------------------+-----------------------+-----------+
# | fantansy              | fantasy               | 1         |
# +-----------------------+-----------------------+-----------+
# | fearified             | terrified             | 1         |
# +-----------------------+-----------------------+-----------+
# | firstheh              | firster               | 1         |
# +-----------------------+-----------------------+-----------+
# | fivedoubleoh          | fivedoubleoh          | 0         |
# +-----------------------+-----------------------+-----------+
# | fiveo                 | fiver                 | 1         |
# +-----------------------+-----------------------+-----------+
# | fiveoh                | five                  | 1         |
# +-----------------------+-----------------------+-----------+
# | flizzight             | flizzight             | 0         |
# +-----------------------+-----------------------+-----------+
# | fo'fo'                | fo'fo'                | 0         |
# +-----------------------+-----------------------+-----------+
# | fofifth               | fifth                 | 1         |
# +-----------------------+-----------------------+-----------+
# | foolies               | boolies               | 0         |
# +-----------------------+-----------------------+-----------+
# | fortyfour             | fortyfold             | 0         |
# +-----------------------+-----------------------+-----------+
# | fourfive              | forlive               | 0         |
# +-----------------------+-----------------------+-----------+
# | fournickel            | fournickel            | 0         |
# +-----------------------+-----------------------+-----------+
# | fuckacop              | fuckacop              | 0         |
# +-----------------------+-----------------------+-----------+
# | fuckboys              | fuckboys              | 0         |
# +-----------------------+-----------------------+-----------+
# | fuckingporcupine      | fuckingporcupine      | 0         |
# +-----------------------+-----------------------+-----------+
# | fuckniggaz            | fuckniggaz            | 0         |
# +-----------------------+-----------------------+-----------+
# | funkdified            | mundified             | 0         |
# +-----------------------+-----------------------+-----------+
# | furier                | furied                | 0         |
# +-----------------------+-----------------------+-----------+
# | furified              | aurified              | 0         |
# +-----------------------+-----------------------+-----------+
# | gimminy               | jimminy               | 0         |
# +-----------------------+-----------------------+-----------+
# | giseles               | lisles                | 0         |
# +-----------------------+-----------------------+-----------+
# | gogetter              | getter                | 1         |
# +-----------------------+-----------------------+-----------+
# | gogetters             | forgetters            | 1         |
# +-----------------------+-----------------------+-----------+
# | gomars                | gomari                | 0         |
# +-----------------------+-----------------------+-----------+
# | gunslang              | gunsling              | 0         |
# +-----------------------+-----------------------+-----------+
# | guntoter              | gunster               | 0         |
# +-----------------------+-----------------------+-----------+
# | halfblack             | halfback              | 1         |
# +-----------------------+-----------------------+-----------+
# | hardcorereal          | hardcorereal          | 0         |
# +-----------------------+-----------------------+-----------+
# | hardings              | harpings              | 0         |
# +-----------------------+-----------------------+-----------+
# | hardrap               | gardnap               | 0         |
# +-----------------------+-----------------------+-----------+
# | haterskeep            | haterskeep            | 0         |
# +-----------------------+-----------------------+-----------+
# | hawalian              | hawaiian              | 1         |
# +-----------------------+-----------------------+-----------+
# | heavnly               | heavily               | 1         |
# +-----------------------+-----------------------+-----------+
# | heavyheavyheavy       | heavyheavyheavy       | 0         |
# +-----------------------+-----------------------+-----------+
# | heffing               | hefting               | 1         |
# +-----------------------+-----------------------+-----------+
# | hehahahahaha          | hehahahahaha          | 0         |
# +-----------------------+-----------------------+-----------+
# | heheaha               | heheaha               | 0         |
# +-----------------------+-----------------------+-----------+
# | hehehahaha            | hehehahaha            | 0         |
# +-----------------------+-----------------------+-----------+
# | heheheyah             | heheheyah             | 0         |
# +-----------------------+-----------------------+-----------+
# | heirem                | heired                | 0         |
# +-----------------------+-----------------------+-----------+
# | henni                 | hennin                | 0         |
# +-----------------------+-----------------------+-----------+
# | hesitiation           | hesitation            | 1         |
# +-----------------------+-----------------------+-----------+
# | heywhoa               | heywhoa               | 0         |
# +-----------------------+-----------------------+-----------+
# | hilfigers             | hilfigers             | 0         |
# +-----------------------+-----------------------+-----------+
# | hiphoppers            | hiphoppers            | 0         |
# +-----------------------+-----------------------+-----------+
# | hollowtip             | hollowtip             | 0         |
# +-----------------------+-----------------------+-----------+
# | homeyg                | homey                 | 1         |
# +-----------------------+-----------------------+-----------+
# | hoochercoocher        | hoochercoocher        | 0         |
# +-----------------------+-----------------------+-----------+
# | hoopala               | hoopla                | 1         |
# +-----------------------+-----------------------+-----------+
# | huxtables             | gustables             | 0         |
# +-----------------------+-----------------------+-----------+
# | hyperchrondriac       | hyperchrondriac       | 0         |
# +-----------------------+-----------------------+-----------+
# | hypertone             | hypercone             | 0         |
# +-----------------------+-----------------------+-----------+
# | hypetip               | hyperin               | 0         |
# +-----------------------+-----------------------+-----------+
# | icegrill              | icegrill              | 0         |
# +-----------------------+-----------------------+-----------+
# | illtrip               | illyric               | 0         |
# +-----------------------+-----------------------+-----------+
# | imitaters             | imitators             | 1         |
# +-----------------------+-----------------------+-----------+
# | immortalz             | immortals             | 1         |
# +-----------------------+-----------------------+-----------+
# | inchant               | inchant               | 0         |
# +-----------------------+-----------------------+-----------+
# | indicatin             | indication            | 1         |
# +-----------------------+-----------------------+-----------+
# | indispute             | indisputed            | 0         |
# +-----------------------+-----------------------+-----------+
# | inducis               | induces               | 1         |
# +-----------------------+-----------------------+-----------+
# | inflex                | inflex                | 0         |
# +-----------------------+-----------------------+-----------+
# | inglewatts            | inglewatts            | 0         |
# +-----------------------+-----------------------+-----------+
# | instutionalized       | institutionalized     | 1         |
# +-----------------------+-----------------------+-----------+
# | intellectionist       | intellectionist       | 0         |
# +-----------------------+-----------------------+-----------+
# | interchart            | interchaff            | 0         |
# +-----------------------+-----------------------+-----------+
# | introchorus           | introchorus           | 0         |
# +-----------------------+-----------------------+-----------+
# | isoh                  | isth                  | 0         |
# +-----------------------+-----------------------+-----------+
# | iwasfinsttoask        | iwasfinsttoask        | 0         |
# +-----------------------+-----------------------+-----------+
# | jabebecausezi         | jabebecausezi         | 0         |
# +-----------------------+-----------------------+-----------+
# | jackmack              | hackmack              | 0         |
# +-----------------------+-----------------------+-----------+
# | jailhouses            | jailhouses            | 0         |
# +-----------------------+-----------------------+-----------+
# | jealousass            | jealousness           | 1         |
# +-----------------------+-----------------------+-----------+
# | jeapordizing          | jeopardizing          | 1         |
# +-----------------------+-----------------------+-----------+
# | jerdy                 | jerry                 | 1         |
# +-----------------------+-----------------------+-----------+
# | jimminy               | jimminy               | 0         |
# +-----------------------+-----------------------+-----------+
# | jiveass               | jiveass               | 0         |
# +-----------------------+-----------------------+-----------+
# | katruple              | katruple              | 0         |
# +-----------------------+-----------------------+-----------+
# | kausion               | caution               | 1         |
# +-----------------------+-----------------------+-----------+
# | kayninefourths        | kayninefourths        | 0         |
# +-----------------------+-----------------------+-----------+
# | kday                  | yday                  | 1         |
# +-----------------------+-----------------------+-----------+
# | khomani               | khokani               | 0         |
# +-----------------------+-----------------------+-----------+
# | killorbekilled        | killorbekilled        | 0         |
# +-----------------------+-----------------------+-----------+
# | killthem              | killthem              | 0         |
# +-----------------------+-----------------------+-----------+
# | klacka                | flack                 | 1         |
# +-----------------------+-----------------------+-----------+
# | klow                  | slow                  | 1         |
# +-----------------------+-----------------------+-----------+
# | knahmean              | knahmean              | 0         |
# +-----------------------+-----------------------+-----------+
# | knowhati              | nowhat                | 0         |
# +-----------------------+-----------------------+-----------+
# | knowledging           | knowledging           | 0         |
# +-----------------------+-----------------------+-----------+
# | kosugi                | sugi                  | 1         |
# +-----------------------+-----------------------+-----------+
# | krsone                | krone                 | 1         |
# +-----------------------+-----------------------+-----------+
# | kusher                | rusher                | 1         |
# +-----------------------+-----------------------+-----------+
# | ladadadah             | ladadadah             | 0         |
# +-----------------------+-----------------------+-----------+
# | ladidadi              | ladidadi              | 0         |
# +-----------------------+-----------------------+-----------+
# | lambsbread            | lambsbread            | 0         |
# +-----------------------+-----------------------+-----------+
# | lastlast              | laglast               | 0         |
# +-----------------------+-----------------------+-----------+
# | lavishist             | lavishest             | 0         |
# +-----------------------+-----------------------+-----------+
# | learedn               | yearend               | 1         |
# +-----------------------+-----------------------+-----------+
# | leavey                | leaved                | 1         |
# +-----------------------+-----------------------+-----------+
# | lelelet               | lifelet               | 0         |
# +-----------------------+-----------------------+-----------+
# | letthem               | letted                | 1         |
# +-----------------------+-----------------------+-----------+
# | levantore             | levanter              | 0         |
# +-----------------------+-----------------------+-----------+
# | lewinski              | lewinski              | 0         |
# +-----------------------+-----------------------+-----------+
# | liebury               | disbury               | 0         |
# +-----------------------+-----------------------+-----------+
# | likeah                | lineas                | 1         |
# +-----------------------+-----------------------+-----------+
# | limbwalk              | likewalk              | 0         |
# +-----------------------+-----------------------+-----------+
# | lizzane               | lizzie                | 1         |
# +-----------------------+-----------------------+-----------+
# | lizzight              | lizzight              | 0         |
# +-----------------------+-----------------------+-----------+
# | lopole                | pole                  | 1         |
# +-----------------------+-----------------------+-----------+
# | lovetraps             | livetraps             | 0         |
# +-----------------------+-----------------------+-----------+
# | lowlow                | bowwow                | 1         |
# +-----------------------+-----------------------+-----------+
# | lowlows               | lollops               | 0         |
# +-----------------------+-----------------------+-----------+
# | lyricst               | lyricist              | 1         |
# +-----------------------+-----------------------+-----------+
# | macadoshis            | macadoshis            | 0         |
# +-----------------------+-----------------------+-----------+
# | macaveli              | manavel               | 0         |
# +-----------------------+-----------------------+-----------+
# | mackaveli             | mackaveli             | 0         |
# +-----------------------+-----------------------+-----------+
# | mackers               | lackers               | 0         |
# +-----------------------+-----------------------+-----------+
# | magellen              | magellan              | 1         |
# +-----------------------+-----------------------+-----------+
# | magnatize             | magnetize             | 1         |
# +-----------------------+-----------------------+-----------+
# | magnatized            | magnetized            | 1         |
# +-----------------------+-----------------------+-----------+
# | mamoon                | mammon                | 1         |
# +-----------------------+-----------------------+-----------+
# | mantronix             | mantronix             | 0         |
# +-----------------------+-----------------------+-----------+
# | mardygraud            | mardygraud            | 0         |
# +-----------------------+-----------------------+-----------+
# | mastercrash           | mastercrash           | 0         |
# +-----------------------+-----------------------+-----------+
# | mc'sl                 | msl                   | 1         |
# +-----------------------+-----------------------+-----------+
# | mealticket            | mealticket            | 0         |
# +-----------------------+-----------------------+-----------+
# | megathesis            | metathesis            | 1         |
# +-----------------------+-----------------------+-----------+
# | melodiesunmakable     | melodiesunmakable     | 0         |
# +-----------------------+-----------------------+-----------+
# | mentallect            | mentallect            | 0         |
# +-----------------------+-----------------------+-----------+
# | mescudi               | scudi                 | 1         |
# +-----------------------+-----------------------+-----------+
# | methical              | metrical              | 1         |
# +-----------------------+-----------------------+-----------+
# | miccops               | mincopi               | 0         |
# +-----------------------+-----------------------+-----------+
# | microphonethat        | microphonethat        | 0         |
# +-----------------------+-----------------------+-----------+
# | microphonist          | microphonism          | 0         |
# +-----------------------+-----------------------+-----------+
# | mictomouth            | mictomouth            | 0         |
# +-----------------------+-----------------------+-----------+
# | midnught              | midnight              | 1         |
# +-----------------------+-----------------------+-----------+
# | milleni               | milleri               | 1         |
# +-----------------------+-----------------------+-----------+
# | minutemaid            | minuteman             | 1         |
# +-----------------------+-----------------------+-----------+
# | moneymakinmachines    | moneymakinmachines    | 0         |
# +-----------------------+-----------------------+-----------+
# | monosize              | monodize              | 0         |
# +-----------------------+-----------------------+-----------+
# | mophreme              | sopheme               | 0         |
# +-----------------------+-----------------------+-----------+
# | mopreme               | expreme               | 0         |
# +-----------------------+-----------------------+-----------+
# | mothercrookedfucking  | mothercrookedfucking  | 0         |
# +-----------------------+-----------------------+-----------+
# | motherfuckersdid      | motherfuckersdid      | 0         |
# +-----------------------+-----------------------+-----------+
# | motherrun             | motherkin             | 0         |
# +-----------------------+-----------------------+-----------+
# | motionfrozen          | motionfrozen          | 0         |
# +-----------------------+-----------------------+-----------+
# | muh'fucking           | muh'fucking           | 0         |
# +-----------------------+-----------------------+-----------+
# | muhfuckers            | muhfuckers            | 0         |
# +-----------------------+-----------------------+-----------+
# | multimillionare       | multimillionaire      | 1         |
# +-----------------------+-----------------------+-----------+
# | multived              | multiped              | 0         |
# +-----------------------+-----------------------+-----------+
# | mumar                 | mymar                 | 0         |
# +-----------------------+-----------------------+-----------+
# | murdererbefore        | murdererbefore        | 0         |
# +-----------------------+-----------------------+-----------+
# | mutulu                | mutule                | 0         |
# +-----------------------+-----------------------+-----------+
# | mynin                 | bynin                 | 0         |
# +-----------------------+-----------------------+-----------+
# | nanananananana        | nanananananana        | 0         |
# +-----------------------+-----------------------+-----------+
# | nananananananana      | nananananananana      | 0         |
# +-----------------------+-----------------------+-----------+
# | naploleon             | napoleon              | 1         |
# +-----------------------+-----------------------+-----------+
# | narratin              | narration             | 1         |
# +-----------------------+-----------------------+-----------+
# | navalet               | naval                 | 1         |
# +-----------------------+-----------------------+-----------+
# | nearthem              | earthed               | 1         |
# +-----------------------+-----------------------+-----------+
# | needbeen              | peebeen               | 0         |
# +-----------------------+-----------------------+-----------+
# | nefretiti             | nefretiti             | 0         |
# +-----------------------+-----------------------+-----------+
# | niggarino             | niggarding            | 0         |
# +-----------------------+-----------------------+-----------+
# | niggaslashrap         | niggaslashrap         | 0         |
# +-----------------------+-----------------------+-----------+
# | nimth                 | ninth                 | 1         |
# +-----------------------+-----------------------+-----------+
# | ninehundred           | ninehundred           | 0         |
# +-----------------------+-----------------------+-----------+
# | ninenickel            | ninenickel            | 0         |
# +-----------------------+-----------------------+-----------+
# | ninetyseven           | ninetyseven           | 0         |
# +-----------------------+-----------------------+-----------+
# | ninetysix             | ninetyish             | 0         |
# +-----------------------+-----------------------+-----------+
# | ninetythree           | ninetythree           | 0         |
# +-----------------------+-----------------------+-----------+
# | ninetytwo             | ninetytwo             | 0         |
# +-----------------------+-----------------------+-----------+
# | nobry                 | norry                 | 0         |
# +-----------------------+-----------------------+-----------+
# | nonplayers            | nonpayer              | 0         |
# +-----------------------+-----------------------+-----------+
# | notthinki             | notthinki             | 0         |
# +-----------------------+-----------------------+-----------+
# | novicane              | novocaine             | 1         |
# +-----------------------+-----------------------+-----------+
# | nuckas                | necks                 | 1         |
# +-----------------------+-----------------------+-----------+
# | offtherack            | offtrack              | 1         |
# +-----------------------+-----------------------+-----------+
# | oftb                  | oft                   | 1         |
# +-----------------------+-----------------------+-----------+
# | ohah                  | shah                  | 1         |
# +-----------------------+-----------------------+-----------+
# | ohhohohohwhoa         | ohhohohohwhoa         | 0         |
# +-----------------------+-----------------------+-----------+
# | ohwe                  | howe                  | 1         |
# +-----------------------+-----------------------+-----------+
# | ohwhoawhoawhoa        | ohwhoawhoawhoa        | 0         |
# +-----------------------+-----------------------+-----------+
# | oneeightseven         | oneeightseven         | 0         |
# +-----------------------+-----------------------+-----------+
# | oneeightyfive         | oneeightyfive         | 0         |
# +-----------------------+-----------------------+-----------+
# | oneletter             | eyeletter             | 0         |
# +-----------------------+-----------------------+-----------+
# | openheart             | enheart               | 0         |
# +-----------------------+-----------------------+-----------+
# | optimos               | optimes               | 0         |
# +-----------------------+-----------------------+-----------+
# | outreal               | outread               | 0         |
# +-----------------------+-----------------------+-----------+
# | overdemanding         | overdemandingly       | 0         |
# +-----------------------+-----------------------+-----------+
# | overthugging          | overthugging          | 0         |
# +-----------------------+-----------------------+-----------+
# | ovius                 | ovis                  | 1         |
# +-----------------------+-----------------------+-----------+
# | owowow                | bowwow                | 1         |
# +-----------------------+-----------------------+-----------+
# | pachenga              | pachanga              | 1         |
# +-----------------------+-----------------------+-----------+
# | pandemical            | pandemics             | 1         |
# +-----------------------+-----------------------+-----------+
# | papapapart            | papapapart            | 0         |
# +-----------------------+-----------------------+-----------+
# | papapapoker           | papapapoker           | 0         |
# +-----------------------+-----------------------+-----------+
# | papapoker             | papapoker             | 0         |
# +-----------------------+-----------------------+-----------+
# | papermates            | papermaker            | 1         |
# +-----------------------+-----------------------+-----------+
# | paragraphical         | paragraphical         | 0         |
# +-----------------------+-----------------------+-----------+
# | paragraphologist      | paragraphologist      | 0         |
# +-----------------------+-----------------------+-----------+
# | patternunecscapable   | patternunecscapable   | 0         |
# +-----------------------+-----------------------+-----------+
# | pauletta              | muletta               | 0         |
# +-----------------------+-----------------------+-----------+
# | peformin              | reforming             | 1         |
# +-----------------------+-----------------------+-----------+
# | penals                | petals                | 1         |
# +-----------------------+-----------------------+-----------+
# | penaltyand            | penaltyand            | 0         |
# +-----------------------+-----------------------+-----------+
# | penetentiaries        | penitentiaries        | 1         |
# +-----------------------+-----------------------+-----------+
# | penmate               | pennate               | 1         |
# +-----------------------+-----------------------+-----------+
# | periphereal           | peripherial           | 1         |
# +-----------------------+-----------------------+-----------+
# | peuente               | pendente              | 1         |
# +-----------------------+-----------------------+-----------+
# | pinkle                | winkle                | 1         |
# +-----------------------+-----------------------+-----------+
# | pizzaint              | pizaine               | 0         |
# +-----------------------+-----------------------+-----------+
# | pizznac               | pizza                 | 1         |
# +-----------------------+-----------------------+-----------+
# | plainpat              | plaint                | 1         |
# +-----------------------+-----------------------+-----------+
# | playerhaters          | playerhaters          | 0         |
# +-----------------------+-----------------------+-----------+
# | plinkling             | plinking              | 1         |
# +-----------------------+-----------------------+-----------+
# | pollitic              | poplitic              | 0         |
# +-----------------------+-----------------------+-----------+
# | poohbutt              | poohbutt              | 0         |
# +-----------------------+-----------------------+-----------+
# | poonannynans          | poonannynans          | 0         |
# +-----------------------+-----------------------+-----------+
# | prophalaks            | prophalaks            | 0         |
# +-----------------------+-----------------------+-----------+
# | prprpretty            | prprpretty            | 0         |
# +-----------------------+-----------------------+-----------+
# | questionwhat          | questionwhat          | 0         |
# +-----------------------+-----------------------+-----------+
# | quitraple             | quittable             | 0         |
# +-----------------------+-----------------------+-----------+
# | quizzin               | quizzing              | 1         |
# +-----------------------+-----------------------+-----------+
# | rahrah                | agrah                 | 0         |
# +-----------------------+-----------------------+-----------+
# | rainbut               | rainout               | 1         |
# +-----------------------+-----------------------+-----------+
# | raiseed               | raised                | 1         |
# +-----------------------+-----------------------+-----------+
# | rangea                | ranges                | 1         |
# +-----------------------+-----------------------+-----------+
# | raprelated            | raprelated            | 0         |
# +-----------------------+-----------------------+-----------+
# | realeast              | realest               | 1         |
# +-----------------------+-----------------------+-----------+
# | reanamator            | reanamator            | 0         |
# +-----------------------+-----------------------+-----------+
# | rehearsin             | rehearsing            | 1         |
# +-----------------------+-----------------------+-----------+
# | remainable            | regainable            | 0         |
# +-----------------------+-----------------------+-----------+
# | reminsce              | reminisce             | 1         |
# +-----------------------+-----------------------+-----------+
# | rentarapper           | entrapper             | 0         |
# +-----------------------+-----------------------+-----------+
# | restitchin            | restitch              | 1         |
# +-----------------------+-----------------------+-----------+
# | rhymefumble           | rhymefumble           | 0         |
# +-----------------------+-----------------------+-----------+
# | rickashay             | ricksha               | 1         |
# +-----------------------+-----------------------+-----------+
# | rigarmortis           | rigarmortis           | 0         |
# +-----------------------+-----------------------+-----------+
# | rigormortis           | rigormortis           | 0         |
# +-----------------------+-----------------------+-----------+
# | risci                 | disci                 | 1         |
# +-----------------------+-----------------------+-----------+
# | roct                  | oct                   | 1         |
# +-----------------------+-----------------------+-----------+
# | rosecranz             | rosecranz             | 0         |
# +-----------------------+-----------------------+-----------+
# | rottwilers            | rottweiler            | 1         |
# +-----------------------+-----------------------+-----------+
# | rrightrightright      | rrightrightright      | 0         |
# +-----------------------+-----------------------+-----------+
# | rushtown              | reshown               | 1         |
# +-----------------------+-----------------------+-----------+
# | sadicious             | seditious             | 1         |
# +-----------------------+-----------------------+-----------+
# | salutedyeah           | salutedyeah           | 0         |
# +-----------------------+-----------------------+-----------+
# | sanderford            | sanderford            | 0         |
# +-----------------------+-----------------------+-----------+
# | sauteein              | sauteing              | 1         |
# +-----------------------+-----------------------+-----------+
# | scarfo                | scarfy                | 0         |
# +-----------------------+-----------------------+-----------+
# | scheaming             | scheming              | 1         |
# +-----------------------+-----------------------+-----------+
# | schoolis              | schools               | 1         |
# +-----------------------+-----------------------+-----------+
# | sckrillas             | scillas               | 0         |
# +-----------------------+-----------------------+-----------+
# | scoliosisskulliosis   | scoliosisskulliosis   | 0         |
# +-----------------------+-----------------------+-----------+
# | seagel                | stager                | 1         |
# +-----------------------+-----------------------+-----------+
# | sekon                 | sekos                 | 0         |
# +-----------------------+-----------------------+-----------+
# | selfexplanatory       | selfexplanatory       | 0         |
# +-----------------------+-----------------------+-----------+
# | sestruct              | destruct              | 1         |
# +-----------------------+-----------------------+-----------+
# | setchu                | vetch                 | 1         |
# +-----------------------+-----------------------+-----------+
# | shermed               | ushered               | 1         |
# +-----------------------+-----------------------+-----------+
# | sidewest              | midwest               | 1         |
# +-----------------------+-----------------------+-----------+
# | simping               | simling               | 0         |
# +-----------------------+-----------------------+-----------+
# | sixeight              | sidelight             | 1         |
# +-----------------------+-----------------------+-----------+
# | sixfigure             | misfigure             | 0         |
# +-----------------------+-----------------------+-----------+
# | sixfo                 | sixmo                 | 0         |
# +-----------------------+-----------------------+-----------+
# | sixo                  | cixo                  | 0         |
# +-----------------------+-----------------------+-----------+
# | sixone                | sixsome               | 0         |
# +-----------------------+-----------------------+-----------+
# | sixthree              | sixthet               | 0         |
# +-----------------------+-----------------------+-----------+
# | sixtysix              | sixtysix              | 0         |
# +-----------------------+-----------------------+-----------+
# | skandalous            | scandalous            | 1         |
# +-----------------------+-----------------------+-----------+
# | skanless              | spanless              | 0         |
# +-----------------------+-----------------------+-----------+
# | skeezing              | sneezing              | 1         |
# +-----------------------+-----------------------+-----------+
# | skypage               | kipage                | 0         |
# +-----------------------+-----------------------+-----------+
# | skypager              | skypager              | 0         |
# +-----------------------+-----------------------+-----------+
# | slizow                | slow                  | 1         |
# +-----------------------+-----------------------+-----------+
# | smokethem             | smokethem             | 0         |
# +-----------------------+-----------------------+-----------+
# | spectactale           | spectacle             | 1         |
# +-----------------------+-----------------------+-----------+
# | splifs                | splits                | 1         |
# +-----------------------+-----------------------+-----------+
# | splifted              | uplifted              | 1         |
# +-----------------------+-----------------------+-----------+
# | sportable             | sportable             | 0         |
# +-----------------------+-----------------------+-----------+
# | stayayay              | strayaway             | 0         |
# +-----------------------+-----------------------+-----------+
# | stayinliner           | stayinliner           | 0         |
# +-----------------------+-----------------------+-----------+
# | stetsasonic           | stetsasonic           | 0         |
# +-----------------------+-----------------------+-----------+
# | sticthes              | stitches              | 1         |
# +-----------------------+-----------------------+-----------+
# | stolider              | stolider              | 0         |
# +-----------------------+-----------------------+-----------+
# | stonefacing           | stonelaying           | 0         |
# +-----------------------+-----------------------+-----------+
# | straightass           | straights             | 1         |
# +-----------------------+-----------------------+-----------+
# | straightseven         | straightseven         | 0         |
# +-----------------------+-----------------------+-----------+
# | stresed               | stressed              | 1         |
# +-----------------------+-----------------------+-----------+
# | strugala              | strigula              | 0         |
# +-----------------------+-----------------------+-----------+
# | styleoriginator       | styleoriginator       | 0         |
# +-----------------------+-----------------------+-----------+
# | suffocator            | suffocated            | 1         |
# +-----------------------+-----------------------+-----------+
# | sumping               | jumping               | 1         |
# +-----------------------+-----------------------+-----------+
# | sunking               | sinking               | 1         |
# +-----------------------+-----------------------+-----------+
# | surveyin              | surveying             | 1         |
# +-----------------------+-----------------------+-----------+
# | swerl                 | swerd                 | 1         |
# +-----------------------+-----------------------+-----------+
# | taketake              | caretake              | 1         |
# +-----------------------+-----------------------+-----------+
# | taketaketaketake      | taketaketaketake      | 0         |
# +-----------------------+-----------------------+-----------+
# | tarvue                | tarve                 | 0         |
# +-----------------------+-----------------------+-----------+
# | tearthem              | teathe                | 0         |
# +-----------------------+-----------------------+-----------+
# | temptingwhatever      | temptingwhatever      | 0         |
# +-----------------------+-----------------------+-----------+
# | terrordome            | terrorsome            | 0         |
# +-----------------------+-----------------------+-----------+
# | themthere             | themthere             | 0         |
# +-----------------------+-----------------------+-----------+
# | threefiftyseven       | threefiftyseven       | 0         |
# +-----------------------+-----------------------+-----------+
# | threefiftysevens      | threefiftysevens      | 0         |
# +-----------------------+-----------------------+-----------+
# | threefourths          | threefourths          | 0         |
# +-----------------------+-----------------------+-----------+
# | thuged                | thugged               | 1         |
# +-----------------------+-----------------------+-----------+
# | thuging               | thugging              | 1         |
# +-----------------------+-----------------------+-----------+
# | ticktocking           | ticktocking           | 0         |
# +-----------------------+-----------------------+-----------+
# | tingaling             | tingling              | 1         |
# +-----------------------+-----------------------+-----------+
# | toastses              | trasses               | 0         |
# +-----------------------+-----------------------+-----------+
# | todosomethinass       | todosomethinass       | 0         |
# +-----------------------+-----------------------+-----------+
# | togination            | sagination            | 0         |
# +-----------------------+-----------------------+-----------+
# | toginations           | nominations           | 1         |
# +-----------------------+-----------------------+-----------+
# | togine                | toxine                | 0         |
# +-----------------------+-----------------------+-----------+
# | togined               | trined                | 1         |
# +-----------------------+-----------------------+-----------+
# | tonguekissing         | tonguekissing         | 0         |
# +-----------------------+-----------------------+-----------+
# | tonguetied            | tonguetip             | 0         |
# +-----------------------+-----------------------+-----------+
# | topicless             | toilless              | 0         |
# +-----------------------+-----------------------+-----------+
# | topling               | tooling               | 1         |
# +-----------------------+-----------------------+-----------+
# | topranked             | bepranked             | 0         |
# +-----------------------+-----------------------+-----------+
# | totions               | notions               | 1         |
# +-----------------------+-----------------------+-----------+
# | towerin               | towering              | 1         |
# +-----------------------+-----------------------+-----------+
# | trampass              | trampess              | 0         |
# +-----------------------+-----------------------+-----------+
# | trefo                 | trefa                 | 0         |
# +-----------------------+-----------------------+-----------+
# | tretch                | tetch                 | 0         |
# +-----------------------+-----------------------+-----------+
# | treytrey              | treitre               | 0         |
# +-----------------------+-----------------------+-----------+
# | trifeass              | trifeass              | 0         |
# +-----------------------+-----------------------+-----------+
# | triggar               | trigger               | 1         |
# +-----------------------+-----------------------+-----------+
# | tugawar               | tulwar                | 0         |
# +-----------------------+-----------------------+-----------+
# | tupacalypse           | tupacalypse           | 0         |
# +-----------------------+-----------------------+-----------+
# | tutankhamuns          | tutankhamen           | 1         |
# +-----------------------+-----------------------+-----------+
# | twentyfo              | twentymo              | 0         |
# +-----------------------+-----------------------+-----------+
# | twentyfourseven       | twentyfourseven       | 0         |
# +-----------------------+-----------------------+-----------+
# | twentysomeodd         | twentysomeodd         | 0         |
# +-----------------------+-----------------------+-----------+
# | twitterin             | twittering            | 1         |
# +-----------------------+-----------------------+-----------+
# | twodollar             | twodollar             | 0         |
# +-----------------------+-----------------------+-----------+
# | twothou               | twothou               | 0         |
# +-----------------------+-----------------------+-----------+
# | tymel                 | gymel                 | 0         |
# +-----------------------+-----------------------+-----------+
# | uhyeah                | whydah                | 0         |
# +-----------------------+-----------------------+-----------+
# | ultamatum             | ultimatum             | 1         |
# +-----------------------+-----------------------+-----------+
# | unevil                | unevil                | 0         |
# +-----------------------+-----------------------+-----------+
# | unfuckwittable        | unfuckwittable        | 0         |
# +-----------------------+-----------------------+-----------+
# | usabi                 | unai                  | 1         |
# +-----------------------+-----------------------+-----------+
# | utilalize             | utilize               | 1         |
# +-----------------------+-----------------------+-----------+
# | viennas               | siennas               | 1         |
# +-----------------------+-----------------------+-----------+
# | walkby                | walker                | 1         |
# +-----------------------+-----------------------+-----------+
# | wanksters             | canisters             | 1         |
# +-----------------------+-----------------------+-----------+
# | weakrhymer            | weakrhymer            | 0         |
# +-----------------------+-----------------------+-----------+
# | wearthem              | earthed               | 1         |
# +-----------------------+-----------------------+-----------+
# | wessons               | weasons               | 0         |
# +-----------------------+-----------------------+-----------+
# | whoosah               | whoosh                | 1         |
# +-----------------------+-----------------------+-----------+
# | whorider              | worder                | 1         |
# +-----------------------+-----------------------+-----------+
# | wildass               | wildish               | 1         |
# +-----------------------+-----------------------+-----------+
# | withchu               | witchy                | 1         |
# +-----------------------+-----------------------+-----------+
# | wowwowwow             | wowwowwow             | 0         |
# +-----------------------+-----------------------+-----------+
# | wwwrakimcom           | wwwrakimcom           | 0         |
# +-----------------------+-----------------------+-----------+
# | wyndanch              | wyndanch              | 0         |
# +-----------------------+-----------------------+-----------+
# | xannies               | nannies               | 1         |
# +-----------------------+-----------------------+-----------+
# | xthree                | three                 | 1         |
# +-----------------------+-----------------------+-----------+
# | yaknahmean            | yaknahmean            | 0         |
# +-----------------------+-----------------------+-----------+
# | yaknahmsayin          | yaknahmsayin          | 0         |
# +-----------------------+-----------------------+-----------+
# | yanamean              | panacean              | 0         |
# +-----------------------+-----------------------+-----------+
# | yeaheheh              | yeaheheh              | 0         |
# +-----------------------+-----------------------+-----------+
# | yoasiatics            | yoasiatics            | 0         |
# +-----------------------+-----------------------+-----------+
# | yothe                 | cothe                 | 0         |
# +-----------------------+-----------------------+-----------+
# | young'uns             | youngun               | 1         |
# +-----------------------+-----------------------+-----------+
# | youohohoh             | youohohoh             | 0         |
# +-----------------------+-----------------------+-----------+
# | yousea                | youse                 | 1         |
# +-----------------------+-----------------------+-----------+
# | zakia                 | akia                  | 1         |
# +-----------------------+-----------------------+-----------+
# | zayros                | cayos                 | 0         |
# +-----------------------+-----------------------+-----------+
# | zigandzag             | zigandzag             | 0         |
# +-----------------------+-----------------------+-----------+
# | zigga                 | ziega                 | 0         |
# +-----------------------+-----------------------+-----------+
# | ziggaziggas           | ziggaziggas           | 0         |
# +-----------------------+-----------------------+-----------+

# %%
valid_embedding_words = {}
correction_map = {}

unknown_default = np.array(300*[0])

for unknown, corrected, accepted in comparison:
    if accepted:
        valid_embedding_words[corrected] = recorrected_weights[corrected]
        correction_map [unknown] = corrected
    # else:
    #     valid_embedding_words[unknown] = unknown_default

# %% [markdown]
# ### Now we replace the wrong words in our original text with our corrections, so that more words can be embedded by glove

# %%
corrected_text = text

for key, value in correction_map.items():
    corrected_text = corrected_text.replace(key, value)
# Out:
# 'scantron ; aw ; surely ; shining ; something ; 88 ; trined ; right ; electric ; coasts ; coast ; tog'

# %%
pre.write_text("data/final_2_pac_rakim_kid_cudi.txt", corrected_text)

# %% [markdown]
# ### From here on, all words that are not contained inside the embedding are mapped to some default value.
# We could use the mean for this or some random value or we could completely omit these values

# %%
import tools.processing as pre

final_text = pre.get_text("data/final_2_pac_rakim_kid_cudi.txt")
final_vocabulary = pre.Vocabulary(final_text)

embedding_weights = get_glove(path, final_vocabulary._dict)

# %%
print( f"recognized words: {len(embedding_weights.keys())} / {len(final_vocabulary._dict.keys())}")
# Out:
# recognized words: 8167 / 8471

# %%
weights = np.array(list(embedding_weights.values()))

# %%
# We have 8167 word vectors of length 300
weights.shape
# Out:
# (8167, 300)

# %% [markdown]
# **The mean word vector is:**

# %%
mean = np.mean(weights, axis=0)
mean
# Out:
# array([-2.46031582e-03, -3.15875886e-03, -2.89881392e-03, -7.44687999e-03,
#         6.34450279e-03, -2.94484664e-04, -8.76065344e-04, -2.65731796e-04,
#        -3.80283082e-03,  1.90850943e-01,  2.54441937e-03, -5.57928160e-03,
#        -1.27946585e-03, -5.77619439e-03, -3.01242387e-03, -2.86886032e-04,
#         1.79459178e-03,  5.95713630e-02,  3.95095791e-04,  1.53345382e-03,
#         1.84276327e-03, -1.13724580e-03,  1.54758431e-03, -2.43751821e-03,
#        -7.36646960e-03, -9.04039852e-03, -1.42165273e-03, -2.53893225e-03,
#         2.21080077e-03, -9.79978684e-03, -4.56522591e-03,  2.03011185e-03,
#        -1.47635275e-02,  4.61883936e-03,  1.91298767e-03, -1.76920241e-03,
#         4.73718578e-03,  9.33369808e-03, -3.47765721e-03,  8.02848767e-03,
#        -3.70021444e-03, -3.09497095e-03, -2.85498798e-03, -2.70495540e-03,
#         4.48540412e-03,  2.27067946e-03,  1.72381569e-03, -3.25393421e-03,
#        -1.36920984e-03,  3.38628376e-03, -1.89377461e-03,  8.39639083e-03,
#        -5.52345673e-03, -1.00098934e-03, -8.69564305e-04,  5.13483956e-03,
#        -2.38230126e-03, -1.74419628e-03,  5.20559913e-03, -6.43798336e-03,
#        -8.06233007e-03, -9.38087818e-04, -3.16870655e-03, -1.19316438e-02,
#        -9.04235523e-04, -3.47260898e-03, -3.68816312e-03, -1.94264017e-03,
#         2.05722707e-03, -9.91074601e-04, -2.68268934e-03, -4.10131318e-03,
#         5.19711105e-03, -1.21963199e-03,  7.83950440e-04, -3.10456194e-03,
#         5.00746351e-03, -7.95814616e-04, -2.59159785e-03,  3.09906760e-03,
#        -3.89000191e-03,  1.74134935e-03, -8.85346532e-03,  2.16530862e-05,
#        -2.58265203e-03,  1.23312138e-03,  6.13212623e-02, -4.62659728e-03,
#         3.50067159e-04,  3.35336314e-03, -5.26126474e-03, -2.10416736e-03,
#        -4.29160008e-03,  4.31093061e-03, -1.77673588e-03,  7.30963890e-03,
#        -4.80436347e-03, -3.98874795e-03, -4.97774128e-03, -2.55229836e-03,
#         1.59740390e-03,  4.50812140e-03,  2.83585605e-03, -1.89794158e-03,
#         6.79938355e-03, -1.78929508e-01,  6.90663699e-03, -2.90573342e-03,
#         1.38556433e-03,  1.48996385e-03,  3.98290996e-03, -4.29159403e-03,
#         3.75405862e-03, -8.32741987e-03, -1.30698620e-03,  7.83897191e-03,
#         1.21447991e-03, -4.84127924e-03, -4.81219171e-03, -3.95686692e-03,
#        -2.00299756e-03, -4.03169915e-03,  8.65758979e-04,  7.04317307e-03,
#         2.72030942e-03, -1.01147798e-05, -5.96063258e-03, -7.28331879e-03,
#        -2.98377679e-04,  1.06651474e-04,  3.24452267e-04, -6.09389925e-03,
#        -5.59422374e-03,  3.46315326e-03,  8.57521407e-03, -2.03506462e-03,
#        -9.02898959e-04,  4.87024011e-03, -7.99486786e-03, -9.56130447e-04,
#        -1.81339025e-01,  4.68139816e-03,  4.20990726e-03, -8.38408188e-04,
#        -3.08325887e-03, -1.81457610e-03,  3.06619611e-03,  8.50405544e-03,
#         7.04649137e-04, -3.49373696e-03, -2.09864741e-03, -1.80292560e-03,
#         7.04448251e-03,  2.63484847e-03, -2.45840114e-04, -1.57822424e-03,
#        -8.52161378e-04, -1.34466756e-02,  1.71951100e-03, -3.81384534e-03,
#        -7.69127859e-04, -2.81566265e-03, -4.97999275e-03,  1.53796505e-02,
#         7.65006244e-03, -8.91633797e-03, -3.33330920e-03, -6.35066477e-04,
#        -4.09977743e-03,  1.90188747e-03, -4.14228905e-03, -2.23193970e-03,
#         1.24446098e-02, -3.53409234e-03,  9.18744423e-04, -1.62696850e-03,
#        -9.98674054e-03,  5.35140687e-04, -1.03554940e-02, -4.84286156e-03,
#         4.72570024e-03,  1.68145262e-03, -1.09764386e-03,  9.46629699e-03,
#         5.85105317e-03,  3.97560000e-03, -1.98830967e-03, -6.53713522e-03,
#         7.16206199e-03,  6.64459402e-03,  8.93345755e-03, -2.58660503e-03,
#        -3.10924370e-03, -5.17363288e-03,  1.08047470e-03,  4.28444613e-03,
#         5.26446011e-03, -4.51069558e-03,  7.84548651e-03, -4.60371654e-03,
#        -5.89054730e-03, -1.78592093e-03, -1.66698860e-03, -6.98705111e-03,
#        -3.83892143e-03, -4.38847020e-03,  3.26808705e-03,  1.50438375e-03,
#         5.35319466e-03, -1.81170891e-03, -6.38176734e-03,  5.86774759e-03,
#         1.32919638e-03,  2.90146843e-03,  3.25348880e-03, -9.23306798e-04,
#         2.97955214e-03,  2.88914377e-03,  1.83214853e-03, -5.67661040e-03,
#         5.67905791e-03, -9.55378579e-04, -5.40436199e-03, -6.81547076e-03,
#        -3.50969657e-03, -7.53248110e-03, -6.81287749e-03,  4.46218438e-03,
#        -5.61990403e-03, -3.74985160e-03, -1.31153746e-03,  4.10688156e-03,
#         2.79463106e-03,  2.47671083e-03, -1.88314018e-03,  6.06841466e-04,
#        -5.66014845e-04, -2.33004498e-03, -4.25262842e-03,  3.86381900e-04,
#        -3.35553568e-03,  3.10471538e-03, -3.70716839e-03, -4.77793910e-05,
#        -4.73026698e-03,  1.63183315e-03, -4.09658253e-03,  1.03264151e-03,
#        -1.82000498e-04,  1.10665690e-02, -5.36706764e-03, -3.33041395e-03,
#        -1.18152145e-03,  8.03002343e-03, -2.76376191e-03, -1.12571230e-03,
#        -2.04277714e-03, -2.10237014e-03, -6.22373540e-03,  9.37374309e-03,
#        -4.95180674e-03,  3.74066387e-03, -5.41122956e-03, -5.65901352e-03,
#         5.02512138e-03,  1.18760625e-02, -3.77943434e-05,  7.63662020e-03,
#        -7.23830843e-03,  1.48697775e-02, -1.24366460e-02, -2.44992110e-03,
#        -9.01224930e-03,  3.55415069e-03, -2.14521118e-04, -2.96517811e-03,
#        -1.22481015e-05, -2.90412945e-03, -9.14994220e-04,  9.57797514e-04,
#         4.07557003e-03, -5.51207410e-03, -4.46167123e-03, -3.19892005e-03,
#         1.63552538e-03,  3.27744219e-03,  1.24731287e-02, -1.13009149e-03,
#        -2.68627726e-03, -5.50793193e-04, -6.52423874e-03, -6.21290179e-03,
#        -3.43628065e-03, -3.71420500e-03,  3.47885164e-03,  1.16058532e-02,
#        -1.51766127e-03,  4.61785821e-03, -6.36126962e-04, -3.23921070e-03],
#       dtype=float32)

# %% [markdown]
# **Let's check what word this would be using the cosine distance**

# %%
def get_closest_words(embedded_word, embedding_dict, limit=10):
    
    embedding_dict.items()
    
    weights = np.array(list(embedding_dict.values()))
    
    cosine_dists = np.dot( weights, embedded_word)
    ff = np.argsort(cosine_dists)[::-1][:limit]
    
    words = list(embedding_dict.keys())
    index2word_map = dict( (key, value) for (key, value) in enumerate(words) )
    
    words = []
    distance = []
    for f in ff:
        words.append(index2word_map[f])
        distance.append(cosine_dists[f])
    
    return list(zip(words, distance))

get_closest_words(mean, embedding_weights)
# Out:
# [('even', 0.25623482),
#  ('nothing', 0.25214267),
#  ('somehow', 0.24717022),
#  ('imagine', 0.24696591),
#  ('whatever', 0.24661142),
#  ('they', 0.24656454),
#  ('hardly', 0.24625331),
#  ('rather', 0.24608666),
#  ('so', 0.2456822),
#  ('enough', 0.2448145)]

# %%
get_closest_words(embedding_weights[';'], embedding_weights)
# Out:
# [(';', 1.0000001),
#  ('and', 0.50414),
#  ('as', 0.4537127),
#  ('which', 0.41770586),
#  ('while', 0.41335005),
#  ('shall', 0.4117339),
#  ('or', 0.41107875),
#  ('others', 0.40873516),
#  ('except', 0.376888),
#  ('but', 0.3727518)]

# %% [markdown]
# # We will export these embedding related functions into the package tools.embedding

# %% [markdown]
# ## Let's put these embeddings into action and test them for our rap text
