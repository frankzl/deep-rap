# %%
import tools.processing as pre
text = pre.get_text("data/cleaned-rap-lyrics/clean2_pac.txt")

CONTRACTION_MAP = {"'em":"them","y'know": "you know", "'hem": "them",                   
                   "c'mon": "come on", "'caine": "cocaine",
                   "mo'": "my", "cha'": "ya", "'cha": "ya",
                   "whaddya": "what do ya", "nuttin": "nothing",
                   "thru": "through",
                   "shoulda": "should have",
                   "lets": "let us", "let's": "let us",
                   "'til": "until", "outta": "out of", "i'ma": "i am a", "tho'": "though","til'": "until",
                   "'im": "him", "'bout": "about", "'n": "and", "tha'": "the", "tu'": "to",
                   "uz'": "daheck?", "yo'": "your", "witcha": "with ya",
                   "'tack": "attack", "'head": "ahead", "lil'": "little", "getcha": "get ya",
                   "wit'chu": "with you", "get'cha": "get ya", "sweatcha": "sweat ya", "e'ry": "every",
                   "what'cha": "what ya", "hitcha": "hit ya", "gov'na": "governor", "'fore": "before",
                   "mill'": "million", "ain't": "is not", "aren't": "are not","can't": "can not", 
                   "can't've": "can not have", "'cause": "because", "could've": "could have", 
                   "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
                   "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
                   "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
                   "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
                   "he'll've": "he he will have", "he's": "he is", "how'd": "how did", 
                   "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
                   "i'd": "i would", "i'd've": "i would have", "i'll": "i will",
                   "i'll've": "i will have","i'm": "i am", "i've": "i have", 
                   "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
                   "i'll've": "i will have","i'm": "i am", "i've": "i have", 
                   "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
                   "it'll": "it will", "it'll've": "it will have","it's": "it is", 
                   "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
                   "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
                   "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
                   "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", "why'd": "why did",
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have", 
                   "gon'": "going to",
                   "an'": "and"
                  }

# %% [markdown]
# # Step 1: Cleaning the data
#
# We need to correct typos such as "imdamcwitdenastymouf" = "i am the mc with the nasty mouth"

# %%
import re


remove_lbreak = text.replace("\n", " ; ")
remove_space  = re.sub(" +", " ", remove_lbreak)

remove_space = remove_space.replace("'ll ", " will ")
remove_space = remove_space.replace("'ve ", " have ")
remove_space = remove_space.replace(" u ", " you ")
remove_space = remove_space.replace(" youre ", " you are ")
remove_space = remove_space.replace(" n ", " and ")
remove_space = remove_space.replace(" de ", " the ")
remove_space = remove_space.replace(" gon ", " going to ")

def expand_contractions(sentence, contraction_mapping):
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)
        return expanded_contraction
        
    expanded_sentence = contractions_pattern.sub(expand_match, sentence)
    return expanded_sentence


expanded = expand_contractions(remove_space, CONTRACTION_MAP)
expanded = expanded.replace("'s ", " 's ")
expanded = expanded.replace("s'", " 's ")
expanded = expanded.replace("in'", "ing")
expanded = expanded.replace("'ll", " will")
expanded = expanded.replace("mutha", "mother")
expanded = expanded.replace("en'", "ing")
expanded = expanded.replace("brotha", "brother")
# expanded = expanded.replace("outta", "out of")
expanded = expanded.replace("2pac", "tupac")
print(expanded[:1000])
# Out:
# as real as it seems the american dream ; is not nothing but another calculated schemes ; to get us locked up shot up back in chains ; to deny us of the future rob our names ; kept my history of mystery but now i see ; the american dream was not meant for me ; cause lady liberty is a hypocrite she lied to me ; promised me freedom education equality ; never gave me nothing but slavery ; and now look at how dangerous you made me ; calling me a mad man cause i am strong and bold ; with this dump full of knowledge of the lies you told ; promise me emancipation indispute nation ; all you gave my people was our patience ; fathers of our country never cared for me ; they kept my answer shackled up in slavery ; and uncle sam never did a damn thing for me ; except lie about the facts in my history ; so now i am sitting here mad cause i am unemployed ; but the government 's glad cause they enjoyed ; when my people are down so they can screw us around ; time to change the government now panther po

# %%
_dict = pre.Vocabulary(expanded)
t = "\n".join(_dict._keys)
pre.write_text("data/my_dict.txt", t)

# %% [markdown]
# # Step 2: Building a dictionary
# We load the found distinct words into a txt file *data/my_dict.txt*
#
# We slowly build up the dictionary from the given text to make sure we don't accept any typos

# %%
text_dict = pre.get_text("data/my_dict.txt")
_dict = pre.Vocabulary(text_dict)

next = True

startIdx = 0
print("The text has been loaded. Build up the dictionary slowly by scanning through the text bit by bit")
startIdx = int( input("Enter index where you want to start") )

print(startIdx)

step_size = 200

all_words = expanded.split(" ")

while startIdx < len(all_words): 
    vocab = all_words[startIdx: startIdx + step_size]
    new_words = list( (set(vocab) - (set(_dict._keys))) )
    
    print(f"startIDX: {startIdx}")
    print(new_words)
    
    user = input("accept? y/n")
    while (user == "n"):
        repl = input("replace word: ")
        sub  = input("substitute: ")
        new_words [ new_words.index(repl) ] = sub
        print(new_words)
        user = input("accept? y/n")
        
    if(user == "break"):
        break
        
    total = sorted( new_words + _dict._keys )
    
    _dict = pre.Vocabulary(" ".join(total))
    
    startIdx += step_size
    
print(" ".join(total))
# Out:
# The text has been loaded. Build up the dictionary slowly by scanning through the text bit by bit
# Enter index where you want to start 0
# 0
# startIDX: 0
# ['fathers', 'when', 'down', 'about', 'are', 'uncle', 'answer', 'sam', 'sitting', 'screw', 'enjoyed', 'government', 'they', 'country', 'here', 'so', 'shackled', 'did', 'cared', 'glad', 'unemployed', 'lie', 'damn', 'thing', 'facts', 'can', 'patience', "'s", 'except', 'around']
# accept? y/n y
# startIDX: 200
# ['take', 'fame', 'rich', 'more', 'sell', 'resides', 'put', 'tried', 'think', 'just', 'let', 'forget', 'coming', 'toe', 'less', 'other', 'fight', 'nightmare', 'know', 'or', 'community', 'klu-klux-klan', 'outs', 'poor', 'besides', 'true', 'skin', 'had', 'free', 'could', 'fair', 'sneak', 'no', 'segregation', 'richer', 'time', 'be', 'unity', 'settle', 'win', 'power', 'statistic', 'go', 'survive', 'rest', 'yell', 'suppressed', 'ignorant', 'than', 'using', 'blacks', 'dead', 'intimidation', 'within', 'then', 'drew', 'bats', 'change', 'on', 'capitalistic', 'refuse', 'set', 'were', 'allowed', 'will', 'straight', 'wanted', 'being', 'suffered', 'keep', 'an', 'attack', 'hoping', 'impatient', 'panther', 'way', 'that', 'drugs', 'out', 'hold', 'mother']
# accept? y/n y
# startIDX: 400
# ['remember', 'name', 'laugh', 'arteries', 'seem', 'stole', 'eyes', 'open', 'clawed', 'there', 'immunity', 'civilized', 'some', 'strike', 'breath', 'like', 'has', 'hard', 'panter', 'america', 'we', 'been', 'your', 'passed', 'living', 'realize', 'dying', 'yet', 'charged', 'try', 'said', 'running', 'do', 'fighting', 'claim', 'what', 'death', 'have', 'boy', 'oh', 'asking', 'disease', 'them', 'through', 'stop', 'case']
# accept? y/n y
# startIDX: 600
# ['sleepin', 'tired', 'wasnt', 'dj', '2pac', 'corrections', 'happened', 'mic', 'whats', 'long', 'woke', 'grip', 'sick', 'gone', 'bizzy', 'finally', 'its', 'typist', 'feeling', 'brotha', 'wrong', 'send', 'hear']
# accept? y/n n
# replace word:  sleepin
# substitute:  sleeping
# ['sleeping', 'tired', 'wasnt', 'dj', '2pac', 'corrections', 'happened', 'mic', 'whats', 'long', 'woke', 'grip', 'sick', 'gone', 'bizzy', 'finally', 'its', 'typist', 'feeling', 'brotha', 'wrong', 'send', 'hear']
# accept? y/n n
# replace word:  wasnt
# substitute:  was
# ['sleeping', 'tired', 'was', 'dj', '2pac', 'corrections', 'happened', 'mic', 'whats', 'long', 'woke', 'grip', 'sick', 'gone', 'bizzy', 'finally', 'its', 'typist', 'feeling', 'brotha', 'wrong', 'send', 'hear']
# accept? y/n n
# replace word:  2pac
# substitute:  tupac
# ['sleeping', 'tired', 'was', 'dj', 'tupac', 'corrections', 'happened', 'mic', 'whats', 'long', 'woke', 'grip', 'sick', 'gone', 'bizzy', 'finally', 'its', 'typist', 'feeling', 'brotha', 'wrong', 'send', 'hear']
# accept? y/n n
# replace word:  brotha
# substitute:  brother
# ['sleeping', 'tired', 'was', 'dj', 'tupac', 'corrections', 'happened', 'mic', 'whats', 'long', 'woke', 'grip', 'sick', 'gone', 'bizzy', 'finally', 'its', 'typist', 'feeling', 'brother', 'wrong', 'send', 'hear']
# accept? y/n y
# startIDX: 800
# ['smoking', 'might', 'clue', 'tms', 'nimth', 'until', 'mouth', 'rock', 'myself', 'paniced', 'use', 'got', 'every', 'health', 'want', 'street', 'house', 'microphone', 'he', 'im', 'strength', 'ya', 'crew', 'battle', 'without', 'guaranteed', 'find', 'stumped', 'over', 'wurd', 'word', 'whipped', 'phone', 'busy', 'first', 'rockin', 'bad', 'picked', 'dizzy', 'musical', 'called', 'mics', 'cigarettes', 'if', 'hit', '6', 'trace', 'sure', 'unbelievable', 'beat', 'cops', 'comes', 'yo', 'before', 'onetwo', 'rhymes']
# accept? y/n n
# replace word:  paniced
# substitute:  panicked
# ['smoking', 'might', 'clue', 'tms', 'nimth', 'until', 'mouth', 'rock', 'myself', 'panicked', 'use', 'got', 'every', 'health', 'want', 'street', 'house', 'microphone', 'he', 'im', 'strength', 'ya', 'crew', 'battle', 'without', 'guaranteed', 'find', 'stumped', 'over', 'wurd', 'word', 'whipped', 'phone', 'busy', 'first', 'rockin', 'bad', 'picked', 'dizzy', 'musical', 'called', 'mics', 'cigarettes', 'if', 'hit', '6', 'trace', 'sure', 'unbelievable', 'beat', 'cops', 'comes', 'yo', 'before', 'onetwo', 'rhymes']
# accept? y/n n
# replace word:  im
# substitute:  i
# ['smoking', 'might', 'clue', 'tms', 'nimth', 'until', 'mouth', 'rock', 'myself', 'panicked', 'use', 'got', 'every', 'health', 'want', 'street', 'house', 'microphone', 'he', 'i', 'strength', 'ya', 'crew', 'battle', 'without', 'guaranteed', 'find', 'stumped', 'over', 'wurd', 'word', 'whipped', 'phone', 'busy', 'first', 'rockin', 'bad', 'picked', 'dizzy', 'musical', 'called', 'mics', 'cigarettes', 'if', 'hit', '6', 'trace', 'sure', 'unbelievable', 'beat', 'cops', 'comes', 'yo', 'before', 'onetwo', 'rhymes']
# accept? y/n y
# startIDX: 1000
# ['leather', 'head', 'signaled', 'hop', 'sucka', 'happy', 'would', 'drop', 'should', 'strictly', 'confident', 'forced', 'shivered', 'bust', 'fell', 'jacket', 'walked', 'begin', 'tasted', 'payin', 'pocket', 'grabbed', 'wit', 'loose', 'prove', 'lucky', 'why', 'hyped', 'hopin', 'dumb', 'play', 'dope', 'rhyme', 'streets', 'going', 'boss', 'perpetrator', 'because', 'hand', 'hell', 'ready', 'night', 'came', 'give', 'ha', 'where', 'defeat', 'from', 'lost', 'stage', 'started']
# accept? y/n n
# replace word:  sucka
# substitute:  sucker
# ['leather', 'head', 'signaled', 'hop', 'sucker', 'happy', 'would', 'drop', 'should', 'strictly', 'confident', 'forced', 'shivered', 'bust', 'fell', 'jacket', 'walked', 'begin', 'tasted', 'payin', 'pocket', 'grabbed', 'wit', 'loose', 'prove', 'lucky', 'why', 'hyped', 'hopin', 'dumb', 'play', 'dope', 'rhyme', 'streets', 'going', 'boss', 'perpetrator', 'because', 'hand', 'hell', 'ready', 'night', 'came', 'give', 'ha', 'where', 'defeat', 'from', 'lost', 'stage', 'started']
# accept? y/n n
# replace word:  payin
# substitute:  paying
# ['leather', 'head', 'signaled', 'hop', 'sucker', 'happy', 'would', 'drop', 'should', 'strictly', 'confident', 'forced', 'shivered', 'bust', 'fell', 'jacket', 'walked', 'begin', 'tasted', 'paying', 'pocket', 'grabbed', 'wit', 'loose', 'prove', 'lucky', 'why', 'hyped', 'hopin', 'dumb', 'play', 'dope', 'rhyme', 'streets', 'going', 'boss', 'perpetrator', 'because', 'hand', 'hell', 'ready', 'night', 'came', 'give', 'ha', 'where', 'defeat', 'from', 'lost', 'stage', 'started']
# accept? y/n n
# replace word:  hopin
# substitute:  hoping
# ['leather', 'head', 'signaled', 'hop', 'sucker', 'happy', 'would', 'drop', 'should', 'strictly', 'confident', 'forced', 'shivered', 'bust', 'fell', 'jacket', 'walked', 'begin', 'tasted', 'paying', 'pocket', 'grabbed', 'wit', 'loose', 'prove', 'lucky', 'why', 'hyped', 'hoping', 'dumb', 'play', 'dope', 'rhyme', 'streets', 'going', 'boss', 'perpetrator', 'because', 'hand', 'hell', 'ready', 'night', 'came', 'give', 'ha', 'where', 'defeat', 'from', 'lost', 'stage', 'started']
# accept? y/n y
# startIDX: 1200
# ['reason', 'die', 'lives', 'tricks', 'build', 'end', 'must', 'cell', 'friend', 'backstab', 'thinking', 'suckers', 'dropped', 'communities', 'mission', 'mind', 'top', 'trick', 'past', 'soul', 'rocking', 'come', 'fake', 'grab', 'cream', 'pin', 'crop', 'wink', 'his', 'by', 'opposition', 'excel', 'sold', 'hole', 'move', 'sweated', 'brothers', 'only', 'cry', 'gold']
# accept? y/n y
# startIDX: 1400
# ['reach', 'proud', 'mountain', 'thought', 'black', 'toast', 'calm', 'folks', 'educated', 'too', 'who', 'source', 'teach', 'loving', 'hearing', 'aiyyo', 'preach', 'stay', 'hated', 'putting', 'scared', 'wondering', 'tossed', 'stopping', 'suffocate', 'caught', 'dilly', 'sweating', 'write', 'ay', 'many', 'boom', 'dropping', 'gets', 'napalm', 'force', 'always', 'bomb', 'constantly', 'nervous', 'dose', 'building', 'listen', 'fact', 'bite', 'buying', 'close', 'simple', 'hype', 'checking', 'flavor', 'ballers']
# accept? y/n y
# startIDX: 1600
# ['bass', 'god', 'girls', 'busting', 'truck', 'base', 'adversaries', 'mediocrity', 'speakers', 'neccessary', 'security', 'defeated', 'scary', 'stricly', 'breathe', 'deal', 'vote', 'pop', 'minute', 'means', 'steal', 'drops', 'present', 'jump', 'intro', 'guerilla', 'lonely', 'larger', 'any', 'waiting', 'damaged', 'beats', 'titan', 'makes', 'pumps', 'control', 'run', 'hands', 'kind', 'jealous', 'appealed', 'chance', 'leader', 'pay', 'conceited', 'goal', 'amateurs']
# accept? y/n y
# startIDX: 1800
# ['huh', 'kidding', 'fast', 'ray', 'stepping', 'fumble', 'fool', 'together', 'better', 'girl', 'care', 'bragging', 'tumble', 'swear', 'light', 'mine', 'born', 'still', 'weapon', 'well', 'tyson', 'gonna', 'since', 'good', 'playing', 'capable', 'battling', 'anywhere', 'slow', 'place', 'one', 'competition', 'her', 'knew', 'yourself']
# accept? y/n y
# startIDX: 2000
# ['troop', 'pant', 'fuck', 'caution', 'battles', 'scarred', 'puff', 'trap', 'deadly', 'cannot', 'veteran', 'holds', 'stopped', 'holding', 'piece', 'vocalist', 'ass', 'most', 'recoup', 'yeast', 'rising', 'anybody', 'rope', 'feel', 'rumble', 'beast', 'inside', 'eat', 'musician', 'lock', 'discouraged', 'others', 'climb', 'fall', 'wrath', 'burnt', 'vicious', 'competitor', 'predator', 'musically', 'forever', 'boldy', 'into', 'toss', 'barred', 'raw', 'success', 'sentry', 'consoloist', 'step', 'proceed', 'salad']
# accept? y/n y
# startIDX: 2200
# ['lesson', 'exact', 'silly', 'upset', 'ant', 'stomped', 'body', 'tracks', 'punk', 'game', 'proven', 'getting', 'things', 'choke', 'diss', 'letting', 'drano', 'cordless', 'hawalian', 'wheels', 'tying', 'making', 'worst', 'moving', 'volcano', 'pull', 'tight', 'grooving', 'paid', 'freddy', 'blowing', 'motherfucker']
# accept? y/n y
# startIDX: 2400
# ['played', 'chilling', 'loading', 'paragraph', 'burn', 'freaks', 'make', 'shoot', 'baseball', 'habit', 'daddio', 'useless', 'mac', 'tons', 'ooh', 'piranha', 'motherfucking', 'uzi', 'moves', 'wanna', 'funky', 'toothless', 'ear', 'discuss', 'ruthless', 'penetrating', 'while', 'jams', 'destroyed', 'bullet', 'radiation', 'toy', 'harmed', 'face', 'quick', 'lyrics', 'taste', 'armed', 'writing', 'bat', 'stand', 'def', 'nuclear', 'patio', 'homeboy']
# accept? y/n n
# replace word:  ooh
# substitute:  oh
# ['played', 'chilling', 'loading', 'paragraph', 'burn', 'freaks', 'make', 'shoot', 'baseball', 'habit', 'daddio', 'useless', 'mac', 'tons', 'oh', 'piranha', 'motherfucking', 'uzi', 'moves', 'wanna', 'funky', 'toothless', 'ear', 'discuss', 'ruthless', 'penetrating', 'while', 'jams', 'destroyed', 'bullet', 'radiation', 'toy', 'harmed', 'face', 'quick', 'lyrics', 'taste', 'armed', 'writing', 'bat', 'stand', 'def', 'nuclear', 'patio', 'homeboy']
# accept? y/n y
# startIDX: 2600
# ['maxium', 'melody', 'woofers', 'thumping', 'rhymefumble', 'bird', 'overload', 'large', 'dilate', 'voice', 'mysterious', 'heard', 'humming', 'stomping', 'speaker', 'thunder', 'wiz', 'young', 'stretch', 'expand', 'hood', 'charge', 'explode', 'countless', 'needle', 'hiphop', 'ears', 'furious', 'record', 'mister', 'nuance', 'conisseur', 'poetry', 'prodigy', 'phd', 'serious', 'clever', 'stuck', 'after', 'drums']
# accept? y/n n
# replace word:  maxium
# substitute:  maximum
# ['maximum', 'melody', 'woofers', 'thumping', 'rhymefumble', 'bird', 'overload', 'large', 'dilate', 'voice', 'mysterious', 'heard', 'humming', 'stomping', 'speaker', 'thunder', 'wiz', 'young', 'stretch', 'expand', 'hood', 'charge', 'explode', 'countless', 'needle', 'hiphop', 'ears', 'furious', 'record', 'mister', 'nuance', 'conisseur', 'poetry', 'prodigy', 'phd', 'serious', 'clever', 'stuck', 'after', 'drums']
# accept? y/n y
# startIDX: 2800
# ['roc', 'outro', 'check']
# accept? y/n y
# startIDX: 3000
# ['car', 'lagging', 'wonder', 'broke', 'backing', 'diz', 'center', 'talking', '2pac', 'team', 'illing', 'limbwalk', 'big', 'sagging', 'posse', 'park', 'west', 'outside', 'till', 'postal', 'boys', 'kick', 'lightweight', 'cruiser', 'understand', 'toughest', 'box', 'bringing', 'say', 'slack', 'e', 'old', 'life', 'winners', 'noise', 'levi', 'cheat', 'twenty', 'choose', 'rolled', 'stepped', 'pad', 'border', 'day', 'hoop', 'side', 'neck', 'ten', 'smacking', 'live', 'handle']
# accept? y/n n
# replace word:  2pac
# substitute:  tupac
# ['car', 'lagging', 'wonder', 'broke', 'backing', 'diz', 'center', 'talking', 'tupac', 'team', 'illing', 'limbwalk', 'big', 'sagging', 'posse', 'park', 'west', 'outside', 'till', 'postal', 'boys', 'kick', 'lightweight', 'cruiser', 'understand', 'toughest', 'box', 'bringing', 'say', 'slack', 'e', 'old', 'life', 'winners', 'noise', 'levi', 'cheat', 'twenty', 'choose', 'rolled', 'stepped', 'pad', 'border', 'day', 'hoop', 'side', 'neck', 'ten', 'smacking', 'live', 'handle']
# accept? y/n n
# replace word:  illing
# substitute:  killing
# ['car', 'lagging', 'wonder', 'broke', 'backing', 'diz', 'center', 'talking', 'tupac', 'team', 'killing', 'limbwalk', 'big', 'sagging', 'posse', 'park', 'west', 'outside', 'till', 'postal', 'boys', 'kick', 'lightweight', 'cruiser', 'understand', 'toughest', 'box', 'bringing', 'say', 'slack', 'e', 'old', 'life', 'winners', 'noise', 'levi', 'cheat', 'twenty', 'choose', 'rolled', 'stepped', 'pad', 'border', 'day', 'hoop', 'side', 'neck', 'ten', 'smacking', 'live', 'handle']
# accept? y/n y
# startIDX: 3200
# ['aggravating', 'three', 'crazy', 'outta', '2pac', 'shower', 'late', 'alone', 'monday', 'morning', 'shocks', 'bit', 'glue', 'brush', 'school', 'show', 'frustrations', 'salutations', 'little', 'matress', 'bed', 'stinking', 'teeth', 'disturbing', 'ring', 'speaking', 'leave', 'roct', 'michael', 'him', 'ahead', 'half', 'vacation', 'lay', 'tone']
# accept? y/n y
# startIDX: 3400
# ['really', 'enough', 'cute', 'rapping', 'hour', 'hits', 'turn', 'two', 'clapping', 'tip', 'clothes', 'introduction', 'limo', 'bodygurad', 'audience', 'jumped', 'air', 'sweatsuit', 'backstage', 'crowd', 'scene', 'colessium', 'everywhere', 'macking', 'moved', 'sweat', 'loud', 'white', 'fans', 'fresh', 'off', 'wait', 'start', 'spare', 'screaming', 'tear', 'trying', 'minutes', 'barely', 'party', 'rolling', 'new', 'finish']
# accept? y/n n
# replace word:  colessium
# substitute:  colesseum
# ['really', 'enough', 'cute', 'rapping', 'hour', 'hits', 'turn', 'two', 'clapping', 'tip', 'clothes', 'introduction', 'limo', 'bodygurad', 'audience', 'jumped', 'air', 'sweatsuit', 'backstage', 'crowd', 'scene', 'colesseum', 'everywhere', 'macking', 'moved', 'sweat', 'loud', 'white', 'fans', 'fresh', 'off', 'wait', 'start', 'spare', 'screaming', 'tear', 'trying', 'minutes', 'barely', 'party', 'rolling', 'new', 'finish']
# accept? y/n n
# replace word:  colesseum
# substitute:  colosseum
# ['really', 'enough', 'cute', 'rapping', 'hour', 'hits', 'turn', 'two', 'clapping', 'tip', 'clothes', 'introduction', 'limo', 'bodygurad', 'audience', 'jumped', 'air', 'sweatsuit', 'backstage', 'crowd', 'scene', 'colosseum', 'everywhere', 'macking', 'moved', 'sweat', 'loud', 'white', 'fans', 'fresh', 'off', 'wait', 'start', 'spare', 'screaming', 'tear', 'trying', 'minutes', 'barely', 'party', 'rolling', 'new', 'finish']
# accept? y/n n
# replace word:  macking
# substitute:  smacking
# ['really', 'enough', 'cute', 'rapping', 'hour', 'hits', 'turn', 'two', 'clapping', 'tip', 'clothes', 'introduction', 'limo', 'bodygurad', 'audience', 'jumped', 'air', 'sweatsuit', 'backstage', 'crowd', 'scene', 'colosseum', 'everywhere', 'smacking', 'moved', 'sweat', 'loud', 'white', 'fans', 'fresh', 'off', 'wait', 'start', 'spare', 'screaming', 'tear', 'trying', 'minutes', 'barely', 'party', 'rolling', 'new', 'finish']
# accept? y/n y
# startIDX: 3600
# ['tipsy', 'floor', 'violence', 'cutie', 'signing', 'stumbled', 'sexual', 'hate', 'dance', 'looking', 'disco', 'autographs', 'pen', 'sipping', 'mean', 'totions', 'neighborhood', 'motion', 'age', 'positive', 'seventeen', 'silence', 'cooling', 'sit', 'cisco', 'girlies', 'door', 'whole', 'limousine', 'keeps', 'paper']
# accept? y/n y
# startIDX: 3800
# ['teenage', 'emcee', 'liar', 'call', 'favorite', 'redeem', 'error', 'rap', 'spin', 'begins', 'room', 'inflation', 'feels', 'high', 'genius', 'whack', 'seen', 'style', 'starts', 'terror', 'desire', 'soon', 'scare', 'pass', 'value', 'beside', 'forte', 'each', 'emcees', 'illtrip', 'awake', 'right', 'dissing', 'tonight', 'ama', 'station', 'admire', "wit'", 'hoods', 'playfully', 'stomach', 'kiss', 'recreation', 'type', 'ladies', 'hypetip', 'avoid', 'hoe']
# accept? y/n n
# replace word:  emcee
# substitute:  emcee
# ['teenage', 'emcee', 'liar', 'call', 'favorite', 'redeem', 'error', 'rap', 'spin', 'begins', 'room', 'inflation', 'feels', 'high', 'genius', 'whack', 'seen', 'style', 'starts', 'terror', 'desire', 'soon', 'scare', 'pass', 'value', 'beside', 'forte', 'each', 'emcees', 'illtrip', 'awake', 'right', 'dissing', 'tonight', 'ama', 'station', 'admire', "wit'", 'hoods', 'playfully', 'stomach', 'kiss', 'recreation', 'type', 'ladies', 'hypetip', 'avoid', 'hoe']
# accept? y/n y
# startIDX: 4000
# ['much', 'words', 'situation', 'sleepin', 'purity', 'closer', 'guilty', 'second', 'stronger', 'blind', 'contact', 'fallin', 'filled', 'men', 'confused', 'does', 'obvious', 'longer', 'leaves', 'stare', 'thinkin', 'touch', 'trustin', 'offers', 'feelin', 'thoughts', 'posessed', 'undressin', 'muttered', 'offer', 'heart', 'stutter', 'lot', 'drink', 'shake', 'passion', 'nowin', 'these', 'girlfriend', 'temptation', 'sweaty', 'eye', 'sinkin', 'kinda', 'best', 'wake', 'gotten']
# accept? y/n n
# replace word:  sleepin
# substitute:  sleeping
# ['much', 'words', 'situation', 'sleeping', 'purity', 'closer', 'guilty', 'second', 'stronger', 'blind', 'contact', 'fallin', 'filled', 'men', 'confused', 'does', 'obvious', 'longer', 'leaves', 'stare', 'thinkin', 'touch', 'trustin', 'offers', 'feelin', 'thoughts', 'posessed', 'undressin', 'muttered', 'offer', 'heart', 'stutter', 'lot', 'drink', 'shake', 'passion', 'nowin', 'these', 'girlfriend', 'temptation', 'sweaty', 'eye', 'sinkin', 'kinda', 'best', 'wake', 'gotten']
# accept? y/n n
# replace word:  fallin
# substitute:  falling
# ['much', 'words', 'situation', 'sleeping', 'purity', 'closer', 'guilty', 'second', 'stronger', 'blind', 'contact', 'falling', 'filled', 'men', 'confused', 'does', 'obvious', 'longer', 'leaves', 'stare', 'thinkin', 'touch', 'trustin', 'offers', 'feelin', 'thoughts', 'posessed', 'undressin', 'muttered', 'offer', 'heart', 'stutter', 'lot', 'drink', 'shake', 'passion', 'nowin', 'these', 'girlfriend', 'temptation', 'sweaty', 'eye', 'sinkin', 'kinda', 'best', 'wake', 'gotten']
# accept? y/n n
# replace word:  thinkin
# substitute:  thinking
# ['much', 'words', 'situation', 'sleeping', 'purity', 'closer', 'guilty', 'second', 'stronger', 'blind', 'contact', 'falling', 'filled', 'men', 'confused', 'does', 'obvious', 'longer', 'leaves', 'stare', 'thinking', 'touch', 'trustin', 'offers', 'feelin', 'thoughts', 'posessed', 'undressin', 'muttered', 'offer', 'heart', 'stutter', 'lot', 'drink', 'shake', 'passion', 'nowin', 'these', 'girlfriend', 'temptation', 'sweaty', 'eye', 'sinkin', 'kinda', 'best', 'wake', 'gotten']
# accept? y/n n
# replace word:  trustin
# substitute:  trusting
# ['much', 'words', 'situation', 'sleeping', 'purity', 'closer', 'guilty', 'second', 'stronger', 'blind', 'contact', 'falling', 'filled', 'men', 'confused', 'does', 'obvious', 'longer', 'leaves', 'stare', 'thinking', 'touch', 'trusting', 'offers', 'feelin', 'thoughts', 'posessed', 'undressin', 'muttered', 'offer', 'heart', 'stutter', 'lot', 'drink', 'shake', 'passion', 'nowin', 'these', 'girlfriend', 'temptation', 'sweaty', 'eye', 'sinkin', 'kinda', 'best', 'wake', 'gotten']
# accept? y/n n
# replace word:  undressin
# substitute:  undressing
# ['much', 'words', 'situation', 'sleeping', 'purity', 'closer', 'guilty', 'second', 'stronger', 'blind', 'contact', 'falling', 'filled', 'men', 'confused', 'does', 'obvious', 'longer', 'leaves', 'stare', 'thinking', 'touch', 'trusting', 'offers', 'feelin', 'thoughts', 'posessed', 'undressing', 'muttered', 'offer', 'heart', 'stutter', 'lot', 'drink', 'shake', 'passion', 'nowin', 'these', 'girlfriend', 'temptation', 'sweaty', 'eye', 'sinkin', 'kinda', 'best', 'wake', 'gotten']
# accept? y/n n
# replace word:  feelin
# substitute:  feeling
# ['much', 'words', 'situation', 'sleeping', 'purity', 'closer', 'guilty', 'second', 'stronger', 'blind', 'contact', 'falling', 'filled', 'men', 'confused', 'does', 'obvious', 'longer', 'leaves', 'stare', 'thinking', 'touch', 'trusting', 'offers', 'feeling', 'thoughts', 'posessed', 'undressing', 'muttered', 'offer', 'heart', 'stutter', 'lot', 'drink', 'shake', 'passion', 'nowin', 'these', 'girlfriend', 'temptation', 'sweaty', 'eye', 'sinkin', 'kinda', 'best', 'wake', 'gotten']
# accept? y/n n
# replace word:  sinkin
# substitute:  sinking
# ['much', 'words', 'situation', 'sleeping', 'purity', 'closer', 'guilty', 'second', 'stronger', 'blind', 'contact', 'falling', 'filled', 'men', 'confused', 'does', 'obvious', 'longer', 'leaves', 'stare', 'thinking', 'touch', 'trusting', 'offers', 'feeling', 'thoughts', 'posessed', 'undressing', 'muttered', 'offer', 'heart', 'stutter', 'lot', 'drink', 'shake', 'passion', 'nowin', 'these', 'girlfriend', 'temptation', 'sweaty', 'eye', 'sinking', 'kinda', 'best', 'wake', 'gotten']
# accept? y/n y
# startIDX: 4200
# ['departed', 'need', 'prolonged', 'sayin', 'fire', 'caress', 'burnin', 'angel', 'affair', 'wet', 'beach', 'pretend', 'treat', 'suffer', 't', 'walkin', 'casanova', 'tender', 'smart', 'seein', 'rougher', 'bein', 'warm', 'sad', 'sweet', 'peach', 'buy', 'callin', 'broken', 'along', 'desires', 'surrender', 'gettin', 'baby', 'love', 'anything']
# accept? y/n n
# replace word:  sayin
# substitute:  saying
# ['departed', 'need', 'prolonged', 'saying', 'fire', 'caress', 'burnin', 'angel', 'affair', 'wet', 'beach', 'pretend', 'treat', 'suffer', 't', 'walkin', 'casanova', 'tender', 'smart', 'seein', 'rougher', 'bein', 'warm', 'sad', 'sweet', 'peach', 'buy', 'callin', 'broken', 'along', 'desires', 'surrender', 'gettin', 'baby', 'love', 'anything']
# accept? y/n n
# replace word:  burnin
# substitute:  burning
# ['departed', 'need', 'prolonged', 'saying', 'fire', 'caress', 'burning', 'angel', 'affair', 'wet', 'beach', 'pretend', 'treat', 'suffer', 't', 'walkin', 'casanova', 'tender', 'smart', 'seein', 'rougher', 'bein', 'warm', 'sad', 'sweet', 'peach', 'buy', 'callin', 'broken', 'along', 'desires', 'surrender', 'gettin', 'baby', 'love', 'anything']
# accept? y/n n
# replace word:  seein
# substitute:  seeing
# ['departed', 'need', 'prolonged', 'saying', 'fire', 'caress', 'burning', 'angel', 'affair', 'wet', 'beach', 'pretend', 'treat', 'suffer', 't', 'walkin', 'casanova', 'tender', 'smart', 'seeing', 'rougher', 'bein', 'warm', 'sad', 'sweet', 'peach', 'buy', 'callin', 'broken', 'along', 'desires', 'surrender', 'gettin', 'baby', 'love', 'anything']
# accept? y/n n
# replace word:  gettin
# substitute:  getting
# ['departed', 'need', 'prolonged', 'saying', 'fire', 'caress', 'burning', 'angel', 'affair', 'wet', 'beach', 'pretend', 'treat', 'suffer', 't', 'walkin', 'casanova', 'tender', 'smart', 'seeing', 'rougher', 'bein', 'warm', 'sad', 'sweet', 'peach', 'buy', 'callin', 'broken', 'along', 'desires', 'surrender', 'getting', 'baby', 'love', 'anything']
# accept? y/n n
# replace word:  callin
# substitute:  calling
# ['departed', 'need', 'prolonged', 'saying', 'fire', 'caress', 'burning', 'angel', 'affair', 'wet', 'beach', 'pretend', 'treat', 'suffer', 't', 'walkin', 'casanova', 'tender', 'smart', 'seeing', 'rougher', 'bein', 'warm', 'sad', 'sweet', 'peach', 'buy', 'calling', 'broken', 'along', 'desires', 'surrender', 'getting', 'baby', 'love', 'anything']
# accept? y/n y
# startIDX: 4400
# ['next', 'casue', 'reality', 'seconds', 'fiend', 'conceal', 'world', 'fantasizin', 'help', 'passionately', 'matter', 'met', 'heavily', 'clockin', 'watched', 'both', 'bond', 'swears', 'totally', 'times', 'desperately', 'watchin', 'already', 'trapped', 'addiction', 'position', 'looks', 'reinforce', 'role', 'curve', 'tounge', 'tied']
# accept? y/n n
# replace word:  casue
# substitute:  cause
# ['next', 'cause', 'reality', 'seconds', 'fiend', 'conceal', 'world', 'fantasizin', 'help', 'passionately', 'matter', 'met', 'heavily', 'clockin', 'watched', 'both', 'bond', 'swears', 'totally', 'times', 'desperately', 'watchin', 'already', 'trapped', 'addiction', 'position', 'looks', 'reinforce', 'role', 'curve', 'tounge', 'tied']
# accept? y/n n
# replace word:  fantasizin
# substitute:  fantasizing
# ['next', 'cause', 'reality', 'seconds', 'fiend', 'conceal', 'world', 'fantasizing', 'help', 'passionately', 'matter', 'met', 'heavily', 'clockin', 'watched', 'both', 'bond', 'swears', 'totally', 'times', 'desperately', 'watchin', 'already', 'trapped', 'addiction', 'position', 'looks', 'reinforce', 'role', 'curve', 'tounge', 'tied']
# accept? y/n n
# replace word:  clockin
# substitute:  clocking
# ['next', 'cause', 'reality', 'seconds', 'fiend', 'conceal', 'world', 'fantasizing', 'help', 'passionately', 'matter', 'met', 'heavily', 'clocking', 'watched', 'both', 'bond', 'swears', 'totally', 'times', 'desperately', 'watchin', 'already', 'trapped', 'addiction', 'position', 'looks', 'reinforce', 'role', 'curve', 'tounge', 'tied']
# accept? y/n n
# replace word:  watchin
# substitute:  watching
# ['next', 'cause', 'reality', 'seconds', 'fiend', 'conceal', 'world', 'fantasizing', 'help', 'passionately', 'matter', 'met', 'heavily', 'clocking', 'watched', 'both', 'bond', 'swears', 'totally', 'times', 'desperately', 'watching', 'already', 'trapped', 'addiction', 'position', 'looks', 'reinforce', 'role', 'curve', 'tounge', 'tied']
# accept? y/n y
# startIDX: 4600
# ['nights', 'ecstacy', 'sayin', 'burnin', 'drives', 'sittin', 'rolls', 'somebody', 'though', 'yearin', 'cried', 'thinkin', 'cheek', 'chest', 'feelin', 'problems', 'reads', 'tell', 'even', 'hope', 'else', 'wana', 'hurt', 'rub']
# accept? y/n n
# replace word:  sittin
# substitute:  sitting
# ['nights', 'ecstacy', 'sayin', 'burnin', 'drives', 'sitting', 'rolls', 'somebody', 'though', 'yearin', 'cried', 'thinkin', 'cheek', 'chest', 'feelin', 'problems', 'reads', 'tell', 'even', 'hope', 'else', 'wana', 'hurt', 'rub']
# accept? y/n n
# replace word:  yearin
# substitute:  yearning
# ['nights', 'ecstacy', 'sayin', 'burnin', 'drives', 'sitting', 'rolls', 'somebody', 'though', 'yearning', 'cried', 'thinkin', 'cheek', 'chest', 'feelin', 'problems', 'reads', 'tell', 'even', 'hope', 'else', 'wana', 'hurt', 'rub']
# accept? y/n n
# replace word:  thinkin
# substitute:  thinking
# ['nights', 'ecstacy', 'sayin', 'burnin', 'drives', 'sitting', 'rolls', 'somebody', 'though', 'yearning', 'cried', 'thinking', 'cheek', 'chest', 'feelin', 'problems', 'reads', 'tell', 'even', 'hope', 'else', 'wana', 'hurt', 'rub']
# accept? y/n n
# replace word:  feelin
# substitute:  feeling
# ['nights', 'ecstacy', 'sayin', 'burnin', 'drives', 'sitting', 'rolls', 'somebody', 'though', 'yearning', 'cried', 'thinking', 'cheek', 'chest', 'feeling', 'problems', 'reads', 'tell', 'even', 'hope', 'else', 'wana', 'hurt', 'rub']
# accept? y/n y
# startIDX: 4800
# ['fallin', 'wife', 'become', 'art', 'sorry', 'feelin', 'honey', 'cruel', 'act', 'beautiful', 'church', 'work', 'cool', 'pray']
# accept? y/n n
# replace word:  fallin
# substitute:  falling
# ['falling', 'wife', 'become', 'art', 'sorry', 'feelin', 'honey', 'cruel', 'act', 'beautiful', 'church', 'work', 'cool', 'pray']
# accept? y/n n
# replace word:  feelin
# substitute:  feeling
# ['falling', 'wife', 'become', 'art', 'sorry', 'feeling', 'honey', 'cruel', 'act', 'beautiful', 'church', 'work', 'cool', 'pray']
# accept? y/n y
# startIDX: 5000
# ['projects', 'sleepin', 'trustin', 'sinkin', 'feelin', 'undressin', 'gettin', 'minnie', 'callin', 'thinkin']
# accept? y/n n
# replace word:  sleepin
# substitute:  sleeping
# ['projects', 'sleeping', 'trustin', 'sinkin', 'feelin', 'undressin', 'gettin', 'minnie', 'callin', 'thinkin']
# accept? y/n trustin
# startIDX: 5200
# ['took', 'getter', 'expert', 'key', 'heartbreaker', 'ignition', 'none', 'freaky', 'legend', 'experience', 'romance', 'wallet', 'whatever', 'hoochercoocher', 'quite', 'parking', 'smile', 'wild', 'own', 'personality', 'once', 'moocher', 'block', 'boyfriend', 'enormous', 'believe', 'catching', 'wore', 'turned', 'reputation', 'shook', 'maybe', 'pox', 'diamond', 'chicken', 'shimmy', 'penny']
# accept? y/n y
# startIDX: 5400
# ['social', 'held', 'lovers', 'possessed', 'kid', 'poverty', 'poker', 'became', 'excitement', 'crack', 'addicted', 'gun', 'hoodlum', 'helping', 'misery', 'dissed', 'hardrap', 'chinatown', 'tape', 'climbing', 'relationship', 'memory', 'addict', 'static', 'smokey', 'gambler', 'peace', 'politicians', 'instantly', 'pipe', 'their', 'killed', 'ghetto', 'sounds', 'nightstand', 'harlem', 'undressed', 'suddenly', 'miccops', 'smoker', 'inditement', 'payment', 'heading', 'same', 'alcoholic', 'pistol', 'bought', 'basshead', 'everyone']
# accept? y/n y
# startIDX: 5600
# ['sadly', 'king', 'sat', 'needing', 'sweden', 'dozen', '1', 'counted', 'ate', 'courses', 'jocking', 'horses', 'wheel', 'meal', 'stable', 'stuff', 'fortune', 'bank', 'plush', 'thoroughbred', 'yeah', 'walk', 'billion', 'nickels', 'steel', 'race', 'herself', 'dimes', 'verse', 'dreams', 'home', 'platt', 'sleep']
# accept? y/n y
# startIDX: 5800
# ['sleepin', 'brotha', 'wasnt', 'self', 'paniced']
# accept? y/n n
# replace word:  sleepin
# substitute:  sleeping
# ['sleeping', 'brotha', 'wasnt', 'self', 'paniced']
# accept? y/n n
# replace word:  brotha
# substitute:  brother
# ['sleeping', 'brother', 'wasnt', 'self', 'paniced']
# accept? y/n n
# replace word:  wasnt
# substitute:  was
# ['sleeping', 'brother', 'was', 'self', 'paniced']
# accept? y/n n
# replace word:  paniced
# substitute:  panicked
# ['sleeping', 'brother', 'was', 'self', 'panicked']
# accept? y/n y
# startIDX: 6000
# ['sucka', 'hopin', 'im', 'payin']
# accept? y/n n
# replace word:  sucka
# substitute:  sucker
# ['sucker', 'hopin', 'im', 'payin']
# accept? y/n n
# replace word:  hopin
# substitute:  hoping
# ['sucker', 'hoping', 'im', 'payin']
# accept? y/n n
# replace word:  im
# substitute:  i
# ['sucker', 'hoping', 'i', 'payin']
# accept? y/n n
# replace word:  payin
# substitute:  paying
# ['sucker', 'hoping', 'i', 'paying']
# accept? y/n y
# startIDX: 6200
# ['retire', 'truth', 'hotter', 'ever', 'em', 'rarely', 'hot', 'sex', 'hobbies', 'whiff', "em'", 'becasue', 'last', 'cuz', 'wax', 'niggas', 'windows', 'haha', 'indo', 'rubber', 'loosin', 'candle', 'breaking', '2', 'keeping', 'misplaced', 'companion', 'impossible', 'notion', 'livin', 'shit', 'medication', 'understanding', 'babies', 'board']
# accept? y/n n
# replace word:  em
# substitute:  them
# ['retire', 'truth', 'hotter', 'ever', 'them', 'rarely', 'hot', 'sex', 'hobbies', 'whiff', "em'", 'becasue', 'last', 'cuz', 'wax', 'niggas', 'windows', 'haha', 'indo', 'rubber', 'loosin', 'candle', 'breaking', '2', 'keeping', 'misplaced', 'companion', 'impossible', 'notion', 'livin', 'shit', 'medication', 'understanding', 'babies', 'board']
# accept? y/n break
#
#
#  's 1 2pac 6 ; \n a about act addict addicted addiction admire adversaries affair after age aggravating ahead air aiyyo alcoholic all allowed alone along already always am ama amateurs america american an and angel another answer ant any anybody anything anywhere appealed are armed around art arteries as asking ass at ate attack audience autographs avoid awake ay baby back backing backstab backstage bad ballers bank barely barred base baseball bass basshead bat bats battle battles battling be beach beast beat beats beautiful became because become bed been before begin begins bein being believe beside besides best better big billion bird bit bite bizzy black blacks blind block blowing body bodygurad bold boldy bomb bond boom border born boss both bought box boy boyfriend boys bragging breath breathe bringing broke broken brother brothers brush build building bullet burn burnin burning burnt bust busting busy but buy buying by calculated call called callin calling calm came can cannot capable capitalistic car care cared caress casanova case catching caught cause caution cell center chains chance change charge charged cheat check checking cheek chest chicken chilling chinatown choke choose church cigarettes cisco civilized claim clapping clawed clever climb climbing clocking close closer clothes clue colosseum come comes coming communities community competition competitor conceal conceited confident confused conisseur consoloist constantly contact control cool cooling cops cordless corrections could counted countless country courses crack crazy cream crew cried crop crowd cruel cruiser cry curve cute cutie daddio damaged damn dance dangerous day dead deadly deal death def defeat defeated deny departed desire desires desperately destroyed diamond did die dilate dilly dimes disco discouraged discuss disease diss dissed dissing disturbing diz dizzy dj do does door dope dose down dozen drano dream dreams drew drink drives drop dropped dropping drops drugs drums dumb dump dying e each ear ears eat ecstacy educated education else emancipation emcee emcees end enjoyed enormous enough equality error even every everyone everywhere exact excel except excitement expand experience expert explode eye eyes face fact facts fair fake fall falling fame fans fantasizing fast fathers favorite feel feelin feeling feels fell fiend fight fighting filled finally find finish fire first flavor floor folks fool for force forced forever forget forte fortune freaks freaky freddy free freedom fresh friend from frustrations fuck full fumble funky furious future gambler game gave genius get gets getter gettin getting ghetto girl girlfriend girlies girls give glad glue go goal god going gold gone gonna good got gotten government grab grabbed grip grooving guaranteed guerilla guilty gun ha habit had half hand handle hands happened happy hard hardrap harlem harmed has hate hated have hawalian he head heading health hear heard hearing heart heartbreaker heavily held hell help helping her here herself high him hiphop his history hit hits hoe hold holding holds hole home homeboy honey hoochercoocher hood hoodlum hoods hoop hop hope hoping hoping horses hour house how huh humming hurt hype hyped hypetip hypocrite i i if ignition ignorant illtrip immunity impatient in indispute inditement inflation inside instantly intimidation into intro introduction is it its jacket jams jealous jocking jump jumped just keep keeps kept key kick kid kidding killed killing kind kinda king kiss klu-klux-klan knew know knowledge ladies lady lagging large larger late laugh lay leader leather leave leaves legend less lesson let letting levi liar liberty lie lied lies life light lightweight like limbwalk limo limousine listen little live lives living loading lock locked lonely long longer look looking looks loose lost lot loud love lovers loving lucky lyrics mac mad made make makes making man many matress matter maximum maybe me meal mean means meant mediocrity melody memory men met mic mi ...

# %% [markdown]
# **The final dictionary will be stored inside the file final_dict.txt**
#
# At this point we skipped a lot of our actual work. In fact, we had to manually go through many words to check if they are actual words or just typos
#
#
#
# # Step 3: Correcting Typos using our new dictionary

# %%
import re
import collections

def tokens(text):
    """
    Get all words from corpus
    """
    return re.findall(r'\w+', text.lower())

wordlist = pre.get_text('data/final_dict.txt')

WORDS = tokens(wordlist) + [";"]
WORD_COUNTS = collections.Counter(WORDS)

WORD_COUNTS.most_common(20)
# Out:
# [('oh', 9),
#  ('i', 5),
#  ('fo', 5),
#  ('to', 4),
#  ('ay', 4),
#  ('yeah', 4),
#  ('uh', 4),
#  ('ah', 4),
#  ('o', 4),
#  ('the', 3),
#  ('nothing', 3),
#  ('locked', 3),
#  ('me', 3),
#  ('sitting', 3),
#  ('wit', 3),
#  ('who', 3),
#  ('making', 3),
#  ('motherfucking', 3),
#  ('old', 3),
#  ('smacking', 3)]

# %%
def edits0(word):
    """
    Return all strings that are zero edits away (i.e. the word itself).
    """
    return{word}

def edits1(word):
    """
    Return all strings that are one edits away.
    """
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    def splits(word):
        """
        return a list of all possible pairs
        that the input word is made of
        """
        return [(word[:i], word[i:]) for i in range(len(word)+1)]
    pairs = splits(word)
    deletes = [a+b[1:] for (a,b) in pairs if b]
    transposes = [a+b[1]+b[0]+b[2:] for (a,b) in pairs if len(b) >1]
    replaces = [a+c+b[1:] for (a,b) in pairs for c in alphabet if b]
    inserts = [a+c+b for (a,b) in pairs for c in alphabet]
    return(set(deletes + transposes + replaces + inserts))

def edits2(word):
    """
    return all strings that are two edits away.
    """
    return {e2 for e1 in edits1(word) for e2 in edits1(e1)}

def known(words):
    return {w for w in words if w in WORD_COUNTS}

def correct(word):
    candidates = (known(edits0(word)) or
                 known(edits1(word)) or
                 known(edits2(word)) or
                 [word])
    # print(candidates)
    return max(candidates, key=WORD_COUNTS.get)

def correct_text(text):
    processed = text.replace('\n', ' \n ')
    corrected = [ correct(word) for word in processed.split(" ") ]
    
    return " ".join(corrected)
    
print (correct("goin"))
# Out:
# going

# %%
expanded[:60]
# Out:
# 'as real as it seems the american dream ; is not nothing but '

# %%
corrected = correct_text(expanded)

# %%
words = corrected.split(" ")
numbers_str = filter( lambda word: word.isnumeric(), words )
print(list(numbers_str))
# Out:
# ['6', '6', '90', '12', '3', '4', '5', '6', '12', '2', '2', '2', '50', '357', '2', '3', '93', '10', '1', '1', '2', '3', '380', '187', '6', '25', '9', '9', '9', '10', '10', '45', '165', '25', '1', '2', '1', '1', '2', '1', '1', '2', '1', '1', '2', '275', '90', '165', '1995', '1', '1', '2', '2', '35', '45', '2', '911', '2', '25', '50', '60', '11', '18', '12', '9', '95', '1', '2', '9', '9', '2020', '500', '6', '12', '500', '9', '3', '50', '12', '923', '106', '16', '71', '3', '12', '6', '8231549', '8599', '50', '30', '90', '62', '90', '62', '12', '45', '45', '500', '44', '45', '95', '1', '1', '2', '45', '80', '40', '70', '12', '23', '45', '45', '9', '10', '10', '187', '10', '10', '35', '22', '45', '45', '60', '13', '1']

# %%
import inflect

def number_to_word(number_str):
    
    p = inflect.engine()
    
    if   (len(number_str) <= 2):
        number = p.number_to_words(int(number_str))
        if(number == "zero"):
            return "ou"
        else: 
            return number.replace("-"," ")
    
    elif (len(number_str) == 4):
        digit_1 = int( number_str[:2] )
        digit_2 = int( number_str[2:] )
        number = p.number_to_words(digit_1) + " " + p.number_to_words(digit_2)
        return number.replace("-", " ")
        
    else:
        return " ".join( [p.number_to_words(int(digit)) for digit in number_str] )

print( number_to_word("55"), number_to_word("911"))
# Out:
# fifty five nine one one

# %%
def get_number_mapping( text ):
    words = text.split(" ")
    numbers_str = filter( lambda word: word.isnumeric(), words )
    
    mapping = {}
    for number in set(numbers_str):
        mapping[number] = number_to_word(number)
    return mapping

encoding = get_number_mapping(corrected)
encoding
# Out:
# {'5': 'five',
#  '11': 'eleven',
#  '2020': 'twenty twenty',
#  '60': 'sixty',
#  '30': 'thirty',
#  '187': 'one eight seven',
#  '911': 'nine one one',
#  '50': 'fifty',
#  '9': 'nine',
#  '923': 'nine two three',
#  '106': 'one zero six',
#  '80': 'eighty',
#  '45': 'forty five',
#  '13': 'thirteen',
#  '6': 'six',
#  '12': 'twelve',
#  '35': 'thirty five',
#  '4': 'four',
#  '165': 'one six five',
#  '275': 'two seven five',
#  '22': 'twenty two',
#  '93': 'ninety three',
#  '10': 'ten',
#  '62': 'sixty two',
#  '1': 'one',
#  '70': 'seventy',
#  '71': 'seventy one',
#  '90': 'ninety',
#  '3': 'three',
#  '500': 'five zero zero',
#  '23': 'twenty three',
#  '95': 'ninety five',
#  '8231549': 'eight two three one five four nine',
#  '1995': 'nineteen ninety five',
#  '40': 'forty',
#  '16': 'sixteen',
#  '2': 'two',
#  '18': 'eighteen',
#  '44': 'forty four',
#  '357': 'three five seven',
#  '380': 'three eight zero',
#  '25': 'twenty five',
#  '8599': 'eighty five ninety nine'}

# %%
def encode_numbers(text, encoding):
    encoded = text
    
    items = list( encoding.items() )
    items.sort(key=lambda item: len( item[0]), reverse=True)
    
    for number, substitute in items:
        encoded = encoded.replace(number, substitute)
    return encoded

number_encoded = encode_numbers(corrected, encoding)
               
print( number_encoded[:500])
# Out:
# as real as it seems the american dream ; is not nothing but another calculated schemes ; to get us locked up shot up back in chains ; to deny us of the future rob our names ; kept my history of mystery but now i see ; the american dream was not meant for me ; cause lady liberty is a hypocrite she lied to me ; promised me freedom education equality ; never gave me nothing but slavery ; and now look at how dangerous you made me ; calling me a mad man cause i am strong and bold ; with this dump ful

# %%
pre.write_text("data/prepped/clean2_pac.txt", corrected.replace(";", "\n") )

# %%
import tools.architectures as nn


text = pre.get_text("data/prepped/clean2_pac.txt")[:20000]

#print(corrected.replace(" lbreak ", "\n"))
# processed
# text = corrected.replace(" lbreak ", "\n")

vocab = pre.Vocabulary(text)

NUM_LAYERS = 2
HIDDEN_LAYER_SIZE = 512
VOCAB_SIZE = vocab.get_size()
TIMESTEPS = 50

EPOCHS = 30
BATCH_SIZE = 256

EMBEDDING_SIZE = 500


data, labels = vocab.making_embedded_one_hot(text, TIMESTEPS)

embedding = nn.LeanableEmbedding(name = "learnable-embedding")
embedding.build(VOCAB_SIZE, EMBEDDING_SIZE)

rnn = nn.SingleLayerRNN(name = "single-pac")
rnn.build(NUM_LAYERS, VOCAB_SIZE, TIMESTEPS, l2_reg=0.0, embedding=embedding)

nn.train(rnn, data, labels, vocab, epochs=EPOCHS, batch_size=BATCH_SIZE, temperature=.6, embedding=True)
# Out:
# (999, 500)
# (?, 50)
#
#
# Epoch 1/30
# Loss:    	 6.872012615203857
# Accuracy:	 1.171875
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of deal intro lie should promise hits freddy confident bragging temptation affair pop tipsy many totally park speaking vocalist mister brother lucky rockin tms street filled intro offers humming lesson trying claim ears handle warm rhyme oh stricly moving hell large health lyrics upset thought crazy thumping choke words going signing allowed goal america stage clapping within seem tossed shot pull twenty ladies puff worst stomach e bullet sad obvious rich locked calm cry lonely as eat bullet inside forte where patio loose
#  unity love side bit wink fall woke old she send no soul
#  e others bit girls patio panther tms cream second yeast tried larger game park they forever everywhere an start woke cute obvious walked set rolling men boss bass seem troop why grooving awake record world loading vote checking fight musical without ring body down caress moving rope ahead burn then stop vacation many morning emancipation is country care over sure your confused dropped go toughest settle was purity hype damn starts off tip whole fall tear health anywhere listen anywhere pocket just it center other sweating is education civilized bad finally paid fair laugh building drums choose feel should girlfriend west cause box defeat leader will steal tupac needle frustrations radiation minute crew mics mysterious floor choose obvious grab boys nervous panther control competition understand overload government consoloist spare destroyed asking whole value tender rhyme yo mine them die capable gone she freedom peach what boom made kinda rob cisco less of funky jumped leather rumble climb education stomping party dissing girlfriend michael played tied lady talking yourself would thing boys base defeat thunder with
#  adversaries inside panther promised rapping dilate oh sweat second fall jacket nightmare paragraph habit ladies survive silence hate nothing larger waiting deal trace clothes calm live ring thing liberty promise vote living rougher knew so and the hits toss slack communities whole longer style guilty toss upset dance promise age out box preach survive clapping ya mister anybody less hood blacks sweat soon lies levi positive be undressing taste waiting thought give first knowledge truck name hear begins bringing begins battling tied ass sell mad starts stomping dissing kiss ready would begin she introduction habit nervous promise because using making ear blacks terror seen good second bite burning gotten stuck nowin passion everywhere emancipation cigarettes seventeen pad sweated move some side stuck vicious makes salad see lied peach the moves burning survive limousine serious if promise country stomped gold mic a roc scary suck checking lives others about dose much audience do rest silence find glue pant pen poor anybody taste yourself lay huh coming name jealous wink screw motherfucking nuance stretch shower tipsy leader hour capitalistic where border adversaries funky caught seems this avoid slow perpetrator think pass eyes except silence know played sweaty sweating well or laugh tone called limo poor see let shivered born free knew saying patio comes maximum put control loving come man motherfucking go mic poor jams calling looking besides aggravating arteries
#
#
# Epoch 2/30
# Loss:    	 6.826334476470947
# Accuracy:	 2.34375
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of house hits clapping lady tipsy see ass place arteries go right finish morning coming slavery at silly disease postal makes new station here girlfriend air folks damaged stumped need barred mysterious ring prolonged this in tied sweat came hearing she leaves sweatsuit large contact settle jealous it future can sam dying another shower street bizzy so glue guerilla fame offer longer adversaries tonight rich trying preach proud beat hold stopped busy signaled first sitting guilty too tying excel world microphone long each burn truck violence mountain fumble bust noise why napalm strictly cordless off rockin ten breathe matress why mean attack you do harmed grabbed buy battles living run stopping run bass get using suppressed know michael choke through attack stronger playfully getting might or lyrics cry dope def tonight up redeem moved needle tons cordless for dropped sucker answer  any facts knew klan friend stop finally bodygurad over neck that autographs as my moves never burning clever power except gonna touch hold allowed live prove blowing sentry within them communities rocking swear soon young dangerous through barred stepped raw rougher come rock audience charge calculated there eye things limousine finish thoughts the unbelievable death wait vocalist take win tricks rougher america closer hoods voice running start thinking rap tight am outs never unbelievable through gone michael teeth smacking how step lagging before fans ant anybody will making jacket take piranha till stopped closer minute started brother write take woke car wet community or totally yell they defeated everywhere excel happy woke many answer motion moved vocalist crowd lucky simple lies back means large civilized admire monday friend nightmare listen hypocrite trap indispute less stretch sentry time communities do spin treat simple park cops cell backstage totions means dream be anybody phd drew fall battling lay little boy twenty affair wit really making brush but everywhere limo settle would smacking equality dilly drums speakers fumble minutes finally scarred always sell hop lesson true speakers force consoloist musically drops uncle blowing grabbed fact trusting means sweating toss scene ignorant schemes everywhere tracks skin letting totally history enough musical forced posse meant made survive scene are knew made show cordless on realize way live full speaker clue too blind lied fact day time tried toughest disco sad yell recreation where making nothing two mac undressing cause touch hits holds ray sentry force musician feel leader build beach them teach girlfriend yo fans wet funky power desire come place grabbed seen tossed busting move lay came play trap aiyyo not dying
#  nuclear armed face success why answer top its a civilized chains put quick audience freddy one eyes crowd nuclear like hit slow shivered baseball cigarettes when kinda dilate other pumps bullet handle stuck thought got bad too sure our chilling every lie penetrating simple forte here defeat teenage silly hear warm battling makes cannot stand rest homeboy over fast through battles suffocate spare puff leaves ready scary any he floor freddy jacket offers perpetrator speakers coming sucker genius mad attack
#
#
# Epoch 3/30
# Loss:    	 6.77357292175293
# Accuracy:	 2.34375
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of prove punk impatient floor proven friend better her silence playfully disturbing play west proven anything streets hoping to try buying pay strictly rob things never poor napalm of clapping screaming genius talking loving these record called communities everywhere michael tone except promised fame security keeps writing leaves chance community voice most black move change predator inflation them build smacking saying night ev sweaty burn time tricks understand ev real comes raw departed being chains hiphop much till starts strictly wheels holding where along die avoid brush minute running drink blind myself name freaks choose mad night hoods rockin moves paper lives indispute chilling until smoking death slack stay fire klan promised forget nightmare
#  three guilty prove fire proud street nightmare deadly girlfriend told indispute always keeps along freedom e you party affair drano friend life patience boss uncle twenty temptation hate eyes useless running america positive shocks redeem tongue end nightmare care best set step thing avoid bragging obvious suckers word ray mouth jams flavor hoe making fair folks stomped since seem lucky longer only trick gold crowd she predator has pin burnt stand blowing heart stutter choke should outs screaming melody still woke side center nowin means calling terror clapping day mics battling happy always baseball happy bodygurad come handle tms without young up equality intimidation hawalian competition check are seems started beats if autographs stopping eyes this tired ruthless calling never people totions damaged nervous toast who happy autographs mine paid dropping gets tons battles dying kick comes breath suffocate into autographs besides overload hood proven veteran strictly equality silly make kick lock furious tried playing screw kept strike write proud power buying will blind teach mics educated locked seen kiss spin close reach god posse most change bats indispute up this glue charged sneak pop smart ten girlfriend trick letting pocket choke alone lied ready word suffer hated favorite 6 scare gotten wanted heart girls attack take always another put along west tying excel chilling pen fuck cooling punk do genius ant street west tip dizzy place jacket dope rumble cell off first put crop filled lady klux emcee segregation intro they scare flavor settle calculated sold bats dead open stomach skin leader ears everywhere want strike check chilling pocket each the door played rolled could for sell panther competition hated talking where recreation pocket breath looking security fell melody fans twenty morning stomped resides busting country deal world true well rolled error lock inflation border lock playing shivered meant fame deny still stopped his freddy sweated park other fact damn freedom motherfucking except strictly enjoyed dangerous scary minutes fall spare broken gotten thumping laugh case dead high facts team toe cry hood gave trick tyson allowed yet close off inside panther armed anything all lyrics jump leaves starts vocalist rising hoop asking while type shot any crop neck anybody meant past tipsy swear colosseum kept sweet god sitting know rap diss yet destroyed rhymes heart stole clever broken pad totions wiz fact free desires consoloist
#
#
# Epoch 4/30
# Loss:    	 6.7217841148376465
# Accuracy:	 1.171875
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of hate teeth stole force moved blind reach poetry feel box grooving lonely violence motherfucking homeboy shot touch serious genius calling calling tupac scarred wonder rapping smoking situation freddy needle never microphone preach ev go damn mission lot dope through out illtrip since he then michael lie while limousine wit aiyyo move freddy hypocrite realize our before signaled loving rolled she mysterious dance slow bird lost prove soul looking dream pop since reach e aggravating boom yo make cigarettes set ay rougher drew emcees excel signing teeth stop power ahead beach undressing puff old second dropped tossed bs sweat there tricks clue streets strictly seem stand sam guilty bit consoloist pumps drums late put limousine crazy let but amateurs grip old dilate screw clothes ahead bite with capable nothing limousine wrath man e black chilling conceited girlfriend made jealous set win then salad e minute cared talking slavery up must michael feeling noise bit tossed will titan out tone always mysterious does streets woke posessed smoking anything casanova casanova hiphop because pant warm stay phone facts streets rougher that hands hard trace dope building sexual play friend inside sentry words long stuck taste stronger a damaged roc myself thoughts tip its longer hoping nimth screw mister moved place folks statistic think pant out before besides goal another limo leaves pocket consoloist calling were except life might you see boy to aiyyo guilty off cooling girl well bs say bodygurad two wheels survive motion jealous on why until stand your sweaty my violence at bomb bust totally forget ay gone young die breathe slow ear do boys stinking think rolled gold spin poetry drugs nothing hearing thinking treat had every really suckers punk keeps stronger opposition hoping promise write stomach girlies raw burnt ears hawalian change blind vicious down ahead gave broke gave makes center rumble kiss hop moved could look who lies dizzy  patience clue fighting check i tear burnt crew rhymefumble born fighting who together say drink ready hoods mad them grip around hear dead hit it stepped loud have find fame stricly consoloist vacation poetry gave stumped expand aggravating facts noise bodygurad calling station capable undressing broke any trace bed stop kept motion listen loud mic move them ring say control remember sweet
#  big morning sick making thought vote america goal calm whack grabbed vicious recreation when control girlfriend competition fair hawalian affair her grab seems anything tupac rocking shot fire immunity strike meant quick her hop dead suffer along neck bed except real record loud me saying prodigy stopping might warm friend overload within wake mac into emcee meant patio limo loose toe ev vicious educated taste must uzi capitalistic playfully defeated anything kidding comes type rockin enjoyed hoping loving appealed wheels out they blowing there lonely mister minutes some source sam school that intro sold until lyrics over grip woofers what caught mother backstab talking a sitting toughest levi lonely salutations mics her rhymefumble source always in lay more straight matress dropped climb cause roct
#
#
# Epoch 5/30
# Loss:    	 6.668581008911133
# Accuracy:	 11.71875
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of caution shoot cry nothing contact equality strictly leave recreation future falling warm it for played go  obvious trace dilate amateurs levi capable big crew chilling for limbwalk finish would second clapping glad from feeling thought useless barred cigarettes rougher new overload stage jump yet rumble cell party move had hood mic unemployed trying shoot brothers i anything sick phd rocking since upset patience vacation postal others morning wet leather play fans statistic fresh wrath get jumped might with hard competition bit everywhere funky chains full only recreation cisco force prodigy sucker illing stop much diss barred emcees sentry homeboy postal saying radiation beat world claim when off late segregation making checking moves beast outside sweat penetrating fame cooling called nothing mac wait picked makes dj sit truck control situation stumped come tone nightmare tongue patience time a because cooling ruthless come control thinking charged stopping large reason dream backstage reach kinda ladies had resides amateurs sucker three set broken case sweating worst oh whipped wet ready dangerous tossed eyes diss hit appealed stepping whats defeat slack ray crew body down up got checking coming top statistic school age mad pad ay came whipped e emcees stepped skin facts good walking record lagging bringing rope violence bragging style looking wheels perpetrator death girlfriend paragraph ears signaled around got gold stare am tyson whole bite realize resides less hiphop nuclear noise game salutations large gotten out mic bust truck hold source quick name control warm pass he loud freddy this asking top power ya sweaty other glad wrath not i wondering allowed bizzy the toughest muttered rhyme pad grabbed wondering bed pocket cared bird another undressing ay leather klan rest countless take burning limbwalk nation suffered falling eye slack scene opposition dump promised reason old tumble contact make toothless leaves bizzy salad falling got serious capitalistic step nation thoughts wit sentry illtrip screaming suffocate dance names consoloist liar rest is kiss limousine friend writing broken consoloist stretch girls redeem hoop light back deny cell deadly cordless wiz clothes trap inflation can as some tupac things maximum gone dump get think lightweight letting klu drugs pass countless fact sure aiyyo was inflation piranha be hoop around emcees rising find said vicious armed bit white guilty west surrender power checking moves my show yell have pull emancipation richer shocks motherfucker with amateurs brother knew patio live equality totally mission much emcee silence down playfully tons loud side radiation how tying emancipation happy others cry shake well cisco toothless motion station smart cute hour capitalistic he feel dilate lives lie toe past nothing move anybody but screaming calculated hype hoe emcee impatient made violence tyson drops rocking bass before locked anything kick toughest departed living power building back harmed confident ten beat world ay life then hand proven disease dizzy have meant knew lot could and stuck breath bold sweatsuit nation boom eye  good preach door rumble heart is ray stinking destroyed feel hour weapon cops girlies anybody another trusting dance everywhere tossed
#
#
# Epoch 6/30
# Loss:    	 6.614965438842773
# Accuracy:	 9.765625
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of guerilla whole where sad settle mother little ignorant levi holds bad still paniced pass stay seen pull if freddy bullet over blowing still hiphop wonder cream close habit might slack tone except amateurs dose chilling dump michael thumping impatient freddy fight habit caution really desire made there when being want loose roct never unbelievable troop play ray his take boldy another only holds still will swear is house emancipation situation them saying favorite stop deny breathe your worst claim hate always musical blacks inflation microphone defeated gets style cared drugs radiation just then ay glue want damn broken burn put let dope voice larger rhyme body door lagging hour destroyed limbwalk crew cooling uncle are caution klan some anywhere punk there beach wit hoping finally street wink saying stumbled his tupac lost teenage caught base tyson girl should right up fall names stomach richer were build bird tasted toss buying late fair lightweight then proven tying finally toughest make hand stumped shivered her bs door uncle been leaves top is swear some pant fresh fighting unity grab each checking had understand rolling here who light every hear mission offers kind american moving a had disturbing wrong rhymefumble whole kidding sell jacket keep end calm admire record sucker stepped keeps vote loose confident discouraged stand write them defeat pen drop forever little place or playfully thing guilty consoloist charge from bold illtrip build run rapping shower allowed liar myself brother boys tupac other hold larger of competition long pass immunity except box tonight not it by sweet cutie god so mine limo name asking guilty hated into educated within tone panther nothing dilate pin vacation paper myself predator saying speaker paper vicious white or seems fool skin hoe genius how anywhere that our night was wrong power bat uzi got pumps time where girlies wiz fresh dumb sweated finally choke fall find reach cell clever nightmare ten might center slack them charged west strong armed claim stopping suffered sucker world passion better rope casanova piranha called jealous settle stinking armed ten ay t pocket do me turn she said angel there rhyme on stumbled set smart passion things uzi prolonged
#  send touch coming love calm words smacking die freedom rapping limousine noise stole homeboy building tone source mean choose positive sweet rhymes good words arteries cared uncle stretch base stricly big drano aggravating age outside names opposition wiz no better levi chilling be free unity laugh sad hoe surrender fans hiphop sweet sweet boom indispute our lock veteran there nuance two bit new born toast of with move winners shocks without got adversaries here lot suppressed stop sinking it uncle bit top him settle teenage been autographs tired illing answer stepped her consoloist understand facts fell intimidation pen were kinda light boys set its did neck deny dream cisco mountain shake tricks truck many useless fell mediocrity loading drew loud indispute lives getting strong furious clapping brothers toy holding bad being rap hoping fathers bust chance yo gave strong got
#
#
# Epoch 7/30
# Loss:    	 6.560665130615234
# Accuracy:	 9.375
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of thinking living spin now hold sweet perpetrator guilty error she clawed day mean mac falling trick unbelievable jacket his should capitalistic sucker fresh hypetip sleepin running present security baseball panther case chance leader recreation my drink broke that defeated constantly rope besides brother will jump she diss two comes ev have beside wondering lucky woke thinking time top laugh feel center community cute up can bs claim stricly glad beach being beside putting tons would hoping falling puff gold lock girls cops opposition woofers the heart mission posessed stricly sagging tender school minutes things name hits unbelievable speaking show tired border tms got yo tear to stomped win want except lady ear american and recoup capable terror than grab wrath play needle smacking hell too so wink let tone
#  hate walked beat nation young with dropping slavery colosseum hyped bizzy rich choose guilty did whats well postal buying white white bed age bold puff scene clever broken there mean drugs cry hole hit defeat punk cheat recoup ay capitalistic future if drano competitor friend answer lucky except hype community center twenty teenage lie competition through right thunder panther bats handle ay recoup choose defeated walked old beach much real charged fact chilling sweat neccessary freaks truck temptation many dope hated feeling school cannot history bold leave filled in look paper dropped colosseum close stumped clapping you stepping stricly moved i better corrections white freedom first for opposition discuss toughest casanova ring said nightmare letting surrender dump tight walked voice boldy bringing wait knowledge competition mouth keep seem sick love patio have to musical signing sucker you lie bold girlies coming appealed running type but freedom strictly end beat send my coming force pretend def told eye levi streets party fame silly tip saying armed going promised busy  limo god too starts starts without signaled lightweight want had why dead why just all wanted more leaves care inflation onetwo pass high trace his if answer yell winners everywhere always bad other say control aiyyo baseball less any cops gave mystery handle community boys too motherfucking neighborhood because fans tms sick stretch success side sweatsuit never one talking rhymes dope within hole old hypocrite up find skin hear bass vicious a rope start rap stomach lightweight screw how bomb to kick crew move bit getting teenage buying immunity cutie weapon bat veteran girlies base segregation perpetrator morning cisco since cruiser dose late daddio go drano locked knew moves outs fell exact boys girls has write thought emcees soul then mac mine aggravating cause forever liar poor never claim playing at playing chains schemes limo let get battle hour hour center gold will our until we come quick except clawed top there wit rhymes casanova who rhyme when do have not and upset suffocate gonna comes mac till forever hop fair hand bold change melody  lady live suppressed lucky age me into constantly broke posse living rising scare penetrating flavor vote desires rhymes conisseur wet try forced pretend living ears
#
#
# Epoch 8/30
# Loss:    	 6.506491661071777
# Accuracy:	 9.765625
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of perpetrator talking playing cannot armed made fake with remember and for is teenage door passed my cops as grabbed others keep proud dizzy lightweight screaming how ballers played open piranha weapon station come unemployed lost mother you error tonight lied am two claim center show sagging can nothing mine expand keep good beat top using high screw lightweight begin exact toast calculated dumb loose hyped cisco let gets full send predator hoods aiyyo jacket sweating some place sweating rockin vote late guerilla stare jams proud hype corrections screw along leaves silly sipping corrections
#  be border only undressing run bragging hear coming your thing pass knew jumped thought adversaries made i that get station hell 6 drano hoping pumps screw desire boldy second thought barred deadly fumble awake titan teach serious swear cause let where names base freaks tipsy jump dizzy homeboy baseball contact woke anything understand do skin musician calling sneak goal stop autographs stand mountain go panther deadly answer little hood fuck and tonight that mic illing did appealed force minutes man education live at brothers clothes buying end saying all except tear stutter choose beside at but what i that another our rob loading ears with woke will back be blacks fall free gotten pad putting claim winners sucker sitting emancipation after emcee tear base busy worst punk sad car loose patience girlfriend rhymes equality me backstage outs klu slavery looking alone because would veteran girlfriend rolled tyson run sipping explode hated phone favorite anybody has statistic air so makes smacking history closer guerilla blowing hoping tumble source hoods refuse must suffocate departed out
#  reach seventeen could rising ears girl mysterious mine outs postal hoods room autographs situation back onetwo monday that fight wasnt situation wrong loud should exact wiz stepped posse give
#  explode eye liberty hiphop let eat hit rich nowin your coming armed caution fans hear roc fuck made pen stole cared hype kept say buy you feels rockin without alone def clapping started rockin charged trick enough security wanna ruthless outro young rope sweet day trying ya guaranteed where prove refuse is defeat soul i no paniced preach at we hearing fumble how of seem names tupac fame drop now keeps claim eye gold will keeps shot see e ring adversaries boys violence i jumped live jacket have girl motherfucking dream car lies settle life ears on words baby lot how hoop equality mother stepped you late bite lonely hyped shivered liberty upset us roc still leave ant closer teach sam grip broke inside sell
#  clapping michael bullet holding only mic girlfriend on time source god all paragraph keeps makes boys know myself taste offers toss each wrong uzi chance mission intimidation wheels door drano panther except drop dance teenage am hype charged yet getting sweated still prolonged crew scary buying baby clue cannot cheat knowledge mountain pull hits building piece think hypocrite sitting locked knowledge burning typist treat exact yo with large hop hypocrite tons tossed tons as free whats
#
#
# Epoch 9/30
# Loss:    	 6.453977108001709
# Accuracy:	 10.15625
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of seeing breath claim stand
#  security sell yourself facts pant alone up funky impatient close totions being not rockin calling rapping dope see whole hard running too yeast kept just consoloist why tired salutations guilty tumble think brother he back up do game tupac boldy hell but suppressed change together moves scared ray hoping settle mad sneak and introduction like at crew deadly radiation hoping die guilty world i long paper now we end looking to sinking alone could
#  your rhyme defeat each cops posse schemes calm proven are but i gonna down beats like shoot happened big floor beside never did posessed steal using seem did freddy words jumped lonely passion clue awake light no was veteran living claim pant intro nothing after reach everywhere battling my girlies baseball now limo wiz rock postal tons sweatsuit error white scarred her roct weapon backstab uzi is stepped you write emcee open lies seem but klan forever strike prolonged picked wondering illing stare feeling immunity discuss stop unemployed promise rhymes outro style base grab means slavery wit crazy most
#  jams uncle when trusting slow is postal wrong tumble we illtrip can am soon minute comes paper suckers saying is started sweaty competitor fall into sweated harmed burn men girlfriend blowing surrender white cute lady favorite sentry night checking down shake outs tumble backstab bold jams nightmare ass cry for competition closer  right so black ay conceited the paid ignorant tear beats security disturbing dangerous bad make bad sucker 6 but stretch tried passed awake at attack we power dope present begins dropping lay battling ass destroyed little been grooving straight allowed volcano stay shower what mission live if tms intimidation said so putting how play uncle yo melody recoup people will stage cops recoup claim situation force wiz forever punk old useless meant starts stinking present musician mine mac team station will no go cell busting rapping conceited freddy mission leather settle fumble play making enjoyed had limousine buying hypetip buying yeast cheat rock game force now ear loud rolling mine we girl light life could asking burnt it said undressing america late told let smart style like then reason disturbing source pin uncle waiting me every discuss damn falling aiyyo mission signing trap pin border too some unbelievable around on pretend stricly flavor face value seem indispute hit wonder some border time must matress rich hands by shoot things health silly stole through sweaty cause weapon she strictly like woofers conceited treat hop into weapon stomach shower lucky make tons sad cream to had we bat ear history keeps playfully government called girlfriend wit guerilla slavery of chains violence happy girls onetwo surrender down knew need strong dying aiyyo wrong freedom sit offer dance future was more folks community but game longer eat myself sitting preach burn of impatient blacks leaves spin buy favorite feeling strictly obvious guaranteed choke at error why was was know hiphop for dope destroyed girlfriend or men audience cigarettes smart wanna loud
#
#
# Epoch 10/30
# Loss:    	 6.402940273284912
# Accuracy:	 12.5
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of hypetip side find time spare sucker making now now never tired goal the are angel climb little told thoughts ready paniced always touch dance second way morning fair remember taste rapping playing will together must melody over tipsy place girlfriend makes stuck outs die bizzy minute be crew give your rhyme statistic guilty picked survive silly
#  ant who illtrip puff promise mouth napalm wrong slow scared need girls my rolled is posessed damn much lagging cause tasted it run survive party streets then is that mic moves strength america toy game with with them muttered source teeth party sam makes love hypocrite to tyson vacation handle how you trap tupac buying baseball beat jams sneak for so busy or with use capable here wait dizzy source when keeps melody
#  health smart onetwo uzi the sit yo dump speaking bad clever day always dump troop avoid nuclear indispute bs stretch beat mind panther stopped walking time body strictly called young desires speaking destroyed where this another without signing is keep am like daddio now could our fight error boy skin seeing troop by breath bringing hate toy intro me good way suckers knowledge backing remember bragging him as scary breath ant checking stronger feeling house was black charged prodigy lonely young sweet klu aiyyo lyrics true totions still tried serious always take see hands neck border border ballers ya stinking nation tupac ya check when capitalistic colosseum wanted deny its not could sweatsuit jump pen stumped illtrip blind simple maximum baseball start hoping puff from competitor beats no forte klux loose skin hear mine suffocate any morning filled is out strength rhymefumble am go tonight defeated i veteran it trick hell feels prove bat know clawed dream bats truck girl segregation drugs toast statistic kidding needle just community rhymefumble quick fool kidding answer tumble out toughest barred what genius bs broke remember consoloist impatient lay poor teenage cigarettes pass kept top thing fathers battle facts lyrics laugh success thing out called bed care girls puff had laugh broken grooving audience fathers totions seems caught prolonged men treat stumbled refuse nightmare radiation for buying jump time limousine tms had deadly ring american was toast it slack dope better ear you her bass  suckers onetwo control one baseball shackled morning backing now happy toughest america cordless holding not outro live crowd fans present forced beside sell they that inflation excel turn boys pen sweated lost scared tyson since bringing promise education change my nightmare second say no fool neighborhood ha there are he shocks dying with letting west caught success myself down gave mine stomach together clothes back could beat has sell hear suffocate and in mine tumble def mysterious inflation pin be dj run 6 glue with gold boldy on baseball then beast dose simple rumble stopping shackled spin in sweet bs roc dead my to ha teach jealous mine disco over seem lie who rest pocket suck confused pocket things poetry confident power means resides caution veteran yourself
#
#
# Epoch 11/30
# Loss:    	 6.353669166564941
# Accuracy:	 16.796875
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of suck prodigy clever hoods resides levi clue aggravating everywhere cell got station drink dope tipsy swear rocking history upset confused fuck cared patio move see still chains suffered chilling clothes avoid face nowin as were steal floor illtrip jumped we school until indispute toe streets less there am using desires called answer bs def bullet fans volcano panther hell power back salutations cheat arteries but hoods teeth speakers mountain whats fumble lied makes poetry uncle each stopped sucker conceited competitor stepping dropped saying charge hell hop nimth change it tongue falling outs lives muttered
#  is gone twenty mic bs shake sick pocket liar bass lies hoping posessed burnt motherfucking microphone introduction made strong a winners heart limbwalk postal car one are hop answer pin feel shake chains makes limbwalk salutations me happened stomping nuclear well wasnt me neighborhood promise slack are anybody stage history fall men immunity rob confused immunity lied by roct unity care lives for contact educated defeated better did rhyme noise rhymefumble leader uncle folks time outside mac in ass kick liberty future past survive bats pay most so wonder not my destroyed lost air stomach disturbing before nuclear words thoughts said hand minute ay fresh american melody richer tight clue up facts stopped kept casanova dissing together situation wheels michael matress at crew weapon present cause drink am leave autographs as head dumb mac deadly trusting think want stretch lightweight see letting recoup until stumped nuclear meant tupac toughest big about eyes drop might like jacket calculated levi nowin wet meant making fumble i alone yo just mediocrity set attack freaks signaled america uncle introduction dizzy beat asking refuse bizzy in stumbled beat bold paragraph vote call ears fumble me boy musically habit let mountain  panther pop minutes think suckers motherfucking emcee we well words stomped be when stinking tender rougher can starts breathe coming been klan street started making toast ready let know running pop air
#  motherfucking aiyyo jumped mother like bs strictly slavery who tasted bust wanna scarred hawalian consoloist free gonna till was end lay us hate slavery moved situation rumble dead loading top suffocate record harmed there rocking put appealed tracks armed world am hated piece will nuance government moving outs lie tupac hype then drop beat drugs of whipped it lock rapping touch moves upset as live aiyyo man give hole hearing neccessary klu bold barely voice huh feels passion time baseball damn cisco whats three attack me for tms park building backing mic drano let competitor vote power most feel other is getting clever wheels was drop we scared new shot change smacking promised school lied not when put drink screaming should run  am lie baby box first just tracks wonder perpetrator only chilling right say sucker holds immunity old car you they awake our  security was head day cause crew discouraged reach violence me not like rope rock streets never prolonged saying anything find rising moving cops armed more school melody fuck walking autographs
#
#
# Epoch 12/30
# Loss:    	 6.306145191192627
# Accuracy:	 17.578125
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of rumble my feels they ray down departed bs calculated yeast tying neighborhood everywhere while larger along deny sweating limbwalk will tumble calculated my panther liar too government suckers worst at sinking freaks nightmare what capitalistic coming making made peach drugs tossed free drew passed hated looking drink shoot thunder and must god on body call settle proud dropping slack  vocalist crowd step shivered gone piranha boldy dream lie world dance too attack no excel stage heart was you bragging go stomped neighborhood box talking punk serious from if be listen second dumb dumb this lost sure appealed people begin goal obvious sleepin worst stopped stutter hyped speaker rapping beast a do damn battles richer melody girl folks saying mother rhymes never now win desire always it allowed illing attack conisseur guilty out
#  all school freedom undressing close rocking fair in give remember get play within be capitalistic the salutations till brush been unity
#  bite patience motherfucking error cruiser ignorant morning homeboy said got an dumb live whats reason charge rhyme over the looking thinking way grooving could freedom humming how screw enough beats listen rolling end simple us could you better better new proven past caress dropping rumble conceited stage
#  battle moving forte walked
#  blowing love poor yourself onetwo
#  brothers cream stop running stumped kept mediocrity cordless on preach yo unemployed got with man think suck wanted swear tried what tupac stomping well old troop desires stepped asking mother security they freedom communities mean if constantly corrections rolling indispute simple shot these my competition lost begins is kind sweet useless obvious screw full resides fact wonder can yell kiss words pin melody mine too screw calling noise your breath when talking at drink an community can neighborhood stand up hands hell melody moved exact mac or hole full excel less good less center stare hell hour floor deny hoop sam jacket exact hated prodigy neighborhood ladies thing sweatsuit called could kick till pay forget on cream poetry said panther totions indispute flavor sure limo going trying civilized for schemes move lied tricks hold than your by corrections full vacation gave know violence meant intimidation a by comes power paragraph wanna e prolonged choose dropped introduction bird clothes bragging toughest dangerous gold dangerous seen scary neighborhood will told most lagging tracks beat word was my corrections bomb to of put or in pant live brothers new disease rock into opposition boss large rich come team excel moving scary charge this caress long dump to countless drop klu thoughts will might confident it wink dizzy step attack being getting audience shocks new crowd climb high rhymefumble this forte gone for room many was
#  way cared it trick shower touch makes unemployed wink audience mountain knowledge sweat sweaty stepped meant me asking hiphop large mad new not out straight explode unity sure rope down speaker no control history defeat open right be paniced
#  emcee introduction sagging me it them ruthless toy up musician gonna passion
#
#
# Epoch 13/30
# Loss:    	 6.260210037231445
# Accuracy:	 17.578125
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of my were here caught american suffer game opposition opposition strictly can sagging is sleepin weapon in but climb not bragging tupac pumps or speakers come cause or winners tyson must cisco us is ass with bass tried vacation is long still sam countless positive barely seventeen its blowing got stop audience dangerous stand turn on not was will gone up am microphone house mac fuck audience sam enough leave
#  desire paragraph beats win people had swear leave me has punk our sit preach always rhymefumble scene for never your cops has limbwalk dying nuance rockin dizzy silly as busy of calling about promised charge
# ...
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of aiyyo hearing  lightweight find mad told stomped to larger night the phone this wonder in this no baseball sinking did hell nowin its time leaves will who got gets came any a outs with
#  because discuss cops like to beat give will you i stare this fight rap in sold answer sentry discouraged peach a liberty on to a noise it hear bad my by light cooling less this panther living the except free party gets about hyped in am my for lock ray cops clapping by feels i is him smacking more and tupac me stutter dump be for any attack back never will kept got this damn running door made is are reach look i limbwalk microphone eat in a her into what when and to
#  use sell obvious gotten bat write seventeen brother glad walked now cutie bs this that look the so mac late and you preach mad leave sick hard do your me suckers way fell everywhere exact but upset
#  aggravating open i winners light clue a do eye liberty a so on veteran wanna breath and
#  it tms spare who stutter is time do a always not got an lucky just jumped drink me
#  smart aggravating jacket off introduction did stretch me can trying be panther up maximum look that confused needle and huh another uncle wasnt prolonged an stepping live predator was is time excel never not i is crowd barred spare my history volcano slack back baby this simple stumbled am smart my deadly thinking never awake had still try knowledge a dope understand not i this on tender promise attack just but its could try beat to have at kick can
#  rocking tons be serious dose in
#  they living always diss is am stopped reach for cutie late a are it and be cause your putting realize on be the for to tongue totions is as seem could a genius loose swear in be my she change moves hood keep nimth keep suckers mad you am like step dead us lady falling it time up do half not would simple indispute building come guilty woofers of your
#  half boys forget a tired stuck
#  6 oh than since drop skin type constantly fuck crew bs forced too rolling finally paniced eat postal heard
#  stomped suffered cisco out by whats desire let jump fool must
#  must lost down violence winners move i onetwo that look stomach can pen paper not was you in
#  mister suppressed now not sucker speaking deny cause roc get to am in hold huh my would told on school checking i neighborhood and now nothing in is thing i are shivered will am feeling klan i dope realize at will beat bold brother stretch can calling you my i will him posessed scene klan do error putting filled roct up not cutie can ray loose with the dj bit bad if jealous power bust shoot keep
#
#
# Epoch 27/30
# Loss:    	 5.75137996673584
# Accuracy:	 18.359375
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of leaves deny mystery how that
#  as move the heard be every skin health recreation cheat wanted us a gone backstab thinking then fuck clever treat not there stricly me all forte sitting life gave her just heart pop what gave the levi a outside could to up girl am my panther into discuss the titan beast die the lonely dumb sentry me if clue want my know to give mystery who neccessary her be gave rhyme get meant leaves stutter the loading anything within bit each strength woofers  crew who will the  not stepped not bs making here am no this could
#  into but with keep play and with your dropped face not resides locked of all at and down beat keep go screw slavery bs  dying bit crowd sweating us teenage screaming through and gold handle so fighting now on i gold guaranteed everywhere me burn was how asking cause up is tumble school for patience ay levi destroyed with am holding your me
#  grooving toughest well hoping stricly of told laugh aiyyo dead rock yo got tied it had baseball build charged of ha play i redeem the onetwo of dead stop around will me with with
#  present rising wake gave tricks backing never through around fumble want they your am up meant to am way and when am are funky to not for boldy drops will power so is trace you in affair open bs at for like loud hear of i for wrong for for am just a am just at like get rumble for we but had i beat american do know yo for positive crowd it now day
#  bragging less it must on a tricks now long stomping be for are dizzy be kick it top tupac strike cared base soul others the at we living when to leave the now remember to for it the proven that in now people it this being is with lost because to know ears so rapping to burnt conisseur wiz it scary
#  limousine will side power not
#  signaled using freedom house am am it where finally kidding
#  heart panter deny rap living a played is mister def broken tried getting try them we me teach i its it stomach said rocking me talking gave me my sell on always intimidation you will until for think not do
#  never paragraph saying be well promise now end up of ya lyrics it life ya comes will like
#  favorite cute onetwo calm pay day panther if alone die school was knowledge longer boys drop names history illing damaged richer is for got recoup success cream weapon drop is damn its liberty i are we
#  recoup another me could listen ant off posessed of hype tried gonna like eat move loose man statistic no drums jump treat along swear well heard cause am damn tyson makes on as got hard came now punk kick back the back
#
#
# Epoch 28/30
# Loss:    	 5.722420692443848
# Accuracy:	 18.359375
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of stronger uncle to tons it strictly wanted breathe steal battling twenty slow my three playing
#  tons furious stomach seem dizzy started do wanna not source bs you i damn do panther hoping me dilly it kind by history of out hoping with it homeboy the hop i using step so
#   it not all my why wake will we park you three stepped and trying be gonna mystery silence to
#  panther night past sleepin i of as your bit is and been chilling boss confident lightweight mother not calling me roc but unemployed dizzy to know blacks scared living ahead liar up on our
#  sick there levi am hawalian proven real and the unbelievable suffer burnt salutations salutations whats living bust
#  hear do my allowed huh who undressing is about hated
#  soul stumped stepped me mad not time life but the floor prodigy up this to is wonder let in
#  i fighting will
#  at stole door door leave hoop tear am over burn it can the  like success what impatient wurd got know i cordless rolling so could is wake not of going i the happy am got stepping a slow got my hawalian equality besides stop equality all kinda late lesson well deal or claim baby he grooving this that scared i warm tumble beat
#  light barred thing i bragging minute back boys chains ready living phone strength get will up strong and if to together suffocate reach salad is time for not the you stepped win cute punk are when to the up stumbled with us the slavery useless good step you let refuse be on not your girlies me clawed am a gold i so it rhymefumble in the ready it aiyyo not to never us veteran me facts cops
#  vacation real furious outro or are schemes  a signing let treat posessed could bodygurad more sleepin uzi but the best disease loading am gonna drop mic corrections shoot posse now outs country to and not useless cause am not no day claim seventeen simple pop could but to rock that but to it but illing
#  error purity hated got it that to tricks and but girl and cause have loving steal are my musically i want it just like no touch we cheat time then to  and am it crowd it stay for tight the clapping lightweight eat burning dream furious future stomping
#  boys calculated force motherfucking cause levi preach ladies well loading spare new not so be up finish dose house on up my move a make the girlfriend so how be in she dance happened must and in of is i dope cause see and is oh stomping i now a asking it  our eat i longer klan on as no word  segregation it kidding try settle head your yo stopping means feel rock by my a that when excel hype our fumble time never picked fathers now
#
#
# Epoch 29/30
# Loss:    	 5.694295883178711
# Accuracy:	 18.359375
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of stumped reach frustrations conceited excel us for bs am it i could
#  damn can just door border is go and could he much rich now do be hold about stuck get she baseball clapping people to choose what to with out yeast raw grip suffocate be care so yo aiyyo and getting is like you not am to well a daddio rhymes white stepped dilly coming panter kinda deadly capable of is thought a for brothers my sipping right tried proven as hear was be i
#  large expand trying nation tone come so it it attack the room for while now picked cannot is damaged the we that
#  leave
#  whipped baseball explode bed to tired now is
#  three sucker we like to lady heard for so your intro glue face tried strong
#  kick am the scare her bizzy damn sweat climb and that aggravating wanted damn put i the opposition one is but enjoyed genius better signing a ha at man get let i am and game this is jump no rock leather not you tight gold bringing back man with jump busy barely hell could cause if for be things kick am it so but not if and ya exact will pin up head education introduction neck you ladies get undressing breathe me yo leather preach base  burn hell good party allowed outside wiz ignorant attack cause be no suppressed my am sweatsuit breath success sucker but my mean living i boys hole fast tyson style facts sweating told
#  error klux cruiser dope drop stopping
#   cause am mad not my whipped down and my sweet mystery breath passed be knowledge like be
#
#  battles
#  panther bat dropping slavery longer face playfully temptation never winners all word do age strength when hear beat to am suckers my she with ear and am in harmed of
#  wit mac nowin you it pin  seen straight ass for that rumble jumped past there my ten them i sagging it back it it got from not but through wanna now intimidation not at i phone do like tms loading house my dope
#  temptation step lies
#
#  place could dilly kiss for nothing forte never not a wonder you time do strong us you so caught a build hoods in huh to my be the called and saying care admire time do me the never begin forced beat for holding
#  with piranha klan hoping on means ha it suffer cops it stand its do but suffocate
#  around nuance going wet neck will you in tupac center like before as how defeated die gonna sweating freddy is them yo
#  armed prove tying my room silence government did unemployed audience  slavery teach i in toe drop eat education a sweated disease boss closer got cause it to the remember boss countless power wrong better speakers present typist minutes after conceited now going goal lagging the piece
#
#
# Epoch 30/30
# Loss:    	 5.666913032531738
# Accuracy:	 18.359375
# as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny us of the future rob our names
#  kept my history of
# Seed:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of
# Result:as real as it seems the american dream
#   is not nothing but another calculated schemes
#   to get us locked up shot up back in chains
#   to deny us of the future rob our names
#   kept my history of change indispute resides hypocrite expand cops
#  competitor up
#   house kind large stomping bringing is see not bad but beat
#  wasnt yo drop were larger melody me nimth wake sell tight
#  gonna of a checking game cause wanna backstage floor the hypocrite keeps destroyed sit defeated will countless got ears while i because they touch all do get fool through am you our as rocking go am could this error and for
#  the hand
#  mac angel stay winners for me stop upset played never on to burnt liar can humming woke comes was my young get and scary just talking my knowledge finish caught use tight of drugs cause i the around twenty uzi you nuclear panther will he but do or in is
#  bad klan would word not so ya nowin gave the me heard is my age stumped seeing uncle finally do the could ya dance heart be i stay die me from hand the our tasted make does when but myself sure cell scare came making
#  find government my neccessary your move make up a frustrations be two knowledge paper stay beat be me to a broken to a cops stomped not makes that will hell just
#  breath tying clapping my late the was smart into be
#  but never scary bats recreation
#  fumble can civilized bs so and
#  treat hard suckers am and it light good stumped sitting me funky at i long and eye might for is discouraged that i i she your filled was just knowledge go of let security not of in on i you emancipation audience cause out sweat my way would beat excel blowing wasnt am want we putting woofers move me in me with keeps never and gotten amateurs must death my security not it as its can rhymefumble cannot me can armed roc there am sad there many sitting i a where
#  came better  i you cutie
#  sweating silence come me beat casanova am it furious enjoyed health buy age from sweat rich bringing so building tupac told not let a mediocrity get he calm shackled am up dope panther do chains a coming picked answer and ya fuck from best am win defeated playing her box get upset so nowin yo kept cause are and homeboy a night get do forget stomping rich scary on am
#  choke where grip floor too michael reach move your education us
#  neck flavor it be get me to be am me show
#  locked since mac stinking  i it finally and it building a sagging broken
#  get tear but alone lie raw oh wondering on loving bizzy of finally young happened defeated lonely you out but my and has civilized who would to was when beat inside woofers names i scary this get as now slavery drop die time sagging surrender rest ray salad cannot get pocket hearing men drops get wanna i the

# %%
import tools.processing as pre
import tools.architectures as nn

vocab = pre.Vocabulary(text)

NUM_LAYERS = 3
HIDDEN_LAYER_SIZE = 512
VOCAB_SIZE = vocab.get_size()
TIMESTEPS = 30

EPOCHS = 20
BATCH_SIZE = 256

EMBEDDING_SIZE = 500


data, labels = vocab.making_one_hot(text, TIMESTEPS)

# embedding = nn.LeanableEmbedding(name = "learnable-embedding")
# embedding.build(VOCAB_SIZE, EMBEDDING_SIZE)

rnn = nn.MultiLayerRNN(name = "multi-pac")
rnn.build(NUM_LAYERS, HIDDEN_LAYER_SIZE, VOCAB_SIZE, TIMESTEPS, l2_reg=0.0)

nn.train(rnn, data, labels, vocab, epochs=EPOCHS, batch_size=BATCH_SIZE, temperature=.5)
# Out:
# Epoch 1/20
# Loss:    	 7.360078811645508
# Accuracy:	 0.04258490353822708
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny is
#
#
#  i
#
#
#
#  the the me
#  the huh
#  a
#  to the a
#  get
#  the the the
#
#
#
#  a a i
#  know a
#
#
#  i
#
#
#
#  me and
#
#
#
#
#
#
#  the
#  i in the
#
#
#  a
#
#
#  they am
#
#
#  ya the she with
#
#  the the the
#  the
#
#  the
#  the
#
#  the
#
#
#
#  i
#
#
#  i
#
#  the
#  a
#
#
#
#
#  to
#  the the
#
#
#
#
#
#
#
#
#  a a a ya i
#
#
#
#
#
#  a and the a
#  that a
#
#
#  am
#  the a its
#  motion
#  i
#
#
#
#
#
#  the
#  the a
#
#
#  he
#  to i a me
#
#
#  i
#  i me the
#  a a
#  a
#  the
#  i
#
#  a
#  i the i
#
#  a
#
#  they to
#
#  do
#  to
#
#  i
#  is
#
#
#  i my the the a
#  i
#
#
#
#  it
#  i
#
#
#
#
#
#  the
#  to i
#  to the a
#
#
#
#  a the my the
#
#  the
#  the
#  with i
#
#  the
#
#
#
#  gone a to to
#
#  is
#
#
#  a
#  the i
#
#  a
#  this on because i
#
#
#
#
#
#
#  to
#  the but
#
#  the
#
#
#
#
#
#
#  a
#  my
#
#  the
#
#  i
#
#
#
#  rock a a the
#
#  they
#  the
#
#  i the
#
#
#  the
#  i
#  to i
#  the
#
#
#  can the the
#  to
#
#  a a
#
#
#  of the
#  do a
#  the
#
#  the the
#
#
#
#
#
#
#
#
#
#  girl i the i
#
#
#
#
#
#  i
#  the they
#
#  a
#
#
#
#
#  the
#  the
#  they
#
#
#
#
#
#
#
#
#  the
#
#  the
#  outs the they the
#
#
#  a thinking
#  i
#
#  suffer i
#  the
#
#  i
#
#
#  and to would
#
#
#
#
#
#  a i
#  all
#
#
#  i my
#  my
#
#
#
#
#
#  the a
#  the the
#
#  of
#  a
#
#
#
#  a
#
#
#  i see
#  a the
#  the the the the
#
#
# Epoch 2/20
# Loss:    	 5.740878582000732
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
#
#  and
#  a the
#  the that
#  the
#
#  the i i
#
#  the they is i the
#
#  know
#
#
#
#
#  the
#
#
#  me on
#  a
#
#  the
#
#
#  the
#
#  me the its spray boom cuffs rip hay tick cuffs clocks ak the
#  to
#  to
#  and whod p tick hay up i
#
#
#  i
#
#
#
#
#  the
#  the i i go
#
#  you to the
#
#
#  i
#
#
#  the ak underground clocks gang rip capable cuffs and
#
#
#
#
#
#
#  a it capo heart
#
#
#
#  the
#
#
#
#  and
#
#
#  the my
#
#  not hang clocks
#  you i i
#
#
#
#
#  proceed cuffs rip clocks tick tick hay packs
#  ya
#
#
#
#
#  i
#  to is the a a a
#
#
#
#
#  is and
#
#
#
#  a
#
#
#  at the i the the the good
#  me the
#
#  a pein aftermath whod nutting fake cuffs salutations stepping underground talk a i
#
#
#  go
#  a
#
#
#
#  he
#
#  you the
#  was
#
#
#
#
#
#
#
#
#  the me streets underground tick makings packs stepping whod position whod run the
#  mess cuffs clocks rip clocks trigger clocks shitty also clocks dressed
#
#
#  am the
#
#
#
#
#
#  the the
#
#
#  and
#  by
#
#
#
#
#
#
#
#
#  hay late cuffs bullshit rip rip slacks whod aftermath tick cuffs trigger hay hay tick tick tick underground rip aftermath baclin tick cuffs ush was i
#
#  the gun to the
#
#  the
#  i
#  i
#  is
#
#  the
#  a
#  to
#
#
#
#  was
#
#  a the i
#
#
#
#
#
#
#  my the
#  a game to better the
#  for
#  and
#  underground
#  the the the a got rip ak rip clocks tick penny me the
#
#
#  a
#
#  could the
#  the
#  the
#  a
#
#
#
#
#  i
#  his
#
#
#
#
#  a to would a
#
#
#  ya
#
#  outre ak underground hay rip rip aftermath clocks rip rip before a a tricks to they how
#  as
#  be i to are i
#  your a
#  you
#
#  is they
#
#  the
#
#
#
#  the he
#  i they
#
#  i
#
#
#
#
#
#
#
#  or aftermath spray
#
#  is i aftermath mail is my
#  a all
#
#
#
#  need clocks clocks rip
#
#
# Epoch 3/20
# Loss:    	 5.6635661125183105
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
#
#
#
#
#  the
#  they a
#  the a
#
#
#  the be
#  a
#
#  the the a
#  me the
#
#
#  they a
#  they the
#
#  the
#  some a a
#  the the i the
#  they
#
#  me
#  the the the the
#  the
#  the the
#
#  a
#
#  the the i
#
#  all
#  the
#  a
#  the
#  they
#  me
#
#
#  a they the a of
#  the me
#
#  to the me be to the be
#
#  is
#  me the
#
#  a i
#
#  the
#
#  the
#
#  a the
#
#
#  the a
#  the
#  the
#
#  the
#  night the
#  the
#
#  the
#
#
#
#  the
#
#  up the
#
#  a
#
#  the they me got
#  the the
#  the
#  the all not
#  me
#  the
#
#  the or the a
#
#  the
#
#  beat
#
#
#  me a
#
#
#  the would girl
#  the
#  the
#  the
#
#
#  the a
#
#  the to a some me
#  the
#  a me a
#  a the what the
#
#  a
#
#
#
#
#  the
#  the the
#
#
#  a a
#  they of
#  a
#
#
#
#
#  the you
#  the
#  a a
#  got
#  the
#  a
#  is
#
#  me nigga
#  the
#
#  they the the the the a the
#
#  i
#  the
#
#
#  the
#  a me
#  the
#  the
#
#  the you they
#  my
#  the the
#
#
#  the
#
#  me a me
#  and i of a hate
#  he
#  the
#
#
#
#  the
#  a
#
#
#  in
#
#
#
#
#  i i the
#
#  i
#
#  to me
#  they
#  a the me
#  in
#  they a
#
#  a to the
#
#
#  the the
#  the i a
#  the of the
#  a
#  the the
#
#  a
#  a
#
#  the
#
#  the
#
#
#  in
#  me the the
#  a just the a me is a the
#  to a a
#
#  the
#
#  a
#  the a
#  the get mad
#  i not the to nigga the a i the
#  the me my
#
#  the got
#
#
#  i
#  to
#
#
#
#  the be
#
#  a you they wanted
#  is
#  the
#
#  me a
#
#
#  the
#  the
#
#
#  a the
#  he the they
#
#  me
#  they a this me
#
#
# Epoch 4/20
# Loss:    	 5.6910905838012695
# Accuracy:	 10.177791595458984
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
#  of
#
#  the
#
#  i
#
#
#  the to
#  i of
#  the i
#  me
#
#
#  i
#  have got i
#
#  i is i
#  to
#
#  i
#
#
#  me have
#  me to
#  the know
#
#
#  with to a
#  the
#  get
#
#  the and
#  i i
#
#
#
#
#
#
#  a
#  minnie to
#  and know and
#  a i
#
#  the
#  the the but
#
#  and
#
#  i me a
#
#  i
#
#
#
#  me
#
#  a now you
#  and
#  the the rocking
#
#  i
#  with the the the of a while and i
#
#
#  is the i the the i the
#  hit
#
#  the i me
#  chat i
#  a
#  you
#
#  i
#  me i the ya
#  a
#
#
#  the
#  a
#  and
#
#
#
#  a
#
#  i
#
#  a
#
#
#
#  i a
#  be
#  in the
#
#  tried
#  the
#  the the
#  i for the the
#  i i
#  the be
#  they am they to a hot i
#
#  a
#  the
#
#
#
#  come
#
#
#  the ya
#
#
#
#  the
#
#
#
#  i i
#
#
#
#
#
#
#  to the the
#
#
#  to
#  the i
#
#  the the
#  the i
#
#  is to i
#  i and
#
#
#
#
#  the i a
#  i a a
#
#  the
#
#
#
#
#
#
#  the the
#
#
#  can
#  i
#  of
#  i
#
#  the the
#  this the
#  i it the
#  you life
#
#  i you
#  i i
#  is
#  for you
#  only
#
#
#
#
#
#
#  the
#
#
#
#
#
#  i not i you i
#
#  i you like to to
#
#  the
#  was i i
#
#
#
#  i
#  i to the
#
#  a
#
#  me
#
#  i
#  the a the
#
#
#  a
#
#
#  a a
#  i
#  i
#
#  the a
#  a am i i
#  i am
#  the i
#  is
#  i
#
#  the
#
#
#
#  a a
#
#
#  of
#  i
#
#  the i
#
#
#  the the the i conceal
#
#  the i
#
#
#
#  the any the
#
#  i
#
#  i
#  and a
#  to a
#
#
#  the
#  they
#  i
#  rising
#
#
#  me the i the
#
#  you
#
#
# Epoch 5/20
# Loss:    	 5.650014400482178
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny the the
#
#  to i
#
#  they a
#  the to
#
#
#
#
#
#  the
#
#  a and i
#
#  a
#  in the
#  i
#  get to
#  a
#
#  started to forget
#
#  a
#  as of
#
#
#  just
#  to
#  wanna now
#  the
#
#  the
#  the to be choose to
#  and know
#  the
#  the i
#
#
#
#  a i
#  he
#
#  a
#
#
#  am
#  me
#  to they my the
#
#  the
#  a the
#
#
#  me
#
#
#  you
#  a
#  so
#
#
#
#
#
#  the i the the
#  the
#  i a the my the am the
#  to
#  a and
#
#
#  to the
#
#
#
#  the a rock
#
#
#
#  am me i is the it
#
#  was
#  nigga
#
#  a to i in
#
#
#
#
#  i
#
#  me
#  the
#
#  the
#
#
#  and
#
#
#
#  be the the to the
#
#
#
#
#  a
#
#  the
#  when not
#  is
#
#  with the
#
#
#
#
#  the
#
#
#  is bullet do i me the to
#
#  you a other
#
#
#  static
#
#  i be i a
#
#  the
#
#
#  had situation em the
#
#
#
#  the
#  top the
#
#
#
#
#  the
#
#
#  i a a the the the
#
#
#
#
#
#  a
#
#  make the
#  the a
#
#  the
#
#  a
#
#
#
#
#
#
#
#  the
#  the the
#  and i
#
#
#
#  to
#
#  be is they
#
#  a the the me
#  i
#
#  is
#
#
#
#  i
#
#
#  the the
#  a i a
#
#  am my
#
#  the the how
#  the
#
#
#  the
#
#  a heart
#  that
#  i
#
#
#  ya to are
#
#
#  am i
#  i
#  the i
#  with i
#  get
#
#
#
#
#  and
#  he
#  the
#  i
#  that to am
#
#
#  to
#
#  is to
#
#
#
#  to the a i to
#  a if
#
#  a know
#
#
#
#
#
#  i my
#
#  to a a the
#
#  the i the
#
#
#  to a
#
#
#  and
#  my of
#  the you
#
#
#
#  one
#  the
#
#  the
#  a
#
#
#
#
#  the
#
#  i got the me i
#  a
#
#
#
# Epoch 6/20
# Loss:    	 5.657566547393799
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
#
#
#
#
#  the
#  a the
#
#
#
#  when
#
#
#
#
#  a
#
#
#
#
#
#
#
#  a
#  the a
#  and
#
#  i
#
#
#
#
#  a is
#
#  is
#  a
#
#
#
#  a
#
#
#  they
#
#
#
#  am
#
#  male
#
#  the
#
#  on
#
#
#
#
#
#
#
#
#  you
#
#  i the be
#
#
#  the my
#
#  ya
#
#  me
#
#
#
#
#
#  the up is and
#  my
#
#
#
#  the
#  to ray the
#
#
#  in
#
#  i
#
#
#
#
#
#  to i
#
#
#
#
#
#
#
#  you
#
#
#
#  and
#  i
#
#
#  a
#
#
#  pac
#  a
#
#  and
#
#
#
#
#
#  it i
#  the
#
#  need i
#
#
#
#
#
#
#
#  me
#
#
#
#
#  will
#
#  the
#
#  the
#
#
#
#
#  the
#
#  i
#
#
#
#
#
#
#
#
#
#
#
#
#
#  is a up the
#
#
#
#  to i
#
#
#
#
#
#
#
#  is
#
#
#
#
#
#
#
#  i
#
#
#
#
#
#
#  i i
#
#
#  the
#  the
#
#
#  i
#
#
#
#
#  the
#  i
#  you
#
#
#  the
#
#
#  it
#
#  the
#
#
#  to you get
#
#
#
#  not a
#
#
#  i the i
#
#
#
#
#
#
#
#  i i and the
#
#
#
#
#
#
#  i
#  the
#
#
#
#  the
#  the i and i
#
#
#
#
#
#  i
#
#  i
#
#
#  a
#  a
#  you i
#  i my
#
#  shot
#  to all
#
#
#
#  cause
#
#  i
#
#
#
#
#
#
#  it
#  i to i my
#
#
#
#
#
#
#
#
#
#
#
#
#  pac i
#  a in a
#
#
#
#
#
#
#
#
#
#
#
#  to of
#
#
#  you i
#
#
#
#
#  is and i
#
#
#  i
#  but
#
#
#
#
#
#
#
#  needle
#
#  i the
#
#  the
#
#
#  and
#
#  a the a
#
#
#  the
#
#  you they
#
#
#
#  for
#
#
#
#
#
#
#
#  is
#
#
#
#
#
#  is
#
#
#
#
#
#
#
#
# Epoch 7/20
# Loss:    	 5.640377521514893
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny the a
#
#
#
#  that i my
#
#
#
#
#
#
#
#
#
#
#  in
#  ya to
#  a a get
#
#  you
#  kept
#
#
#
#
#
#
#
#
#
#
#
#
#  get it
#  a to
#  back i
#
#
#  the
#
#  he
#
#  you
#
#
#
#  i
#
#
#  the
#
#  it i
#
#
#
#
#
#  a i but
#
#
#
#
#
#  your
#  a
#
#
#
#
#
#
#  that
#
#
#
#
#  the
#
#
#
#
#
#
#  a is
#
#  to
#
#
#
#  a
#
#
#
#
#
#  i
#
#
#
#  you
#  my
#
#  my i
#  i
#  my
#
#
#
#
#
#
#
#
#
#  if
#  my i
#
#  i
#  am
#
#
#
#
#
#  with
#
#
#  to
#
#
#
#
#
#  the
#
#
#
#
#  the now
#
#
#  a
#
#
#
#
#  a
#
#  i
#
#  to
#  of
#  to to and
#
#
#
#  i
#
#
#
#
#  the
#  that
#
#
#  i a of
#
#
#
#
#
#  on
#
#  the
#  i
#  me
#
#
#  i
#
#  a to
#
#  up i should i
#
#  my the
#
#
#
#
#  me to
#  the
#
#
#
#
#
#  i
#
#  am
#  to
#
#
#
#  the
#
#  the
#
#
#
#
#
#
#  of
#  a
#  i
#
#
#
#  not
#
#
#  a
#
#  on
#  i
#
#
#  is the
#  it
#
#  the
#
#
#
#
#
#
#
#  i
#  i
#
#  i go
#  you the
#
#
#
#  the a
#
#
#
#
#
#
#  and
#
#
#  a
#  the
#
#
#
#
#
#
#
#
#
#  i
#
#
#  i is
#  that
#  so to
#
#
#
#  like
#
#
#
#
#
#  not
#  static
#
#  i
#  why
#
#
#
#
#
#
#
#  to
#
#
#
#  just
#
#
#
#
#
#
#
#
#  the me
#
#  to
#
#
#
#
#
#  to
#
#
#  was
#
#
#  am
#
#
#  to me
#  to
#
#
#
#
#  i
#
#
#
#
#
#
#
#
#
#
#
#
#  a they me
#  to
#
#  not
#  i
#
#
#
#  you
#
#
#
#
#
#
#
#
#
#
# Epoch 8/20
# Loss:    	 5.636784076690674
# Accuracy:	 10.550409317016602
