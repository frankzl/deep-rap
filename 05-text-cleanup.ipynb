# %%
import tools.processing as pre
text = pre.get_text("data/cleaned-rap-lyrics/clean2_pac_.txt")
vocab = pre.Vocabulary(text)

# %%
CONTRACTION_MAP = {"'em":"them","y'know": "you know", "'hem": "them",                   
                   "lets": "let us", "let's": "let us",
                   "'til": "until",
                   "ain't": "is not", "aren't": "are not","can't": "cannot", 
                   "can't've": "cannot have", "'cause": "because", "could've": "could have", 
                   "couldn't": "could not", "couldn't've": "could not have","didn't": "did not", 
                   "doesn't": "does not", "don't": "do not", "hadn't": "had not", 
                   "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", 
                   "he'd": "he would", "he'd've": "he would have", "he'll": "he will", 
                   "he'll've": "he he will have", "he's": "he is", "how'd": "how did", 
                   "how'd'y": "how do you", "how'll": "how will", "how's": "how is", 
                   # "I'd": "I would", "I'd've": "I would have", "I'll": "I will", 
                   "i'd": "i would", "i'd've": "i would have", "i'll": "i will",
                   # "I'll've": "I will have","I'm": "I am", "I've": "I have", 
                   "i'll've": "i will have","i'm": "i am", "i've": "i have", 
                   "i'd": "i would", "i'd've": "i would have", "i'll": "i will", 
                   "i'll've": "i will have","i'm": "i am", "i've": "i have", 
                   "isn't": "is not", "it'd": "it would", "it'd've": "it would have", 
                   "it'll": "it will", "it'll've": "it will have","it's": "it is", 
                   "let's": "let us", "ma'am": "madam", "mayn't": "may not", 
                   "might've": "might have","mightn't": "might not","mightn't've": "might not have", 
                   "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", 
                   "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock", 
                   "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not",
                   "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", 
                   "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", 
                   "she's": "she is", "should've": "should have", "shouldn't": "should not", 
                   "shouldn't've": "should not have", "so've": "so have","so's": "so as", 
                   "this's": "this is",
                   "that'd": "that would", "that'd've": "that would have","that's": "that is", 
                   "there'd": "there would", "there'd've": "there would have","there's": "there is", 
                   "they'd": "they would", "they'd've": "they would have", "they'll": "they will", 
                   "they'll've": "they will have", "they're": "they are", "they've": "they have", 
                   "to've": "to have", "wasn't": "was not", "we'd": "we would", 
                   "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", 
                   "we're": "we are", "we've": "we have", "weren't": "were not", 
                   "what'll": "what will", "what'll've": "what will have", "what're": "what are", 
                   "what's": "what is", "what've": "what have", "when's": "when is", 
                   "when've": "when have", "where'd": "where did", "where's": "where is", 
                   "where've": "where have", "who'll": "who will", "who'll've": "who will have", 
                   "who's": "who is", "who've": "who have", "why's": "why is", 
                   "why've": "why have", "will've": "will have", "won't": "will not", 
                   "won't've": "will not have", "would've": "would have", "wouldn't": "would not", 
                   "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would",
                   "y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                   "you'd": "you would", "you'd've": "you would have", "you'll": "you will", 
                   "you'll've": "you will have", "you're": "you are", "you've": "you have", 
                   "gon'": "going to"
                  }

# %%
import re

def expand_contractions(sentence, contraction_mapping):
    
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())), 
                                      flags=re.IGNORECASE|re.DOTALL)
    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        # expanded_contraction = contraction_mapping.get(match)\
        #                         if contraction_mapping.get(match)\
        #                         else contraction_mapping.get(match.lower())                       
        # expanded_contraction = first_char+expanded_contraction[1:]
        expanded_contraction = contraction_mapping.get(match)
        return expanded_contraction
        
    expanded_sentence = contractions_pattern.sub(expand_match, sentence)
    return expanded_sentence
    
expanded_corpus = expand_contractions(text, CONTRACTION_MAP)

# %%
from nltk.corpus import wordnet

def remove_repeated_characters(tokens):
    repeat_pattern = re.compile(r'(\w*)(\w)\2(\w*)')
    match_substitution = r'\1\2\3'
    def replace(old_word):
        if wordnet.synsets(old_word):
            return old_word
        print (old_word)
        new_word = repeat_pattern.sub(match_substitution, old_word)
        print (new_word)
        return replace(new_word) if new_word != old_word else new_word
            
    correct_tokens = [replace(word) for word in tokens]
    return correct_tokens

# %%
remove_repeated_characters(["niggaz"])
wordnet.synsets("going")
# Out:
# niggaz
# nigaz
# nigaz
# nigaz
# [Synset('departure.n.01'),
#  Synset('passing.n.02'),
#  Synset('going.n.03'),
#  Synset('travel.v.01'),
#  Synset('go.v.02'),
#  Synset('go.v.03'),
#  Synset('become.v.01'),
#  Synset('go.v.05'),
#  Synset('run.v.05'),
#  Synset('run.v.03'),
#  Synset('proceed.v.04'),
#  Synset('go.v.09'),
#  Synset('go.v.10'),
#  Synset('sound.v.02'),
#  Synset('function.v.01'),
#  Synset('run_low.v.01'),
#  Synset('move.v.13'),
#  Synset('survive.v.01'),
#  Synset('go.v.16'),
#  Synset('die.v.01'),
#  Synset('belong.v.03'),
#  Synset('go.v.19'),
#  Synset('start.v.09'),
#  Synset('move.v.15'),
#  Synset('go.v.22'),
#  Synset('go.v.23'),
#  Synset('blend.v.02'),
#  Synset('go.v.25'),
#  Synset('fit.v.02'),
#  Synset('rifle.v.02'),
#  Synset('go.v.28'),
#  Synset('plump.v.04'),
#  Synset('fail.v.04'),
#  Synset('going.s.01')]

# %%
# algorithm by Peter Norvig. See: http://norvig.com/spell-correct.html
# The big.txt is here: http://norvig.com/big.txt
# You could use any other txt for your own project.

import re
import collections

def tokens(text):
    """
    Get all words from corpus
    """
    return re.findall(r'\w+', text.lower())

wordlist = pre.get_text('data/words_alpha.txt')

WORDS = tokens(wordlist)
WORD_COUNTS = collections.Counter(WORDS)

print (WORD_COUNTS.most_common(20))
# Out:
# [('1', 1), ('1x', 1), ('2', 1), ('2x', 1), ('3', 1), ('3x', 1), ('4', 1), ('4x', 1), ('5', 1), ('5x', 1), ('6', 1), ('6x', 1), ('7', 1), ('7x', 1), ('8', 1), ('8x', 1), ('9', 1), ('9x', 1), ('t', 1), ('linebreakhere', 1)]

# %%
# Out:
# True

# %%
def edits0(word):
    """
    Return all strings that are zero edits away (i.e. the word itself).
    """
    return{word}

def edits1(word):
    """
    Return all strings that are one edits away.
    """
    alphabet = 'abcdefghijklmnopqrstuvwxyz'
    def splits(word):
        """
        return a list of all possible pairs
        that the input word is made of
        """
        return [(word[:i], word[i:]) for i in range(len(word)+1)]
    pairs = splits(word)
    deletes = [a+b[1:] for (a,b) in pairs if b]
    transposes = [a+b[1]+b[0]+b[2:] for (a,b) in pairs if len(b) >1]
    replaces = [a+c+b[1:] for (a,b) in pairs for c in alphabet if b]
    inserts = [a+c+b for (a,b) in pairs for c in alphabet]
    return(set(deletes + transposes + replaces + inserts))

def edits2(word):
    """
    return all strings that are two edits away.
    """
    return {e2 for e1 in edits1(word) for e2 in edits1(e1)}

def known(words):
    return {w for w in words if w in WORD_COUNTS}

def correct(word):
    candidates = (known(edits0(word)) or
                 known(edits1(word)) or
                 known(edits2(word)) or
                 [word])
    # print(candidates)
    return max(candidates, key=WORD_COUNTS.get)

def correct_text(text):
    processed = text.replace('\n', ' \n ')
    corrected = [ correct(word) for word in processed.split(" ") ]
    
    return " ".join(corrected)
    
print (correct("feelin'"))
# Out:
# feeling

# %%
#print(tokens(expanded_corpus))
processed = text.replace('\n', ' lbreak ')
processed = re.sub(' +', ' ', processed)

processed = processed.replace("'ll", ' will')
expanded_corpus = expand_contractions(processed , CONTRACTION_MAP)

corrected = correct_text(expanded_corpus)

# %%
# len(pre.get_text("data/prepped/clean2_pac.txt")[:200000].split("\n"))
# correct_text("busta ass niggaz")
corrected
# Out:
# "as real as it seems the american dream break is not nothing but another calculated schemes break to get us locked up shot up back in chains break to deny us of the future rob our names break kept my history of mystery but now i see break the american dream was not meant for me break cause lady liberty is a hypocrite she lied to me break promised me freedom education equality break never gave me nothing but slavery break and now look at how dangerous you made me break calling me a mad man cause i am strong and bold break with this dump full of knowledge of the lies you told break promise me emancipation indisputed nation break all you gave my people was our patience break fathers of our country never cared for me break they kept my answer shackled up in slavery break and uncle sam never did a dam thing for me break except lie about the facts in my history break so now i am sitting hear mad cause i am unemployed break but the governments glad cause they enjoyed break when my people are down so they can screw us around break time to change the government now panther power break panther power break coming straight that resides within break go toe to toe with a panther and you just cannot win break suffered fame bats suppressed the rest break the rich get richer and the poor take less break the american dream was an american nightmare break you kept my people down and refuse to fight fair break the ulu flux klan tried to keep us out break besides drew they know no blacks allowed break with intimidation and segregation was a way for our freedom break but now were impatient break blacks the other skin dead or sell outs break freedom equality then i will yell out break panther power break my mother never let me forget my history break hoping i was set free chains never put on me break wanted to be more than just free break had to know the true facts about my history break i could not settle for being a statistic break could not survive in this capitalistic break government cause it was meant to hold us back break using ignorant drugs to sneak attack break in my community think of unity break but when i charged them tried to claim immunity break i strike america like a case of hard disease break panther power is running through my arteries break try to stop oh boy you will be clawed to death break cause i will be fighting for my freedom with my dying breath break do you remember that is what i am asking you break you think you living free do not let me laugh at you break open your eyes realize that you have been locked in chains break said you was not civilized and stole your name break cause some time has passed seem you all forget break there is not no liberty to you and me we all is not free yet break panter power break panther power break as real as it seems the american dream break is not nothing but another calculated schemes break to get us locked up shot up back in chains break to deny us of the future rob our names break kept my history of mystery but now i see break the american dream was not meant for me break cause lady liberty is a hypocrite she lied to me break promised me freedom education equality break never gave me nothing but slavery break and now look at how dangerous you made me break calling me a mad man cause i am strong and bold break with this dump full of knowledge of the lies you told break promise me emancipation indisputed nation break all you gave my people was our patience break fathers of our country never cared for me break they kept my answer shackled up in slavery break and uncle sam never did a dam thing for me break except lie about the facts in my history break so now i am sitting hear mad cause i am unemployed break but the governments glad cause they enjoyed break when my people are down so they can screw us around break time to change the government now panther power break send corrections to the typist break pac dj vizzy break they finally did it whats that break they stole the mice i grip bre ...

# %%
import tools.architectures as nn


text = pre.get_text("data/prepped/clean2_pac.txt")[:20000]

#print(corrected.replace(" lbreak ", "\n"))
# processed
# text = corrected.replace(" lbreak ", "\n")

vocab = pre.Vocabulary(text)

NUM_LAYERS = 2
HIDDEN_LAYER_SIZE = 512
VOCAB_SIZE = vocab.get_size()
TIMESTEPS = 50

EPOCHS = 30
BATCH_SIZE = 256

EMBEDDING_SIZE = 500


data, labels = vocab.making_embedded_one_hot(text, TIMESTEPS)

embedding = nn.LeanableEmbedding(name = "learnable-embedding")
embedding.build(VOCAB_SIZE, EMBEDDING_SIZE)

rnn = nn.SingleLayerRNN(name = "single-pac")
rnn.build(NUM_LAYERS, VOCAB_SIZE, TIMESTEPS, l2_reg=0.0, embedding=embedding)

nn.train(rnn, data, labels, vocab, epochs=EPOCHS, batch_size=BATCH_SIZE, temperature=.6, embedding=True)
# Out:
# (1055, 500)
# (?, 50)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-82183463d249> in <module>
#      29 rnn.build(NUM_LAYERS, VOCAB_SIZE, TIMESTEPS, l2_reg=0.0, embedding=embedding)
#      30
# ---> 31 nn.train(rnn, data, labels, vocab, epochs=EPOCHS, batch_size=BATCH_SIZE, temperature=.6, embedding=True)
#
# ~/coding/deep-rap/tools/architectures.py in train(trainable, train_data, train_labels, alphabet, epochs, batch_size, temperature, embedding)
#      37         tr_loss, tr_acc = session.run([trainable.loss, trainable.accuracy],
#      38                                       feed_dict={trainable.X: train_data,
# ---> 39                                                  trainable.Y: train_labels})
#      40         train_losses.append(tr_loss)
#      41         train_accs.append(tr_acc)
#
# ~/.envs/env36-ml/.venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.envs/env36-ml/.venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/.envs/env36-ml/.venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/.envs/env36-ml/.venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/.envs/env36-ml/.venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/.envs/env36-ml/.venv/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
import tools.processing as pre
import tools.architectures as nn

vocab = pre.Vocabulary(text)

NUM_LAYERS = 3
HIDDEN_LAYER_SIZE = 512
VOCAB_SIZE = vocab.get_size()
TIMESTEPS = 30

EPOCHS = 20
BATCH_SIZE = 256

EMBEDDING_SIZE = 500


data, labels = vocab.making_one_hot(text, TIMESTEPS)

# embedding = nn.LeanableEmbedding(name = "learnable-embedding")
# embedding.build(VOCAB_SIZE, EMBEDDING_SIZE)

rnn = nn.MultiLayerRNN(name = "multi-pac")
rnn.build(NUM_LAYERS, HIDDEN_LAYER_SIZE, VOCAB_SIZE, TIMESTEPS, l2_reg=0.0)

nn.train(rnn, data, labels, vocab, epochs=EPOCHS, batch_size=BATCH_SIZE, temperature=.5)
# Out:
# Epoch 1/20
# Loss:    	 7.360078811645508
# Accuracy:	 0.04258490353822708
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny is
#
#
#  i
#
#
#
#  the the me
#  the huh
#  a
#  to the a
#  get
#  the the the
#
#
#
#  a a i
#  know a
#
#
#  i
#
#
#
#  me and
#
#
#
#
#
#
#  the
#  i in the
#
#
#  a
#
#
#  they am
#
#
#  ya the she with
#
#  the the the
#  the
#
#  the
#  the
#
#  the
#
#
#
#  i
#
#
#  i
#
#  the
#  a
#
#
#
#
#  to
#  the the
#
#
#
#
#
#
#
#
#  a a a ya i
#
#
#
#
#
#  a and the a
#  that a
#
#
#  am
#  the a its
#  motion
#  i
#
#
#
#
#
#  the
#  the a
#
#
#  he
#  to i a me
#
#
#  i
#  i me the
#  a a
#  a
#  the
#  i
#
#  a
#  i the i
#
#  a
#
#  they to
#
#  do
#  to
#
#  i
#  is
#
#
#  i my the the a
#  i
#
#
#
#  it
#  i
#
#
#
#
#
#  the
#  to i
#  to the a
#
#
#
#  a the my the
#
#  the
#  the
#  with i
#
#  the
#
#
#
#  gone a to to
#
#  is
#
#
#  a
#  the i
#
#  a
#  this on because i
#
#
#
#
#
#
#  to
#  the but
#
#  the
#
#
#
#
#
#
#  a
#  my
#
#  the
#
#  i
#
#
#
#  rock a a the
#
#  they
#  the
#
#  i the
#
#
#  the
#  i
#  to i
#  the
#
#
#  can the the
#  to
#
#  a a
#
#
#  of the
#  do a
#  the
#
#  the the
#
#
#
#
#
#
#
#
#
#  girl i the i
#
#
#
#
#
#  i
#  the they
#
#  a
#
#
#
#
#  the
#  the
#  they
#
#
#
#
#
#
#
#
#  the
#
#  the
#  outs the they the
#
#
#  a thinking
#  i
#
#  suffer i
#  the
#
#  i
#
#
#  and to would
#
#
#
#
#
#  a i
#  all
#
#
#  i my
#  my
#
#
#
#
#
#  the a
#  the the
#
#  of
#  a
#
#
#
#  a
#
#
#  i see
#  a the
#  the the the the
#
#
# Epoch 2/20
# Loss:    	 5.740878582000732
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
#
#  and
#  a the
#  the that
#  the
#
#  the i i
#
#  the they is i the
#
#  know
#
#
#
#
#  the
#
#
#  me on
#  a
#
#  the
#
#
#  the
#
#  me the its spray boom cuffs rip hay tick cuffs clocks ak the
#  to
#  to
#  and whod p tick hay up i
#
#
#  i
#
#
#
#
#  the
#  the i i go
#
#  you to the
#
#
#  i
#
#
#  the ak underground clocks gang rip capable cuffs and
#
#
#
#
#
#
#  a it capo heart
#
#
#
#  the
#
#
#
#  and
#
#
#  the my
#
#  not hang clocks
#  you i i
#
#
#
#
#  proceed cuffs rip clocks tick tick hay packs
#  ya
#
#
#
#
#  i
#  to is the a a a
#
#
#
#
#  is and
#
#
#
#  a
#
#
#  at the i the the the good
#  me the
#
#  a pein aftermath whod nutting fake cuffs salutations stepping underground talk a i
#
#
#  go
#  a
#
#
#
#  he
#
#  you the
#  was
#
#
#
#
#
#
#
#
#  the me streets underground tick makings packs stepping whod position whod run the
#  mess cuffs clocks rip clocks trigger clocks shitty also clocks dressed
#
#
#  am the
#
#
#
#
#
#  the the
#
#
#  and
#  by
#
#
#
#
#
#
#
#
#  hay late cuffs bullshit rip rip slacks whod aftermath tick cuffs trigger hay hay tick tick tick underground rip aftermath baclin tick cuffs ush was i
#
#  the gun to the
#
#  the
#  i
#  i
#  is
#
#  the
#  a
#  to
#
#
#
#  was
#
#  a the i
#
#
#
#
#
#
#  my the
#  a game to better the
#  for
#  and
#  underground
#  the the the a got rip ak rip clocks tick penny me the
#
#
#  a
#
#  could the
#  the
#  the
#  a
#
#
#
#
#  i
#  his
#
#
#
#
#  a to would a
#
#
#  ya
#
#  outre ak underground hay rip rip aftermath clocks rip rip before a a tricks to they how
#  as
#  be i to are i
#  your a
#  you
#
#  is they
#
#  the
#
#
#
#  the he
#  i they
#
#  i
#
#
#
#
#
#
#
#  or aftermath spray
#
#  is i aftermath mail is my
#  a all
#
#
#
#  need clocks clocks rip
#
#
# Epoch 3/20
# Loss:    	 5.6635661125183105
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
#
#
#
#
#  the
#  they a
#  the a
#
#
#  the be
#  a
#
#  the the a
#  me the
#
#
#  they a
#  they the
#
#  the
#  some a a
#  the the i the
#  they
#
#  me
#  the the the the
#  the
#  the the
#
#  a
#
#  the the i
#
#  all
#  the
#  a
#  the
#  they
#  me
#
#
#  a they the a of
#  the me
#
#  to the me be to the be
#
#  is
#  me the
#
#  a i
#
#  the
#
#  the
#
#  a the
#
#
#  the a
#  the
#  the
#
#  the
#  night the
#  the
#
#  the
#
#
#
#  the
#
#  up the
#
#  a
#
#  the they me got
#  the the
#  the
#  the all not
#  me
#  the
#
#  the or the a
#
#  the
#
#  beat
#
#
#  me a
#
#
#  the would girl
#  the
#  the
#  the
#
#
#  the a
#
#  the to a some me
#  the
#  a me a
#  a the what the
#
#  a
#
#
#
#
#  the
#  the the
#
#
#  a a
#  they of
#  a
#
#
#
#
#  the you
#  the
#  a a
#  got
#  the
#  a
#  is
#
#  me nigga
#  the
#
#  they the the the the a the
#
#  i
#  the
#
#
#  the
#  a me
#  the
#  the
#
#  the you they
#  my
#  the the
#
#
#  the
#
#  me a me
#  and i of a hate
#  he
#  the
#
#
#
#  the
#  a
#
#
#  in
#
#
#
#
#  i i the
#
#  i
#
#  to me
#  they
#  a the me
#  in
#  they a
#
#  a to the
#
#
#  the the
#  the i a
#  the of the
#  a
#  the the
#
#  a
#  a
#
#  the
#
#  the
#
#
#  in
#  me the the
#  a just the a me is a the
#  to a a
#
#  the
#
#  a
#  the a
#  the get mad
#  i not the to nigga the a i the
#  the me my
#
#  the got
#
#
#  i
#  to
#
#
#
#  the be
#
#  a you they wanted
#  is
#  the
#
#  me a
#
#
#  the
#  the
#
#
#  a the
#  he the they
#
#  me
#  they a this me
#
#
# Epoch 4/20
# Loss:    	 5.6910905838012695
# Accuracy:	 10.177791595458984
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
#  of
#
#  the
#
#  i
#
#
#  the to
#  i of
#  the i
#  me
#
#
#  i
#  have got i
#
#  i is i
#  to
#
#  i
#
#
#  me have
#  me to
#  the know
#
#
#  with to a
#  the
#  get
#
#  the and
#  i i
#
#
#
#
#
#
#  a
#  minnie to
#  and know and
#  a i
#
#  the
#  the the but
#
#  and
#
#  i me a
#
#  i
#
#
#
#  me
#
#  a now you
#  and
#  the the rocking
#
#  i
#  with the the the of a while and i
#
#
#  is the i the the i the
#  hit
#
#  the i me
#  chat i
#  a
#  you
#
#  i
#  me i the ya
#  a
#
#
#  the
#  a
#  and
#
#
#
#  a
#
#  i
#
#  a
#
#
#
#  i a
#  be
#  in the
#
#  tried
#  the
#  the the
#  i for the the
#  i i
#  the be
#  they am they to a hot i
#
#  a
#  the
#
#
#
#  come
#
#
#  the ya
#
#
#
#  the
#
#
#
#  i i
#
#
#
#
#
#
#  to the the
#
#
#  to
#  the i
#
#  the the
#  the i
#
#  is to i
#  i and
#
#
#
#
#  the i a
#  i a a
#
#  the
#
#
#
#
#
#
#  the the
#
#
#  can
#  i
#  of
#  i
#
#  the the
#  this the
#  i it the
#  you life
#
#  i you
#  i i
#  is
#  for you
#  only
#
#
#
#
#
#
#  the
#
#
#
#
#
#  i not i you i
#
#  i you like to to
#
#  the
#  was i i
#
#
#
#  i
#  i to the
#
#  a
#
#  me
#
#  i
#  the a the
#
#
#  a
#
#
#  a a
#  i
#  i
#
#  the a
#  a am i i
#  i am
#  the i
#  is
#  i
#
#  the
#
#
#
#  a a
#
#
#  of
#  i
#
#  the i
#
#
#  the the the i conceal
#
#  the i
#
#
#
#  the any the
#
#  i
#
#  i
#  and a
#  to a
#
#
#  the
#  they
#  i
#  rising
#
#
#  me the i the
#
#  you
#
#
# Epoch 5/20
# Loss:    	 5.650014400482178
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny the the
#
#  to i
#
#  they a
#  the to
#
#
#
#
#
#  the
#
#  a and i
#
#  a
#  in the
#  i
#  get to
#  a
#
#  started to forget
#
#  a
#  as of
#
#
#  just
#  to
#  wanna now
#  the
#
#  the
#  the to be choose to
#  and know
#  the
#  the i
#
#
#
#  a i
#  he
#
#  a
#
#
#  am
#  me
#  to they my the
#
#  the
#  a the
#
#
#  me
#
#
#  you
#  a
#  so
#
#
#
#
#
#  the i the the
#  the
#  i a the my the am the
#  to
#  a and
#
#
#  to the
#
#
#
#  the a rock
#
#
#
#  am me i is the it
#
#  was
#  nigga
#
#  a to i in
#
#
#
#
#  i
#
#  me
#  the
#
#  the
#
#
#  and
#
#
#
#  be the the to the
#
#
#
#
#  a
#
#  the
#  when not
#  is
#
#  with the
#
#
#
#
#  the
#
#
#  is bullet do i me the to
#
#  you a other
#
#
#  static
#
#  i be i a
#
#  the
#
#
#  had situation em the
#
#
#
#  the
#  top the
#
#
#
#
#  the
#
#
#  i a a the the the
#
#
#
#
#
#  a
#
#  make the
#  the a
#
#  the
#
#  a
#
#
#
#
#
#
#
#  the
#  the the
#  and i
#
#
#
#  to
#
#  be is they
#
#  a the the me
#  i
#
#  is
#
#
#
#  i
#
#
#  the the
#  a i a
#
#  am my
#
#  the the how
#  the
#
#
#  the
#
#  a heart
#  that
#  i
#
#
#  ya to are
#
#
#  am i
#  i
#  the i
#  with i
#  get
#
#
#
#
#  and
#  he
#  the
#  i
#  that to am
#
#
#  to
#
#  is to
#
#
#
#  to the a i to
#  a if
#
#  a know
#
#
#
#
#
#  i my
#
#  to a a the
#
#  the i the
#
#
#  to a
#
#
#  and
#  my of
#  the you
#
#
#
#  one
#  the
#
#  the
#  a
#
#
#
#
#  the
#
#  i got the me i
#  a
#
#
#
# Epoch 6/20
# Loss:    	 5.657566547393799
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
#
#
#
#
#  the
#  a the
#
#
#
#  when
#
#
#
#
#  a
#
#
#
#
#
#
#
#  a
#  the a
#  and
#
#  i
#
#
#
#
#  a is
#
#  is
#  a
#
#
#
#  a
#
#
#  they
#
#
#
#  am
#
#  male
#
#  the
#
#  on
#
#
#
#
#
#
#
#
#  you
#
#  i the be
#
#
#  the my
#
#  ya
#
#  me
#
#
#
#
#
#  the up is and
#  my
#
#
#
#  the
#  to ray the
#
#
#  in
#
#  i
#
#
#
#
#
#  to i
#
#
#
#
#
#
#
#  you
#
#
#
#  and
#  i
#
#
#  a
#
#
#  pac
#  a
#
#  and
#
#
#
#
#
#  it i
#  the
#
#  need i
#
#
#
#
#
#
#
#  me
#
#
#
#
#  will
#
#  the
#
#  the
#
#
#
#
#  the
#
#  i
#
#
#
#
#
#
#
#
#
#
#
#
#
#  is a up the
#
#
#
#  to i
#
#
#
#
#
#
#
#  is
#
#
#
#
#
#
#
#  i
#
#
#
#
#
#
#  i i
#
#
#  the
#  the
#
#
#  i
#
#
#
#
#  the
#  i
#  you
#
#
#  the
#
#
#  it
#
#  the
#
#
#  to you get
#
#
#
#  not a
#
#
#  i the i
#
#
#
#
#
#
#
#  i i and the
#
#
#
#
#
#
#  i
#  the
#
#
#
#  the
#  the i and i
#
#
#
#
#
#  i
#
#  i
#
#
#  a
#  a
#  you i
#  i my
#
#  shot
#  to all
#
#
#
#  cause
#
#  i
#
#
#
#
#
#
#  it
#  i to i my
#
#
#
#
#
#
#
#
#
#
#
#
#  pac i
#  a in a
#
#
#
#
#
#
#
#
#
#
#
#  to of
#
#
#  you i
#
#
#
#
#  is and i
#
#
#  i
#  but
#
#
#
#
#
#
#
#  needle
#
#  i the
#
#  the
#
#
#  and
#
#  a the a
#
#
#  the
#
#  you they
#
#
#
#  for
#
#
#
#
#
#
#
#  is
#
#
#
#
#
#  is
#
#
#
#
#
#
#
#
# Epoch 7/20
# Loss:    	 5.640377521514893
# Accuracy:	 10.550409317016602
# Seed:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny
# Result:as real as it seems the american dream
#  is not nothing but another calculated schemes
#  to get us locked up shot up back in chains
#  to deny the a
#
#
#
#  that i my
#
#
#
#
#
#
#
#
#
#
#  in
#  ya to
#  a a get
#
#  you
#  kept
#
#
#
#
#
#
#
#
#
#
#
#
#  get it
#  a to
#  back i
#
#
#  the
#
#  he
#
#  you
#
#
#
#  i
#
#
#  the
#
#  it i
#
#
#
#
#
#  a i but
#
#
#
#
#
#  your
#  a
#
#
#
#
#
#
#  that
#
#
#
#
#  the
#
#
#
#
#
#
#  a is
#
#  to
#
#
#
#  a
#
#
#
#
#
#  i
#
#
#
#  you
#  my
#
#  my i
#  i
#  my
#
#
#
#
#
#
#
#
#
#  if
#  my i
#
#  i
#  am
#
#
#
#
#
#  with
#
#
#  to
#
#
#
#
#
#  the
#
#
#
#
#  the now
#
#
#  a
#
#
#
#
#  a
#
#  i
#
#  to
#  of
#  to to and
#
#
#
#  i
#
#
#
#
#  the
#  that
#
#
#  i a of
#
#
#
#
#
#  on
#
#  the
#  i
#  me
#
#
#  i
#
#  a to
#
#  up i should i
#
#  my the
#
#
#
#
#  me to
#  the
#
#
#
#
#
#  i
#
#  am
#  to
#
#
#
#  the
#
#  the
#
#
#
#
#
#
#  of
#  a
#  i
#
#
#
#  not
#
#
#  a
#
#  on
#  i
#
#
#  is the
#  it
#
#  the
#
#
#
#
#
#
#
#  i
#  i
#
#  i go
#  you the
#
#
#
#  the a
#
#
#
#
#
#
#  and
#
#
#  a
#  the
#
#
#
#
#
#
#
#
#
#  i
#
#
#  i is
#  that
#  so to
#
#
#
#  like
#
#
#
#
#
#  not
#  static
#
#  i
#  why
#
#
#
#
#
#
#
#  to
#
#
#
#  just
#
#
#
#
#
#
#
#
#  the me
#
#  to
#
#
#
#
#
#  to
#
#
#  was
#
#
#  am
#
#
#  to me
#  to
#
#
#
#
#  i
#
#
#
#
#
#
#
#
#
#
#
#
#  a they me
#  to
#
#  not
#  i
#
#
#
#  you
#
#
#
#
#
#
#
#
#
#
# Epoch 8/20
# Loss:    	 5.636784076690674
# Accuracy:	 10.550409317016602
